# %% [markdown]
# ## install mujoco-py, D4RL, graph libs
#
# * **Restart Runtime** after running this block to complete D4RL setup

# %%
###### libs for install ######


# !sudo apt-get update
# !sudo apt-get install gcc

# !sudo apt-get build-dep mesa
# !sudo apt-get install llvm-dev
# !sudo apt-get install freeglut3 freeglut3-dev

# !sudo apt-get install python3-dev

# !sudo apt-get install build-essential

# !sudo apt install curl git libgl1-mesa-dev libgl1-mesa-glx libglew-dev \
        libosmesa6-dev software-properties-common net-tools unzip vim \
        virtualenv wget xpra xserver-xorg-dev libglfw3-dev patchelf

#!sudo apt-get install -y libglew-dev

# !pip install networkx
# !pip install pybind11
# !pip install graph-walker
# !pip install glfw
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [830 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,798 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,082 kB]
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [27.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,374 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,069 kB]
# Fetched 7,542 kB in 3s (2,315 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gcc is already the newest version (4:11.2.0-1ubuntu1).
# gcc set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 51 not upgraded.
# Reading package lists... Done
# E: Unable to find a source package for mesa
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   binfmt-support libffi-dev libpfm4 libz3-4 libz3-dev llvm llvm-14 llvm-14-dev
#   llvm-14-runtime llvm-14-tools llvm-runtime python3-pygments python3-yaml
# Suggested packages:
#   llvm-14-doc python-pygments-doc ttf-bitstream-vera
# The following NEW packages will be installed:
#   binfmt-support libffi-dev libpfm4 libz3-4 libz3-dev llvm llvm-14 llvm-14-dev
#   llvm-14-runtime llvm-14-tools llvm-dev llvm-runtime python3-pygments
#   python3-yaml
# 0 upgraded, 14 newly installed, 0 to remove and 51 not upgraded.
# Need to get 58.6 MB of archives.
# After this operation, 355 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-yaml amd64 5.4.1-1ubuntu1 [129 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 binfmt-support amd64 2.2.1-2 [55.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 llvm-14-runtime amd64 1:14.0.0-1ubuntu1.1 [484 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 llvm-runtime amd64 1:14.0-55~exp2 [3,204 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpfm4 amd64 4.11.1+git32-gd0b85fb-1ubuntu0.1 [345 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 llvm-14 amd64 1:14.0.0-1ubuntu1.1 [12.7 MB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 llvm amd64 1:14.0-55~exp2 [3,758 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libffi-dev amd64 3.4.2-4 [63.7 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-pygments all 2.11.2+dfsg-2 [750 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 llvm-14-tools amd64 1:14.0.0-1ubuntu1.1 [404 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libz3-4 amd64 4.8.12-1 [5,766 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libz3-dev amd64 4.8.12-1 [72.2 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 llvm-14-dev amd64 1:14.0.0-1ubuntu1.1 [37.8 MB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/universe amd64 llvm-dev amd64 1:14.0-55~exp2 [1,656 B]
# Fetched 58.6 MB in 7s (8,837 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 14.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package python3-yaml.
# (Reading database ... 121918 files and directories currently installed.)
# Preparing to unpack .../00-python3-yaml_5.4.1-1ubuntu1_amd64.deb ...
# Unpacking python3-yaml (5.4.1-1ubuntu1) ...
# Selecting previously unselected package binfmt-support.
# Preparing to unpack .../01-binfmt-support_2.2.1-2_amd64.deb ...
# Unpacking binfmt-support (2.2.1-2) ...
# Selecting previously unselected package llvm-14-runtime.
# Preparing to unpack .../02-llvm-14-runtime_1%3a14.0.0-1ubuntu1.1_amd64.deb ...
# Unpacking llvm-14-runtime (1:14.0.0-1ubuntu1.1) ...
# Selecting previously unselected package llvm-runtime:amd64.
# Preparing to unpack .../03-llvm-runtime_1%3a14.0-55~exp2_amd64.deb ...
# Unpacking llvm-runtime:amd64 (1:14.0-55~exp2) ...
# Selecting previously unselected package libpfm4:amd64.
# Preparing to unpack .../04-libpfm4_4.11.1+git32-gd0b85fb-1ubuntu0.1_amd64.deb ...
# Unpacking libpfm4:amd64 (4.11.1+git32-gd0b85fb-1ubuntu0.1) ...
# Selecting previously unselected package llvm-14.
# Preparing to unpack .../05-llvm-14_1%3a14.0.0-1ubuntu1.1_amd64.deb ...
# Unpacking llvm-14 (1:14.0.0-1ubuntu1.1) ...
# Selecting previously unselected package llvm.
# Preparing to unpack .../06-llvm_1%3a14.0-55~exp2_amd64.deb ...
# Unpacking llvm (1:14.0-55~exp2) ...
# Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../07-libffi-dev_3.4.2-4_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.4.2-4) ...
# Selecting previously unselected package python3-pygments.
# Preparing to unpack .../08-python3-pygments_2.11.2+dfsg-2_all.deb ...
# Unpacking python3-pygments (2.11.2+dfsg-2) ...
# Selecting previously unselected package llvm-14-tools.
# Preparing to unpack .../09-llvm-14-tools_1%3a14.0.0-1ubuntu1.1_amd64.deb ...
# Unpacking llvm-14-tools (1:14.0.0-1ubuntu1.1) ...
# Selecting previously unselected package libz3-4:amd64.
# Preparing to unpack .../10-libz3-4_4.8.12-1_amd64.deb ...
# Unpacking libz3-4:amd64 (4.8.12-1) ...
# Selecting previously unselected package libz3-dev:amd64.
# Preparing to unpack .../11-libz3-dev_4.8.12-1_amd64.deb ...
# Unpacking libz3-dev:amd64 (4.8.12-1) ...
# Selecting previously unselected package llvm-14-dev.
# Preparing to unpack .../12-llvm-14-dev_1%3a14.0.0-1ubuntu1.1_amd64.deb ...
# Unpacking llvm-14-dev (1:14.0.0-1ubuntu1.1) ...
# Selecting previously unselected package llvm-dev.
# Preparing to unpack .../13-llvm-dev_1%3a14.0-55~exp2_amd64.deb ...
# Unpacking llvm-dev (1:14.0-55~exp2) ...
# Setting up python3-yaml (5.4.1-1ubuntu1) ...
# Setting up libffi-dev:amd64 (3.4.2-4) ...
# Setting up python3-pygments (2.11.2+dfsg-2) ...
# Setting up libz3-4:amd64 (4.8.12-1) ...
# Setting up libpfm4:amd64 (4.11.1+git32-gd0b85fb-1ubuntu0.1) ...
# Setting up llvm-14-runtime (1:14.0.0-1ubuntu1.1) ...
# Setting up llvm-runtime:amd64 (1:14.0-55~exp2) ...
# Setting up binfmt-support (2.2.1-2) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of restart.
# Created symlink /etc/systemd/system/multi-user.target.wants/binfmt-support.service → /lib/systemd/system/binfmt-support.service.
# Setting up llvm-14 (1:14.0.0-1ubuntu1.1) ...
# Setting up llvm-14-tools (1:14.0.0-1ubuntu1.1) ...
# Setting up libz3-dev:amd64 (4.8.12-1) ...
# Setting up llvm (1:14.0-55~exp2) ...
# Setting up llvm-14-dev (1:14.0.0-1ubuntu1.1) ...
# Setting up llvm-dev (1:14.0-55~exp2) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libegl-dev libgl-dev libgl1-mesa-dev libgles-dev libgles1 libglu1-mesa
#   libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev libice-dev
#   libopengl-dev libsm-dev libxt-dev
# Suggested packages:
#   libice-doc libsm-doc libxt-doc
# The following NEW packages will be installed:
#   freeglut3 freeglut3-dev libegl-dev libgl-dev libgl1-mesa-dev libgles-dev
#   libgles1 libglu1-mesa libglu1-mesa-dev libglvnd-core-dev libglvnd-dev
#   libglx-dev libice-dev libopengl-dev libsm-dev libxt-dev
# 0 upgraded, 16 newly installed, 0 to remove and 51 not upgraded.
# Need to get 1,262 kB of archives.
# After this operation, 6,754 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freeglut3 amd64 2.8.1-6 [74.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.2 [6,842 B]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa-dev amd64 9.0.2-1 [231 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libice-dev amd64 2:1.0.10-1build2 [51.4 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsm-dev amd64 2:1.2.3-1build2 [18.1 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxt-dev amd64 1:1.2.1-1 [396 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freeglut3-dev amd64 2.8.1-6 [126 kB]
# Fetched 1,262 kB in 1s (1,944 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 16.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package freeglut3:amd64.
# (Reading database ... 125208 files and directories currently installed.)
# Preparing to unpack .../00-freeglut3_2.8.1-6_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-6) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../01-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../02-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../03-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../04-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../05-libgles1_1.4.0-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../06-libgles-dev_1.4.0-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../07-libopengl-dev_1.4.0-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../08-libglvnd-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../09-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../10-libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Selecting previously unselected package libglu1-mesa-dev:amd64.
# Preparing to unpack .../11-libglu1-mesa-dev_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Selecting previously unselected package libice-dev:amd64.
# Preparing to unpack .../12-libice-dev_2%3a1.0.10-1build2_amd64.deb ...
# Unpacking libice-dev:amd64 (2:1.0.10-1build2) ...
# Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../13-libsm-dev_2%3a1.2.3-1build2_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.3-1build2) ...
# Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../14-libxt-dev_1%3a1.2.1-1_amd64.deb ...
# Unpacking libxt-dev:amd64 (1:1.2.1-1) ...
# Selecting previously unselected package freeglut3-dev:amd64.
# Preparing to unpack .../15-freeglut3-dev_2.8.1-6_amd64.deb ...
# Unpacking freeglut3-dev:amd64 (2.8.1-6) ...
# Setting up freeglut3:amd64 (2.8.1-6) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up libice-dev:amd64 (2:1.0.10-1build2) ...
# Setting up libsm-dev:amd64 (2:1.2.3-1build2) ...
# Setting up libxt-dev:amd64 (1:1.2.1-1) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up freeglut3-dev:amd64 (2.8.1-6) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3-dev is already the newest version (3.10.6-1~22.04).
# python3-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 51 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# 0 upgraded, 0 newly installed, 0 to remove and 51 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# wget is already the newest version (1.21.2-2ubuntu1).
# curl is already the newest version (7.81.0-1ubuntu1.16).
# git is already the newest version (1:2.34.1-1ubuntu1.10).
# libgl1-mesa-dev is already the newest version (23.2.1-1ubuntu3.1~22.04.2).
# libgl1-mesa-dev set to manually installed.
# software-properties-common is already the newest version (0.99.22.9).
# unzip is already the newest version (6.0-26ubuntu3.2).
# vim is already the newest version (2:8.2.3995-1ubuntu2.16).
# The following additional packages will be installed:
#   gir1.2-appindicator3-0.1 gir1.2-atk-1.0 gir1.2-freedesktop
#   gir1.2-gdkpixbuf-2.0 gir1.2-gtk-3.0 gir1.2-harfbuzz-0.0 gir1.2-pango-1.0
#   keyboard-configuration libappindicator3-1 libdbusmenu-glib4
#   libdbusmenu-gtk3-4 libdrm-dev libegl1-mesa-dev libfontenc-dev libfontenc1
#   libglfw3 libimagequant0 liblocale-gettext-perl liblzo2-2 libosmesa6
#   libpangoxft-1.0-0 libpciaccess-dev libpixman-1-dev libraqm0 libudev1
#   libvulkan-dev libvulkan1 libwayland-bin libwayland-dev libxcvt-dev libxcvt0
#   libxfont-dev libxfont2 libxkbfile-dev libxkbfile1 libxrandr-dev libxtst6
#   mailcap mesa-common-dev mesa-vulkan-drivers mime-support python3-bcrypt
#   python3-brotli python3-cairo python3-cpuinfo python3-decorator
#   python3-distlib python3-dns python3-filelock python3-gssapi python3-ifaddr
#   python3-kerberos python3-lz4 python3-lzo python3-nacl python3-numpy
#   python3-olefile python3-opengl python3-paramiko python3-pil python3-pip
#   python3-pip-whl python3-platformdirs python3-pyinotify python3-rencode
#   python3-setproctitle python3-setuptools python3-setuptools-whl
#   python3-uritools python3-virtualenv python3-wheel python3-wheel-whl
#   python3-xdg python3-zeroconf ssh-askpass systemd-hwe-hwdb udev x11-xkb-utils
#   x11-xserver-utils xcvt xfonts-base xfonts-encodings xfonts-utils
#   xserver-common xserver-xorg-core xserver-xorg-video-dummy xvfb
# Suggested packages:
#   indicator-application libglfw3-doc libwayland-doc python-nacl-doc
#   python-numpy-doc python3-pytest libgle3 python3-invoke python-pil-doc
#   python-pyinotify-doc python-setuptools-doc python2-pip-whl
#   python2-setuptools-whl nickle cairo-5c xorg-docs-core openssh-server
#   python3-pyopencl gstreamer1.0-plugins-base gstreamer1.0-plugins-good
#   | gstreamer1.0-plugins-ugly | gstreamer1.0-plugins-bad python3-gst-1.0
#   pulseaudio pulseaudio-utils python3-avahi python3-netifaces cups-client
#   cups-common cups-filters cups-pdf python3-cups python3-opencv
#   v4l2loopback-dkms python3-uinput xfonts-100dpi | xfonts-75dpi
#   xfonts-scalable
# The following NEW packages will be installed:
#   gir1.2-appindicator3-0.1 gir1.2-atk-1.0 gir1.2-freedesktop
#   gir1.2-gdkpixbuf-2.0 gir1.2-gtk-3.0 gir1.2-harfbuzz-0.0 gir1.2-pango-1.0
#   keyboard-configuration libappindicator3-1 libdbusmenu-glib4
#   libdbusmenu-gtk3-4 libdrm-dev libegl1-mesa-dev libfontenc-dev libfontenc1
#   libgl1-mesa-glx libglew-dev libglfw3 libglfw3-dev libimagequant0
#   liblocale-gettext-perl liblzo2-2 libosmesa6 libosmesa6-dev libpangoxft-1.0-0
#   libpciaccess-dev libpixman-1-dev libraqm0 libvulkan-dev libvulkan1
#   libwayland-bin libwayland-dev libxcvt-dev libxcvt0 libxfont-dev libxfont2
#   libxkbfile-dev libxkbfile1 libxrandr-dev libxtst6 mailcap mesa-common-dev
#   mesa-vulkan-drivers mime-support net-tools patchelf python3-bcrypt
#   python3-brotli python3-cairo python3-cpuinfo python3-decorator
#   python3-distlib python3-dns python3-filelock python3-gssapi python3-ifaddr
#   python3-kerberos python3-lz4 python3-lzo python3-nacl python3-numpy
#   python3-olefile python3-opengl python3-paramiko python3-pil python3-pip
#   python3-pip-whl python3-platformdirs python3-pyinotify python3-rencode
#   python3-setproctitle python3-setuptools python3-setuptools-whl
#   python3-uritools python3-virtualenv python3-wheel python3-wheel-whl
#   python3-xdg python3-zeroconf ssh-askpass systemd-hwe-hwdb udev virtualenv
#   x11-xkb-utils x11-xserver-utils xcvt xfonts-base xfonts-encodings
#   xfonts-utils xpra xserver-common xserver-xorg-core xserver-xorg-dev
#   xserver-xorg-video-dummy xvfb
# The following packages will be upgraded:
#   libudev1
# 1 upgraded, 95 newly installed, 0 to remove and 50 not upgraded.
# Need to get 44.8 MB of archives.
# After this operation, 187 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblocale-gettext-perl amd64 1.07-4build3 [17.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 keyboard-configuration all 1.205ubuntu3 [206 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.12 [78.2 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.12 [1,557 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 gir1.2-atk-1.0 amd64 2.36.0-3build1 [21.0 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 gir1.2-freedesktop amd64 1.72.0-1 [22.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.42.8+dfsg-1ubuntu0.2 [9,482 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-harfbuzz-0.0 amd64 2.7.4-1ubuntu3.1 [31.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpangoxft-1.0-0 amd64 1.50.6+ds-2ubuntu1 [31.0 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-pango-1.0 amd64 1.50.6+ds-2ubuntu1 [44.0 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-gtk-3.0 amd64 3.24.33-1ubuntu2.1 [240 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdbusmenu-glib4 amd64 16.04.1+18.10.20180917-0ubuntu8 [45.4 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdbusmenu-gtk3-4 amd64 16.04.1+18.10.20180917-0ubuntu8 [31.0 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libappindicator3-1 amd64 12.10.1+20.10.20200706.1-0ubuntu1 [23.2 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/universe amd64 gir1.2-appindicator3-0.1 amd64 12.10.1+20.10.20200706.1-0ubuntu1 [3,452 B]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpciaccess-dev amd64 0.16-3 [21.9 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-dev amd64 2.4.113-2~ubuntu0.22.04.1 [292 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libegl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.2 [11.1 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc-dev amd64 1:1.1.4-1build3 [15.4 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libgl1-mesa-glx amd64 23.0.4-0ubuntu1~22.04.1 [5,584 B]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglew-dev amd64 2.2.0-4 [287 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglfw3 amd64 3.3.6-1 [83.2 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libglfw3-dev amd64 3.3.6-1 [41.1 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libimagequant0 amd64 2.17.0-1 [34.6 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblzo2-2 amd64 2.10-2build3 [53.7 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpixman-1-dev amd64 0.40.0-1ubuntu0.22.04.1 [280 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libraqm0 amd64 0.7.0-4ubuntu1 [11.7 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvulkan1 amd64 1.3.204.1-2 [128 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvulkan-dev amd64 1.3.204.1-2 [892 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt0 amd64 0.1.1-3 [5,494 B]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcvt-dev amd64 0.1.1-3 [3,242 B]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont-dev amd64 1:2.0.5-1build1 [128 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile-dev amd64 1:1.1.0-1build3 [85.0 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxrandr-dev amd64 2:1.5.2-1build1 [26.7 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 mailcap all 3.70+nmu1ubuntu1 [23.8 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mesa-common-dev amd64 23.2.1-1ubuntu3.1~22.04.2 [2,208 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mesa-vulkan-drivers amd64 23.2.1-1ubuntu3.1~22.04.2 [10.7 MB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 mime-support all 3.66 [3,696 B]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 net-tools amd64 1.60+git20181103.0eebece-1ubuntu5 [204 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 patchelf amd64 0.14.3-1 [72.1 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-brotli amd64 1.0.9-2build6 [319 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-cairo amd64 1.20.1-3build1 [73.7 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-cpuinfo all 5.0.0-2 [17.3 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-decorator all 4.4.2-0ubuntu1 [10.3 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-distlib all 0.3.4-1 [269 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-dns all 3.2.1-1 [25.6 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-filelock all 3.6.0-1 [8,788 B]
# Get:52 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-gssapi amd64 1.6.12-1ubuntu0.1 [368 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-ifaddr all 0.1.7-1 [8,492 B]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-kerberos amd64 1.1.14-3.1build5 [23.0 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-lz4 amd64 3.1.3+dfsg-1build3 [33.3 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-lzo amd64 1.12-4build1 [8,130 B]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-nacl amd64 1.5.0-2 [63.1 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-numpy amd64 1:1.21.5-1ubuntu22.04.1 [3,467 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-olefile all 0.46-3 [33.8 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-opengl all 3.1.5+dfsg-1 [605 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-bcrypt amd64 3.2.0-1build1 [32.7 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-paramiko all 2.9.3-0ubuntu1.2 [134 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-pil amd64 9.0.1-1ubuntu0.3 [419 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-setuptools all 59.6.0-1.2ubuntu0.22.04.1 [339 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-wheel all 0.37.1-2ubuntu0.22.04.1 [32.0 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip all 22.0.2+dfsg-1ubuntu0.4 [1,305 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip-whl all 22.0.2+dfsg-1ubuntu0.4 [1,680 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-platformdirs all 2.5.1-1 [14.2 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-pyinotify all 0.9.6-1.3 [24.8 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-rencode amd64 1.0.6-2build1 [45.2 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-setuptools-whl all 59.6.0-1.2ubuntu0.22.04.1 [788 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-uritools all 3.0.2-1 [24.7 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-wheel-whl all 0.37.1-2ubuntu0.22.04.1 [38.0 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-virtualenv all 20.13.0+ds-2 [80.3 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-xdg all 0.27-2 [36.9 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-zeroconf all 0.38.3-2 [76.5 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ssh-askpass amd64 1:1.2.4.1-13 [26.0 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.5 [3,228 B]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/universe amd64 virtualenv all 20.13.0+ds-2 [1,968 B]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xserver-utils amd64 7.7+9build1 [170 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/main amd64 xcvt amd64 0.1.1-3 [7,140 B]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:86 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.10 [28.5 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-xorg-core amd64 2:21.1.4-2ubuntu1.7~22.04.10 [1,476 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy/main amd64 xserver-xorg-video-dummy amd64 1:0.3.8-2build1 [9,578 B]
# Get:89 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.10 [863 kB]
# Get:90 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xpra amd64 3.1-1build5 [3,396 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-xorg-dev amd64 2:21.1.4-2ubuntu1.7~22.04.10 [204 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libosmesa6 amd64 23.2.1-1ubuntu3.1~22.04.2 [3,121 kB]
# Get:93 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libosmesa6-dev amd64 23.2.1-1ubuntu3.1~22.04.2 [8,984 B]
# Get:94 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-bin amd64 1.20.0-1ubuntu0.1 [20.4 kB]
# Get:95 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-dev amd64 1.20.0-1ubuntu0.1 [69.5 kB]
# Get:96 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-setproctitle amd64 1.2.2-2build1 [16.1 kB]
# Fetched 44.8 MB in 2s (19.6 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 96.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package liblocale-gettext-perl.
# (Reading database ... 125666 files and directories currently installed.)
# Preparing to unpack .../liblocale-gettext-perl_1.07-4build3_amd64.deb ...
# Unpacking liblocale-gettext-perl (1.07-4build3) ...
# Selecting previously unselected package keyboard-configuration.
# Preparing to unpack .../keyboard-configuration_1.205ubuntu3_all.deb ...
# Unpacking keyboard-configuration (1.205ubuntu3) ...
# Preparing to unpack .../libudev1_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.12) over (249.11-0ubuntu3.10) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.12) ...
# Selecting previously unselected package udev.
# (Reading database ... 125700 files and directories currently installed.)
# Preparing to unpack .../00-udev_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.12) ...
# Selecting previously unselected package gir1.2-atk-1.0:amd64.
# Preparing to unpack .../01-gir1.2-atk-1.0_2.36.0-3build1_amd64.deb ...
# Unpacking gir1.2-atk-1.0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package gir1.2-freedesktop:amd64.
# Preparing to unpack .../02-gir1.2-freedesktop_1.72.0-1_amd64.deb ...
# Unpacking gir1.2-freedesktop:amd64 (1.72.0-1) ...
# Selecting previously unselected package gir1.2-gdkpixbuf-2.0:amd64.
# Preparing to unpack .../03-gir1.2-gdkpixbuf-2.0_2.42.8+dfsg-1ubuntu0.2_amd64.deb ...
# Unpacking gir1.2-gdkpixbuf-2.0:amd64 (2.42.8+dfsg-1ubuntu0.2) ...
# Selecting previously unselected package gir1.2-harfbuzz-0.0:amd64.
# Preparing to unpack .../04-gir1.2-harfbuzz-0.0_2.7.4-1ubuntu3.1_amd64.deb ...
# Unpacking gir1.2-harfbuzz-0.0:amd64 (2.7.4-1ubuntu3.1) ...
# Selecting previously unselected package libpangoxft-1.0-0:amd64.
# Preparing to unpack .../05-libpangoxft-1.0-0_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking libpangoxft-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package gir1.2-pango-1.0:amd64.
# Preparing to unpack .../06-gir1.2-pango-1.0_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking gir1.2-pango-1.0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package gir1.2-gtk-3.0:amd64.
# Preparing to unpack .../07-gir1.2-gtk-3.0_3.24.33-1ubuntu2.1_amd64.deb ...
# Unpacking gir1.2-gtk-3.0:amd64 (3.24.33-1ubuntu2.1) ...
# Selecting previously unselected package libdbusmenu-glib4:amd64.
# Preparing to unpack .../08-libdbusmenu-glib4_16.04.1+18.10.20180917-0ubuntu8_amd64.deb ...
# Unpacking libdbusmenu-glib4:amd64 (16.04.1+18.10.20180917-0ubuntu8) ...
# Selecting previously unselected package libdbusmenu-gtk3-4:amd64.
# Preparing to unpack .../09-libdbusmenu-gtk3-4_16.04.1+18.10.20180917-0ubuntu8_amd64.deb ...
# Unpacking libdbusmenu-gtk3-4:amd64 (16.04.1+18.10.20180917-0ubuntu8) ...
# Selecting previously unselected package libappindicator3-1.
# Preparing to unpack .../10-libappindicator3-1_12.10.1+20.10.20200706.1-0ubuntu1_amd64.deb ...
# Unpacking libappindicator3-1 (12.10.1+20.10.20200706.1-0ubuntu1) ...
# Selecting previously unselected package gir1.2-appindicator3-0.1.
# Preparing to unpack .../11-gir1.2-appindicator3-0.1_12.10.1+20.10.20200706.1-0ubuntu1_amd64.deb ...
# Unpacking gir1.2-appindicator3-0.1 (12.10.1+20.10.20200706.1-0ubuntu1) ...
# Selecting previously unselected package libpciaccess-dev:amd64.
# Preparing to unpack .../12-libpciaccess-dev_0.16-3_amd64.deb ...
# Unpacking libpciaccess-dev:amd64 (0.16-3) ...
# Selecting previously unselected package libdrm-dev:amd64.
# Preparing to unpack .../13-libdrm-dev_2.4.113-2~ubuntu0.22.04.1_amd64.deb ...
# Unpacking libdrm-dev:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Selecting previously unselected package libegl1-mesa-dev:amd64.
# Preparing to unpack .../14-libegl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking libegl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../15-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libfontenc-dev:amd64.
# Preparing to unpack .../16-libfontenc-dev_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc-dev:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libgl1-mesa-glx:amd64.
# Preparing to unpack .../17-libgl1-mesa-glx_23.0.4-0ubuntu1~22.04.1_amd64.deb ...
# Unpacking libgl1-mesa-glx:amd64 (23.0.4-0ubuntu1~22.04.1) ...
# Selecting previously unselected package libglew-dev:amd64.
# Preparing to unpack .../18-libglew-dev_2.2.0-4_amd64.deb ...
# Unpacking libglew-dev:amd64 (2.2.0-4) ...
# Selecting previously unselected package libglfw3:amd64.
# Preparing to unpack .../19-libglfw3_3.3.6-1_amd64.deb ...
# Unpacking libglfw3:amd64 (3.3.6-1) ...
# Selecting previously unselected package libglfw3-dev:amd64.
# Preparing to unpack .../20-libglfw3-dev_3.3.6-1_amd64.deb ...
# Unpacking libglfw3-dev:amd64 (3.3.6-1) ...
# Selecting previously unselected package libimagequant0:amd64.
# Preparing to unpack .../21-libimagequant0_2.17.0-1_amd64.deb ...
# Unpacking libimagequant0:amd64 (2.17.0-1) ...
# Selecting previously unselected package liblzo2-2:amd64.
# Preparing to unpack .../22-liblzo2-2_2.10-2build3_amd64.deb ...
# Unpacking liblzo2-2:amd64 (2.10-2build3) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../23-libpixman-1-dev_0.40.0-1ubuntu0.22.04.1_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.40.0-1ubuntu0.22.04.1) ...
# Selecting previously unselected package libraqm0:amd64.
# Preparing to unpack .../24-libraqm0_0.7.0-4ubuntu1_amd64.deb ...
# Unpacking libraqm0:amd64 (0.7.0-4ubuntu1) ...
# Selecting previously unselected package libvulkan1:amd64.
# Preparing to unpack .../25-libvulkan1_1.3.204.1-2_amd64.deb ...
# Unpacking libvulkan1:amd64 (1.3.204.1-2) ...
# Selecting previously unselected package libvulkan-dev:amd64.
# Preparing to unpack .../26-libvulkan-dev_1.3.204.1-2_amd64.deb ...
# Unpacking libvulkan-dev:amd64 (1.3.204.1-2) ...
# Selecting previously unselected package libxcvt0:amd64.
# Preparing to unpack .../27-libxcvt0_0.1.1-3_amd64.deb ...
# Unpacking libxcvt0:amd64 (0.1.1-3) ...
# Selecting previously unselected package libxcvt-dev:amd64.
# Preparing to unpack .../28-libxcvt-dev_0.1.1-3_amd64.deb ...
# Unpacking libxcvt-dev:amd64 (0.1.1-3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../29-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxfont-dev.
# Preparing to unpack .../30-libxfont-dev_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont-dev (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../31-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxkbfile-dev:amd64.
# Preparing to unpack .../32-libxkbfile-dev_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile-dev:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../33-libxrandr-dev_2%3a1.5.2-1build1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.2-1build1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../34-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package mailcap.
# Preparing to unpack .../35-mailcap_3.70+nmu1ubuntu1_all.deb ...
# Unpacking mailcap (3.70+nmu1ubuntu1) ...
# Selecting previously unselected package mesa-common-dev:amd64.
# Preparing to unpack .../36-mesa-common-dev_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking mesa-common-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package mesa-vulkan-drivers:amd64.
# Preparing to unpack .../37-mesa-vulkan-drivers_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking mesa-vulkan-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package mime-support.
# Preparing to unpack .../38-mime-support_3.66_all.deb ...
# Unpacking mime-support (3.66) ...
# Selecting previously unselected package net-tools.
# Preparing to unpack .../39-net-tools_1.60+git20181103.0eebece-1ubuntu5_amd64.deb ...
# Unpacking net-tools (1.60+git20181103.0eebece-1ubuntu5) ...
# Selecting previously unselected package patchelf.
# Preparing to unpack .../40-patchelf_0.14.3-1_amd64.deb ...
# Unpacking patchelf (0.14.3-1) ...
# Selecting previously unselected package python3-brotli.
# Preparing to unpack .../41-python3-brotli_1.0.9-2build6_amd64.deb ...
# Unpacking python3-brotli (1.0.9-2build6) ...
# Selecting previously unselected package python3-cairo:amd64.
# Preparing to unpack .../42-python3-cairo_1.20.1-3build1_amd64.deb ...
# Unpacking python3-cairo:amd64 (1.20.1-3build1) ...
# Selecting previously unselected package python3-cpuinfo.
# Preparing to unpack .../43-python3-cpuinfo_5.0.0-2_all.deb ...
# Unpacking python3-cpuinfo (5.0.0-2) ...
# Selecting previously unselected package python3-decorator.
# Preparing to unpack .../44-python3-decorator_4.4.2-0ubuntu1_all.deb ...
# Unpacking python3-decorator (4.4.2-0ubuntu1) ...
# Selecting previously unselected package python3-distlib.
# Preparing to unpack .../45-python3-distlib_0.3.4-1_all.deb ...
# Unpacking python3-distlib (0.3.4-1) ...
# Selecting previously unselected package python3-dns.
# Preparing to unpack .../46-python3-dns_3.2.1-1_all.deb ...
# Unpacking python3-dns (3.2.1-1) ...
# Selecting previously unselected package python3-filelock.
# Preparing to unpack .../47-python3-filelock_3.6.0-1_all.deb ...
# Unpacking python3-filelock (3.6.0-1) ...
# Selecting previously unselected package python3-gssapi.
# Preparing to unpack .../48-python3-gssapi_1.6.12-1ubuntu0.1_amd64.deb ...
# Unpacking python3-gssapi (1.6.12-1ubuntu0.1) ...
# Selecting previously unselected package python3-ifaddr.
# Preparing to unpack .../49-python3-ifaddr_0.1.7-1_all.deb ...
# Unpacking python3-ifaddr (0.1.7-1) ...
# Selecting previously unselected package python3-kerberos.
# Preparing to unpack .../50-python3-kerberos_1.1.14-3.1build5_amd64.deb ...
# Unpacking python3-kerberos (1.1.14-3.1build5) ...
# Selecting previously unselected package python3-lz4.
# Preparing to unpack .../51-python3-lz4_3.1.3+dfsg-1build3_amd64.deb ...
# Unpacking python3-lz4 (3.1.3+dfsg-1build3) ...
# Selecting previously unselected package python3-lzo:amd64.
# Preparing to unpack .../52-python3-lzo_1.12-4build1_amd64.deb ...
# Unpacking python3-lzo:amd64 (1.12-4build1) ...
# Selecting previously unselected package python3-nacl.
# Preparing to unpack .../53-python3-nacl_1.5.0-2_amd64.deb ...
# Unpacking python3-nacl (1.5.0-2) ...
# Selecting previously unselected package python3-numpy.
# Preparing to unpack .../54-python3-numpy_1%3a1.21.5-1ubuntu22.04.1_amd64.deb ...
# Unpacking python3-numpy (1:1.21.5-1ubuntu22.04.1) ...
# Selecting previously unselected package python3-olefile.
# Preparing to unpack .../55-python3-olefile_0.46-3_all.deb ...
# Unpacking python3-olefile (0.46-3) ...
# Selecting previously unselected package python3-opengl.
# Preparing to unpack .../56-python3-opengl_3.1.5+dfsg-1_all.deb ...
# Unpacking python3-opengl (3.1.5+dfsg-1) ...
# Selecting previously unselected package python3-bcrypt.
# Preparing to unpack .../57-python3-bcrypt_3.2.0-1build1_amd64.deb ...
# Unpacking python3-bcrypt (3.2.0-1build1) ...
# Selecting previously unselected package python3-paramiko.
# Preparing to unpack .../58-python3-paramiko_2.9.3-0ubuntu1.2_all.deb ...
# Unpacking python3-paramiko (2.9.3-0ubuntu1.2) ...
# Selecting previously unselected package python3-pil:amd64.
# Preparing to unpack .../59-python3-pil_9.0.1-1ubuntu0.3_amd64.deb ...
# Unpacking python3-pil:amd64 (9.0.1-1ubuntu0.3) ...
# Selecting previously unselected package python3-setuptools.
# Preparing to unpack .../60-python3-setuptools_59.6.0-1.2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-setuptools (59.6.0-1.2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../61-python3-wheel_0.37.1-2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../62-python3-pip_22.0.2+dfsg-1ubuntu0.4_all.deb ...
# Unpacking python3-pip (22.0.2+dfsg-1ubuntu0.4) ...
# Selecting previously unselected package python3-pip-whl.
# Preparing to unpack .../63-python3-pip-whl_22.0.2+dfsg-1ubuntu0.4_all.deb ...
# Unpacking python3-pip-whl (22.0.2+dfsg-1ubuntu0.4) ...
# Selecting previously unselected package python3-platformdirs.
# Preparing to unpack .../64-python3-platformdirs_2.5.1-1_all.deb ...
# Unpacking python3-platformdirs (2.5.1-1) ...
# Selecting previously unselected package python3-pyinotify.
# Preparing to unpack .../65-python3-pyinotify_0.9.6-1.3_all.deb ...
# Unpacking python3-pyinotify (0.9.6-1.3) ...
# Selecting previously unselected package python3-rencode.
# Preparing to unpack .../66-python3-rencode_1.0.6-2build1_amd64.deb ...
# Unpacking python3-rencode (1.0.6-2build1) ...
# Selecting previously unselected package python3-setuptools-whl.
# Preparing to unpack .../67-python3-setuptools-whl_59.6.0-1.2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-setuptools-whl (59.6.0-1.2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-uritools.
# Preparing to unpack .../68-python3-uritools_3.0.2-1_all.deb ...
# Unpacking python3-uritools (3.0.2-1) ...
# Selecting previously unselected package python3-wheel-whl.
# Preparing to unpack .../69-python3-wheel-whl_0.37.1-2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-wheel-whl (0.37.1-2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-virtualenv.
# Preparing to unpack .../70-python3-virtualenv_20.13.0+ds-2_all.deb ...
# Unpacking python3-virtualenv (20.13.0+ds-2) ...
# Selecting previously unselected package python3-xdg.
# Preparing to unpack .../71-python3-xdg_0.27-2_all.deb ...
# Unpacking python3-xdg (0.27-2) ...
# Selecting previously unselected package python3-zeroconf.
# Preparing to unpack .../72-python3-zeroconf_0.38.3-2_all.deb ...
# Unpacking python3-zeroconf (0.38.3-2) ...
# Selecting previously unselected package ssh-askpass.
# Preparing to unpack .../73-ssh-askpass_1%3a1.2.4.1-13_amd64.deb ...
# Unpacking ssh-askpass (1:1.2.4.1-13) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../74-systemd-hwe-hwdb_249.11.5_all.deb ...
# Unpacking systemd-hwe-hwdb (249.11.5) ...
# Selecting previously unselected package virtualenv.
# Preparing to unpack .../75-virtualenv_20.13.0+ds-2_all.deb ...
# Unpacking virtualenv (20.13.0+ds-2) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../76-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package x11-xserver-utils.
# Preparing to unpack .../77-x11-xserver-utils_7.7+9build1_amd64.deb ...
# Unpacking x11-xserver-utils (7.7+9build1) ...
# Selecting previously unselected package xcvt.
# Preparing to unpack .../78-xcvt_0.1.1-3_amd64.deb ...
# Unpacking xcvt (0.1.1-3) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../79-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../80-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../81-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../82-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.10_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.10) ...
# Selecting previously unselected package xserver-xorg-core.
# Preparing to unpack .../83-xserver-xorg-core_2%3a21.1.4-2ubuntu1.7~22.04.10_amd64.deb ...
# Unpacking xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.10) ...
# Selecting previously unselected package xserver-xorg-video-dummy.
# Preparing to unpack .../84-xserver-xorg-video-dummy_1%3a0.3.8-2build1_amd64.deb ...
# Unpacking xserver-xorg-video-dummy (1:0.3.8-2build1) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../85-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.10_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.10) ...
# Selecting previously unselected package xpra.
# Preparing to unpack .../86-xpra_3.1-1build5_amd64.deb ...
# Unpacking xpra (3.1-1build5) ...
# Selecting previously unselected package xserver-xorg-dev.
# Preparing to unpack .../87-xserver-xorg-dev_2%3a21.1.4-2ubuntu1.7~22.04.10_amd64.deb ...
# Unpacking xserver-xorg-dev (2:21.1.4-2ubuntu1.7~22.04.10) ...
# Selecting previously unselected package libosmesa6:amd64.
# Preparing to unpack .../88-libosmesa6_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking libosmesa6:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package libosmesa6-dev:amd64.
# Preparing to unpack .../89-libosmesa6-dev_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking libosmesa6-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package libwayland-bin.
# Preparing to unpack .../90-libwayland-bin_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-bin (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package libwayland-dev:amd64.
# Preparing to unpack .../91-libwayland-dev_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-dev:amd64 (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package python3-setproctitle:amd64.
# Preparing to unpack .../92-python3-setproctitle_1.2.2-2build1_amd64.deb ...
# Unpacking python3-setproctitle:amd64 (1.2.2-2build1) ...
# Setting up python3-uritools (3.0.2-1) ...
# Setting up libglfw3:amd64 (3.3.6-1) ...
# Setting up net-tools (1.60+git20181103.0eebece-1ubuntu5) ...
# Setting up python3-setuptools-whl (59.6.0-1.2ubuntu0.22.04.1) ...
# Setting up python3-filelock (3.6.0-1) ...
# Setting up gir1.2-freedesktop:amd64 (1.72.0-1) ...
# Setting up libpixman-1-dev:amd64 (0.40.0-1ubuntu0.22.04.1) ...
# Setting up libpciaccess-dev:amd64 (0.16-3) ...
# Setting up python3-cairo:amd64 (1.20.1-3build1) ...
# Setting up python3-rencode (1.0.6-2build1) ...
# Setting up python3-setuptools (59.6.0-1.2ubuntu0.22.04.1) ...
# Setting up libpangoxft-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libglfw3-dev:amd64 (3.3.6-1) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.42.8+dfsg-1ubuntu0.2) ...
# Setting up python3-pip-whl (22.0.2+dfsg-1ubuntu0.4) ...
# Setting up python3-lz4 (3.1.3+dfsg-1build3) ...
# Setting up gir1.2-atk-1.0:amd64 (2.36.0-3build1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up python3-olefile (0.46-3) ...
# Setting up libdbusmenu-glib4:amd64 (16.04.1+18.10.20180917-0ubuntu8) ...
# Setting up python3-bcrypt (3.2.0-1build1) ...
# Setting up python3-pyinotify (0.9.6-1.3) ...
# Setting up python3-kerberos (1.1.14-3.1build5) ...
# Setting up liblzo2-2:amd64 (2.10-2build3) ...
# Setting up python3-distlib (0.3.4-1) ...
# Setting up python3-opengl (3.1.5+dfsg-1) ...
# Setting up python3-xdg (0.27-2) ...
# Setting up x11-xserver-utils (7.7+9build1) ...
# Setting up gir1.2-harfbuzz-0.0:amd64 (2.7.4-1ubuntu3.1) ...
# Setting up python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Setting up python3-platformdirs (2.5.1-1) ...
# Setting up python3-ifaddr (0.1.7-1) ...
# Setting up libglew-dev:amd64 (2.2.0-4) ...
# Setting up libwayland-bin (1.20.0-1ubuntu0.1) ...
# Setting up python3-decorator (4.4.2-0ubuntu1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up gir1.2-pango-1.0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libxrandr-dev:amd64 (2:1.5.2-1build1) ...
# Setting up ssh-askpass (1:1.2.4.1-13) ...
# update-alternatives: using /usr/lib/ssh/x11-ssh-askpass to provide /usr/bin/ssh-askpass (ssh-askpass) in auto mode
# Setting up python3-gssapi (1.6.12-1ubuntu0.1) ...
# Setting up python3-brotli (1.0.9-2build6) ...
# Setting up libraqm0:amd64 (0.7.0-4ubuntu1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libimagequant0:amd64 (2.17.0-1) ...
# Setting up python3-setproctitle:amd64 (1.2.2-2build1) ...
# Setting up udev (249.11-0ubuntu3.12) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up python3-pip (22.0.2+dfsg-1ubuntu0.4) ...
# Setting up python3-dns (3.2.1-1) ...
# Setting up python3-cpuinfo (5.0.0-2) ...
# Setting up python3-numpy (1:1.21.5-1ubuntu22.04.1) ...
# Setting up libvulkan1:amd64 (1.3.204.1-2) ...
# Setting up systemd-hwe-hwdb (249.11.5) ...
# Setting up libgl1-mesa-glx:amd64 (23.0.4-0ubuntu1~22.04.1) ...
# Setting up libxcvt0:amd64 (0.1.1-3) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up patchelf (0.14.3-1) ...
# Setting up python3-wheel-whl (0.37.1-2ubuntu0.22.04.1) ...
# Setting up mailcap (3.70+nmu1ubuntu1) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up liblocale-gettext-perl (1.07-4build3) ...
# Setting up python3-nacl (1.5.0-2) ...
# Setting up python3-lzo:amd64 (1.12-4build1) ...
# Setting up libxkbfile-dev:amd64 (1:1.1.0-1build3) ...
# Setting up libosmesa6:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up libegl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up mesa-vulkan-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up libdrm-dev:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libdbusmenu-gtk3-4:amd64 (16.04.1+18.10.20180917-0ubuntu8) ...
# Setting up libvulkan-dev:amd64 (1.3.204.1-2) ...
# Setting up libxcvt-dev:amd64 (0.1.1-3) ...
# Setting up mime-support (3.66) ...
# Setting up python3-zeroconf (0.38.3-2) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up gir1.2-gtk-3.0:amd64 (3.24.33-1ubuntu2.1) ...
# Setting up libfontenc-dev:amd64 (1:1.1.4-1build3) ...
# Setting up python3-virtualenv (20.13.0+ds-2) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up libwayland-dev:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up libappindicator3-1 (12.10.1+20.10.20200706.1-0ubuntu1) ...
# Setting up xcvt (0.1.1-3) ...
# Setting up python3-pil:amd64 (9.0.1-1ubuntu0.3) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up gir1.2-appindicator3-0.1 (12.10.1+20.10.20200706.1-0ubuntu1) ...
# Setting up virtualenv (20.13.0+ds-2) ...
# Setting up libosmesa6-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up mesa-common-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.10) ...
# Setting up keyboard-configuration (1.205ubuntu3) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Configuring keyboard-configuration
# ----------------------------------
#
# The layout of keyboards varies per country, with some countries having multiple
# common layouts. Please select the country of origin for the keyboard of this
# computer.
#
#   1. Afghani
#   2. Albanian
#   3. Amharic
#   4. Arabic
#   5. Arabic (Morocco)
#   6. Arabic (Syria)
#   7. Armenian
#   8. A user-defined custom Layout
#   9. Azerbaijani
#   10. Bambara
#   11. Bangla
#   12. Belarusian
#   13. Belgian
#   14. Berber (Algeria, Latin)
#   15. Bosnian
#   16. Braille
#   17. Bulgarian
#   18. Burmese
#   19. Chinese
#   20. Croatian
#   21. Czech
#   22. Danish
#   23. Dhivehi
#   24. Dutch
#   25. Dzongkha
#   26. English (Australian)
#   27. English (Cameroon)
#   28. English (Ghana)
#   29. English (Nigeria)
#   30. English (South Africa)
#   31. English (UK)
#   32. English (US)
#   33. Esperanto
#   34. Estonian
#   35. Faroese
#   36. Filipino
#   37. Finnish
#   38. French
#   39. French (Canada)
#   40. French (Democratic Republic of the Congo)
#   41. French (Togo)
#   42. Georgian
#   43. German
#   44. German (Austria)
#   45. Greek
#   46. Hebrew
#   47. Hungarian
#   48. Icelandic
#   49. Indian
#   50. Indonesian (Javanese)
#   51. Indonesian (Latin)
#   52. Iraqi
#   53. Irish
#   54. Italian
#   55. Japanese
#   56. Japanese (PC-98)
#   57. Kazakh
#   58. Khmer (Cambodia)
#   59. Korean
#   60. Kyrgyz
#   61. Lao
#   62. Latvian
#   63. Lithuanian
#   64. Macedonian
#   65. Malay (Jawi, Arabic Keyboard)
#   66. Maltese
#   67. Maori
#   68. Moldavian
#   69. Mongolian
#   70. Montenegrin
#   71. Nepali
#   72. NKo (AZERTY)
#   73. Norwegian
#   74. Persian
#   75. Polish
#   76. Portuguese
#   77. Portuguese (Brazil)
#   78. Romanian
#   79. Russian
#   80. Serbian
#   81. Sinhala (phonetic)
#   82. Slovak
#   83. Slovenian
#   84. Spanish
#   85. Spanish (Latin American)
#   86. Swahili (Kenya)
#   87. Swahili (Tanzania)
#   88. Swedish
#   89. Switzerland
#   90. Taiwanese
#   91. Tajik
#   92. Thai
#   93. Tswana
#   94. Turkish
#   95. Turkmen
#   96. Ukrainian
#   97. Urdu (Pakistan)
#   98. Uzbek
#   99. Vietnamese
#   100. Wolof
# Country of origin for the keyboard: 32
#
# Please select the layout matching the keyboard for this machine.
#
#   1. English (US)
#   2. English (US) - Cherokee
#   3. English (US) - English (classic Dvorak)
#   4. English (US) - English (Colemak)
#   5. English (US) - English (Colemak-DH)
#   6. English (US) - English (Colemak-DH ISO)
#   7. English (US) - English (Dvorak)
#   8. English (US) - English (Dvorak, alt. intl.)
#   9. English (US) - English (Dvorak, intl., with dead keys)
#   10. English (US) - English (Dvorak, left-handed)
#   11. English (US) - English (Dvorak, right-handed)
#   12. English (US) - English (intl., with AltGr dead keys)
#   13. English (US) - English (Macintosh)
#   14. English (US) - English (Norman)
#   15. English (US) - English (programmer Dvorak)
#   16. English (US) - English (the divide/multiply toggle the layout)
#   17. English (US) - English (US, alt. intl.)
#   18. English (US) - English (US, euro on 5)
#   19. English (US) - English (US, intl., with dead keys)
#   20. English (US) - English (US, Symbolic)
#   21. English (US) - English (Workman)
#   22. English (US) - English (Workman, intl., with dead keys)
#   23. English (US) - Hawaiian
#   24. English (US) - Russian (US, phonetic)
#   25. English (US) - Serbo-Croatian (US)
# Keyboard layout: 1
#
# Your console font configuration will be updated the next time your system
# boots. If you want to update it now, run 'setupcon' from a virtual console.
# Setting up python3-paramiko (2.9.3-0ubuntu1.2) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.10) ...
# Setting up libxfont-dev (1:2.0.5-1build1) ...
# Setting up xserver-xorg-core (2:21.1.4-2ubuntu1.7~22.04.10) ...
# Setting up xserver-xorg-video-dummy (1:0.3.8-2build1) ...
# Setting up xserver-xorg-dev (2:21.1.4-2ubuntu1.7~22.04.10) ...
# Setting up xpra (3.1-1build5) ...
# ....+....+......+........+....+...+............+..+.+...+...........................+............+..+...+......+.+...........+.........+.+.....+....+...+......+..+.......+...+..+.......+...+.....+......+...............+.+..............+.+......+...+......+...+...+............+...........+....+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*....+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*...+.......+.........+...+......+.........+.....+.+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ...............+......+..+.......+.....+.+..+.........+.+...+.....+.........+.+.....+......+.........+..........+..+...+............+....+.....+.............+......+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*....+...+.+......+...............+...+........+...+....+............+...........+...+.+...+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++*....+......+.....+.......+......+............+..+.......+........+.............+.........+...+..+...+......+.+......+...+......+........+......+.+...........+.......+......+......+...........+....+......+.................+......+......+......+.........+.............+......+.....+......+...+.......+...+..+...+...............+...+...+.+..............+..........+..+...+.+.....+..........+......+........+....+...+..+.+......+...+..............................+...+...+......+........+.............+..+......+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# -----
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Processing triggers for shared-mime-info (2.1-2) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Collecting glfw
#   Downloading glfw-2.7.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: glfw
# Successfully installed glfw-2.7.0

# %%
###### mujoco setup ######


#!wget https://mujoco.org/download/mujoco210-linux-x86_64.tar.gz

# !wget https://roboti.us/download/mujoco200_linux.zip

# !wget https://roboti.us/file/mjkey.txt
# Out:
# --2024-05-12 20:44:47--  https://roboti.us/download/mujoco200_linux.zip
# Resolving roboti.us (roboti.us)... 104.40.85.93
# Connecting to roboti.us (roboti.us)|104.40.85.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4427362 (4.2M) [application/zip]
# Saving to: ‘mujoco200_linux.zip’
#
# mujoco200_linux.zip 100%[===================>]   4.22M  22.1MB/s    in 0.2s
#
# 2024-05-12 20:44:48 (22.1 MB/s) - ‘mujoco200_linux.zip’ saved [4427362/4427362]
#
# --2024-05-12 20:44:48--  https://roboti.us/file/mjkey.txt
# Resolving roboti.us (roboti.us)... 104.40.85.93
# Connecting to roboti.us (roboti.us)|104.40.85.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 768 [text/plain]
# Saving to: ‘mjkey.txt’
#
# mjkey.txt           100%[===================>]     768  --.-KB/s    in 0s
#
# 2024-05-12 20:44:48 (68.0 MB/s) - ‘mjkey.txt’ saved [768/768]

# %%
# !mkdir /root/.mujoco

### mujoco 210
#!tar -xf mujoco210-linux-x86_64.tar.gz -C /.mujoco/
#!ls -alh /.mujoco/mujoco210

### mujoco 200
# !unzip mujoco200_linux.zip -d /root/.mujoco/
# !cp -r /root/.mujoco/mujoco200_linux /root/.mujoco/mujoco200

# !mv mjkey.txt /root/.mujoco/

# !cp -r /root/.mujoco/mujoco200/bin/* /usr/lib/
# Out:
# Archive:  mujoco200_linux.zip
#    creating: /root/.mujoco/mujoco200_linux/
#    creating: /root/.mujoco/mujoco200_linux/sample/
#   inflating: /root/.mujoco/mujoco200_linux/sample/mjxmake.m
#   inflating: /root/.mujoco/mujoco200_linux/sample/makefile
#   inflating: /root/.mujoco/mujoco200_linux/sample/mjx.cpp
#   inflating: /root/.mujoco/mujoco200_linux/sample/simulate.cpp
#   inflating: /root/.mujoco/mujoco200_linux/sample/record.cpp
#   inflating: /root/.mujoco/mujoco200_linux/sample/basic.cpp
#   inflating: /root/.mujoco/mujoco200_linux/sample/derivative.cpp
#   inflating: /root/.mujoco/mujoco200_linux/sample/compile.cpp
#   inflating: /root/.mujoco/mujoco200_linux/sample/testspeed.cpp
#   inflating: /root/.mujoco/mujoco200_linux/sample/testxml.cpp
#    creating: /root/.mujoco/mujoco200_linux/model/
#   inflating: /root/.mujoco/mujoco200_linux/model/sponge.png
#   inflating: /root/.mujoco/mujoco200_linux/model/softellipsoid.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/softcylinder.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/softbox.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/scene.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/rope.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/particle.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/marble.png
#   inflating: /root/.mujoco/mujoco200_linux/model/loop.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/grid2pin.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/grid2.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/grid1pin.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/grid1.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/cloth.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/carpet.png
#   inflating: /root/.mujoco/mujoco200_linux/model/hammock.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/humanoid100.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/humanoid.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/arm26.xml
#    creating: /root/.mujoco/mujoco200_linux/include/
#   inflating: /root/.mujoco/mujoco200_linux/include/uitools.h
#   inflating: /root/.mujoco/mujoco200_linux/include/uitools.c
#   inflating: /root/.mujoco/mujoco200_linux/include/mujoco.h
#   inflating: /root/.mujoco/mujoco200_linux/include/mjxmacro.h
#   inflating: /root/.mujoco/mujoco200_linux/include/mjvisualize.h
#   inflating: /root/.mujoco/mujoco200_linux/include/mjui.h
#   inflating: /root/.mujoco/mujoco200_linux/include/mjrender.h
#   inflating: /root/.mujoco/mujoco200_linux/include/mjmodel.h
#   inflating: /root/.mujoco/mujoco200_linux/include/mjdata.h
#   inflating: /root/.mujoco/mujoco200_linux/include/glfw3.h
#    creating: /root/.mujoco/mujoco200_linux/doc/
#   inflating: /root/.mujoco/mujoco200_linux/doc/README.txt
#   inflating: /root/.mujoco/mujoco200_linux/doc/REFERENCE.txt
#    creating: /root/.mujoco/mujoco200_linux/bin/
#   inflating: /root/.mujoco/mujoco200_linux/bin/libmujoco200.so
#   inflating: /root/.mujoco/mujoco200_linux/bin/simulate
#   inflating: /root/.mujoco/mujoco200_linux/bin/record
#   inflating: /root/.mujoco/mujoco200_linux/bin/basic
#   inflating: /root/.mujoco/mujoco200_linux/bin/derivative
#   inflating: /root/.mujoco/mujoco200_linux/bin/compile
#   inflating: /root/.mujoco/mujoco200_linux/bin/testspeed
#   inflating: /root/.mujoco/mujoco200_linux/bin/testxml
#   inflating: /root/.mujoco/mujoco200_linux/bin/libmujoco200nogl.so
#   inflating: /root/.mujoco/mujoco200_linux/bin/libglfw3.a
#   inflating: /root/.mujoco/mujoco200_linux/bin/libglfw.so.3
#   inflating: /root/.mujoco/mujoco200_linux/bin/libglewosmesa.so
#   inflating: /root/.mujoco/mujoco200_linux/bin/libglewegl.so
#   inflating: /root/.mujoco/mujoco200_linux/bin/libglew.so

# %%
# !ls -alh /root/.mujoco/
# Out:
# total 24K
# drwxr-xr-x 4 root root 4.0K May 12 20:44 .
# drwx------ 1 root root 4.0K May 12 20:44 ..
# -rw-r--r-- 1 root root  768 Oct 18  2021 mjkey.txt
# drwxr-xr-x 7 root root 4.0K May 12 20:44 mujoco200
# drwxrwxr-x 7 root root 4.0K Oct  2  2018 mujoco200_linux

# %%
# %env LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin
# Out:
# env: LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin

# %%
###### mujoco-py setup ######

# !pip install mujoco_py==2.0.2.8
# Out:
# Collecting mujoco_py==2.0.2.8
#   Downloading mujoco_py-2.0.2.8-py3-none-any.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: glfw>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (2.7.0)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (1.25.2)
# Requirement already satisfied: Cython>=0.27.2 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (3.0.10)
# Requirement already satisfied: imageio>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (2.31.6)
# Requirement already satisfied: cffi>=1.10 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (1.16.0)
# Collecting fasteners~=0.15 (from mujoco_py==2.0.2.8)
#   Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.10->mujoco_py==2.0.2.8) (2.22)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio>=2.1.2->mujoco_py==2.0.2.8) (9.4.0)
# Installing collected packages: fasteners, mujoco_py
# Successfully installed fasteners-0.19 mujoco_py-2.0.2.8

# %%
###### D4RL setup ######

## !pip uninstall dm_control==0.0.364896371

# !git clone https://github.com/rail-berkeley/d4rl.git

### edit dm_control version in d4rl setup.py
# !sed -i "s;dm_control @ git+git://github.com/deepmind/dm_control@master#egg=dm_control;dm_control==0.0.364896371;g" /content/d4rl/setup.py

### edit mjrl install in d4rl setup.py to use github's new https protocol instead of git SSH
# !sed -i "s;mjrl @ git+git://github.com/aravindr93/mjrl@master#egg=mjrl;mjrl @ git+https://github.com/aravindr93/mjrl@master#egg=mjrl;g" /content/d4rl/setup.py

# !pip install -e d4rl/.
# Out:
# Cloning into 'd4rl'...
# remote: Enumerating objects: 1373, done.
# remote: Counting objects: 100% (1373/1373), done.
# remote: Compressing objects: 100% (691/691), done.
# remote: Total 1373 (delta 710), reused 1115 (delta 671), pack-reused 0
# Receiving objects: 100% (1373/1373), 28.54 MiB | 32.05 MiB/s, done.
# Resolving deltas: 100% (710/710), done.
# Obtaining file:///content/d4rl
#   Preparing metadata (setup.py) ... done
# Collecting mjrl@ git+https://github.com/aravindr93/mjrl@master#egg=mjrl (from D4RL==1.1)
#   Cloning https://github.com/aravindr93/mjrl (to revision master) to /tmp/pip-install-50novtx6/mjrl_af724101dee240ff9ec344f36c9cb7bb
#   Running command git clone --filter=blob:none --quiet https://github.com/aravindr93/mjrl /tmp/pip-install-50novtx6/mjrl_af724101dee240ff9ec344f36c9cb7bb
#   Resolved https://github.com/aravindr93/mjrl to commit 3871d93763d3b49c4741e6daeaebbc605fe140dc
#   Preparing metadata (setup.py) ... done
# Collecting gym<0.24.0 (from D4RL==1.1)
#   Downloading gym-0.23.1.tar.gz (626 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.2/626.2 kB 5.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (1.25.2)
# Requirement already satisfied: mujoco_py in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (2.0.2.8)
# Collecting pybullet (from D4RL==1.1)
#   Downloading pybullet-3.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (103.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 MB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (3.9.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (2.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (8.1.7)
# Collecting dm_control>=1.0.3 (from D4RL==1.1)
#   Downloading dm_control-1.0.19-py3-none-any.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (1.4.0)
# Collecting dm-env (from dm_control>=1.0.3->D4RL==1.1)
#   Downloading dm_env-1.6-py3-none-any.whl (26 kB)
# Requirement already satisfied: dm-tree!=0.1.2 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (0.1.8)
# Requirement already satisfied: glfw in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (2.7.0)
# Collecting labmaze (from dm_control>=1.0.3->D4RL==1.1)
#   Downloading labmaze-1.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 101.5 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (4.9.4)
# Collecting mujoco>=3.1.5 (from dm_control>=1.0.3->D4RL==1.1)
#   Downloading mujoco-3.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 102.8 MB/s eta 0:00:00
# Requirement already satisfied: protobuf>=3.19.4 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (3.20.3)
# Requirement already satisfied: pyopengl>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (3.1.7)
# Requirement already satisfied: pyparsing>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (3.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (2.31.0)
# Requirement already satisfied: setuptools!=50.0.0 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (67.7.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (1.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (4.66.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym<0.24.0->D4RL==1.1) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym<0.24.0->D4RL==1.1) (0.0.8)
# Requirement already satisfied: Cython>=0.27.2 in /usr/local/lib/python3.10/dist-packages (from mujoco_py->D4RL==1.1) (3.0.10)
# Requirement already satisfied: imageio>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from mujoco_py->D4RL==1.1) (2.31.6)
# Requirement already satisfied: cffi>=1.10 in /usr/local/lib/python3.10/dist-packages (from mujoco_py->D4RL==1.1) (1.16.0)
# Requirement already satisfied: fasteners~=0.15 in /usr/local/lib/python3.10/dist-packages (from mujoco_py->D4RL==1.1) (0.19)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.10->mujoco_py->D4RL==1.1) (2.22)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio>=2.1.2->mujoco_py->D4RL==1.1) (9.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.10/dist-packages (from mujoco>=3.1.5->dm_control>=1.0.3->D4RL==1.1) (1.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dm_control>=1.0.3->D4RL==1.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dm_control>=1.0.3->D4RL==1.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dm_control>=1.0.3->D4RL==1.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dm_control>=1.0.3->D4RL==1.1) (2024.2.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=3.1.5->dm_control>=1.0.3->D4RL==1.1) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=3.1.5->dm_control>=1.0.3->D4RL==1.1) (6.4.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=3.1.5->dm_control>=1.0.3->D4RL==1.1) (4.11.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=3.1.5->dm_control>=1.0.3->D4RL==1.1) (3.18.1)
# Building wheels for collected packages: gym, mjrl
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.23.1-py3-none-any.whl size=701345 sha256=1e91edfd141e40e10e6d4a27eaee02842f67ec9132cff48b188d215f750ed7d3
#   Stored in directory: /root/.cache/pip/wheels/1a/00/fb/fe5cf2860fb9b7bc860e28f00095a1f42c7b726dd6f42d1acc
#   Building wheel for mjrl (setup.py) ... done
#   Created wheel for mjrl: filename=mjrl-1.0.0-py3-none-any.whl size=61936 sha256=7494eb6faa0de693d54960a78cac4fffa2f1c9082c94dfad8764cbd906d17902
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7i6y4ms5/wheels/8f/99/f9/efd223b38d503df5eaada10ffe96a869fb0c0f3c92d9e43ed0
# Successfully built gym mjrl
# Installing collected packages: pybullet, mjrl, labmaze, gym, dm-env, mujoco, dm_control, D4RL
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
#   Running setup.py develop for D4RL
# Successfully installed D4RL-1.1 dm-env-1.6 dm_control-1.0.19 gym-0.23.1 labmaze-1.0.6 mjrl-1.0.0 mujoco-3.1.5 pybullet-3.2.6

# %%
###### restart runtime ######

exit()

# %%
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install -U colabgymrender
# Out:
# Collecting colabgymrender
#   Downloading colabgymrender-1.1.0.tar.gz (3.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (from colabgymrender) (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender) (4.66.4)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender) (1.25.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender) (2.31.6)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender) (0.4.9)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio<3.0,>=2.5->moviepy->colabgymrender) (9.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg>=0.2.0->moviepy->colabgymrender) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender) (2024.2.2)
# Building wheels for collected packages: colabgymrender
#   Building wheel for colabgymrender (setup.py) ... done
#   Created wheel for colabgymrender: filename=colabgymrender-1.1.0-py3-none-any.whl size=3114 sha256=199ff4a8799956abd2e89935a4a0f47f6753a6b2b6767c5de40e459bd0c03815
#   Stored in directory: /root/.cache/pip/wheels/13/62/63/7b3acfb684dd3d665d7fc1d213427b136205a222389767e295
# Successfully built colabgymrender
# Installing collected packages: colabgymrender
# Successfully installed colabgymrender-1.1.0

# %%
# !pip install pytorch_lightning
# !pip install einops
# Out:
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.2.4-py3-none-any.whl (802 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.2/802.2 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.25.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2.2.1+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2023.6.0)
# Collecting torchmetrics>=0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.4.0-py3-none-any.whl (868 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (24.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.11.0)
# Collecting lightning-utilities>=0.8.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.11.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.9.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->pytorch_lightning) (67.7.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (3.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.13.0->pytorch_lightning)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.13.0->pytorch_lightning)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.13.0->pytorch_lightning)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.13.0->pytorch_lightning)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.13.0->pytorch_lightning)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.13.0->pytorch_lightning)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.13.0->pytorch_lightning)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.13.0->pytorch_lightning)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.13.0->pytorch_lightning)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.13.0->pytorch_lightning)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.13.0->pytorch_lightning)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->pytorch_lightning)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Collecting pretty-errors==1.2.25 (from torchmetrics>=0.7.0->pytorch_lightning)
#   Downloading pretty_errors-1.2.25-py3-none-any.whl (17 kB)
# Collecting colorama (from pretty-errors==1.2.25->torchmetrics>=0.7.0->pytorch_lightning)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->pytorch_lightning) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->pytorch_lightning) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, colorama, pretty-errors, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchmetrics, pytorch_lightning
# Successfully installed colorama-0.4.6 lightning-utilities-0.11.2 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 pretty-errors-1.2.25 pytorch_lightning-2.2.4 torchmetrics-1.4.0
# Collecting einops
#   Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.8.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install imageio==2.4.1

# %% [markdown]
# # check mujoco-py and D4RL installation
#
# * if check fails then **Restart Runtime** again
# * if check still fails then Factory reset runtime and install again
# * After installing, first import will be slow as the lib will be built again

# %%
# !pip install Cython==3.0.0a10
# Out:
# Collecting Cython==3.0.0a10
#   Downloading Cython-3.0.0a10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 9.5 MB/s eta 0:00:00
# Installing collected packages: Cython
#   Attempting uninstall: Cython
#     Found existing installation: Cython 3.0.10
#     Uninstalling Cython-3.0.10:
#       Successfully uninstalled Cython-3.0.10
# Successfully installed Cython-3.0.0a10

# %%
# set mujoco env path if not already set
# %env LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin

import gym
import d4rl # Import required to register environments


env = gym.make('Walker2d-v3')
env.reset()
env.step(env.action_space.sample())
env.close()
print("mujoco-py check passed")

# env = gym.make('walker2d-medium-v2')
# env.reset()
# env.step(env.action_space.sample())
# env.close()
# print("d4rl check passed")
# Out:
# env: LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin
# Compiling /usr/local/lib/python3.10/dist-packages/mujoco_py/cymj.pyx because it depends on /usr/local/lib/python3.10/dist-packages/Cython/Includes/cpython/type.pxd.
# [1/1] Cythonizing /usr/local/lib/python3.10/dist-packages/mujoco_py/cymj.pyx
# warning: /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/wrappers.pxi:4:0: Dotted filenames ('../pxd/mujoco.pxd') are deprecated. Please use the normal Python package directory layout.
# INFO:root:running build_ext
# INFO:root:building 'mujoco_py.cymj' extension
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.8_310_linuxcpuextensionbuilder
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.8_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.8_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.8_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.8_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.8_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib/python3.10
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.8_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib/python3.10/dist-packages
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.8_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib/python3.10/dist-packages/mujoco_py
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.8_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib/python3.10/dist-packages/mujoco_py/gl
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.10/dist-packages/mujoco_py -I/root/.mujoco/mujoco200/include -I/usr/local/lib/python3.10/dist-packages/numpy/core/include -I/usr/include/python3.10 -c /usr/local/lib/python3.10/dist-packages/mujoco_py/cymj.c -o /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.8_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib/python3.10/dist-packages/mujoco_py/cymj.o -fopenmp -w
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.10/dist-packages/mujoco_py -I/root/.mujoco/mujoco200/include -I/usr/local/lib/python3.10/dist-packages/numpy/core/include -I/usr/include/python3.10 -c /usr/local/lib/python3.10/dist-packages/mujoco_py/gl/osmesashim.c -o /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.8_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib/python3.10/dist-packages/mujoco_py/gl/osmesashim.o -fopenmp -w
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.8_310_linuxcpuextensionbuilder/lib.linux-x86_64-cpython-310
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.8_310_linuxcpuextensionbuilder/lib.linux-x86_64-cpython-310/mujoco_py
# INFO:root:x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.8_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib/python3.10/dist-packages/mujoco_py/cymj.o /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.8_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib/python3.10/dist-packages/mujoco_py/gl/osmesashim.o -L/root/.mujoco/mujoco200/bin -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/root/.mujoco/mujoco200/bin -lmujoco200 -lglewosmesa -lOSMesa -lGL -o /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.8_310_linuxcpuextensionbuilder/lib.linux-x86_64-cpython-310/mujoco_py/cymj.cpython-310-x86_64-linux-gnu.so -fopenmp
# <frozen importlib._bootstrap>:283: DeprecationWarning: the load_module() method is deprecated and slated for removal in Python 3.12; use exec_module() instead
# mujoco-py check passed

# %% [markdown]
# # import libs

# %%
# set mujoco env path if not already set
# %env LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin

import os
import sys
import random
import csv
from datetime import datetime
import pickle
import collections
import math

import numpy as np
import gym
from typing import Optional, Mapping, Tuple, Union


import logging

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import torchvision
import torchvision.transforms as transforms

# import networkx as nx
# import walker
import gym
from gym.envs.registration import registry, register

from pytorch_lightning.utilities import rank_zero_only
from einops import rearrange, repeat


contract = torch.einsum
# Out:
# env: LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/__init__.py:41: Deprecated call to `pkg_resources.declare_namespace('lightning_fabric')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/__init__.py:37: Deprecated call to `pkg_resources.declare_namespace('pytorch_lightning')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from datetime import datetime
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/MyDrive/6_8200_project/S4')


from models.s4.s4 import S4Block as S4  # Can use full version instead of minimal S4D standalone below
from models.s4.s4d import S4D
from tqdm.auto import tqdm
# Out:
# WARNING:models.s4.s4:CUDA extension for structured kernels (Cauchy and Vandermonde multiplication) not found. Install by going to extensions/kernels/ and running `python setup.py install`, for improved speed and memory efficiency. Note that the kernel changed for state-spaces 4.0 and must be recompiled.
# WARNING:models.s4.s4:Falling back on slow Cauchy and Vandermonde kernel. Install at least one of pykeops or the CUDA extension for better speed and memory efficiency.

# %% [markdown]
# # S4 model

# %%
def split_train_val(train, val_split):
    train_len = int(len(train) * (1.0-val_split))
    train, val = torch.utils.data.random_split(
        train,
        (train_len, len(train) - train_len),
        generator=torch.Generator().manual_seed(42),
    )
    return train, val


class S4Model(nn.Module):

    def __init__(
        self,
        state_dim, # d_input?
        act_dim, #d_output=10,
        h_dim, # d_model=256?
        context_len,
        dropout=0.2,
        n_layers=4,
        max_timestep=4096,
        prenorm=False,

        # d_output=10,
        # # d_model=256,
        # n_layers=4,

    ):
        super().__init__()

        self.prenorm = prenorm

        self.state_dim = state_dim
        self.act_dim = act_dim
        self.h_dim = h_dim

        ### projection heads (project to embedding)
        self.embed_ln = nn.LayerNorm(h_dim)
        self.embed_timestep = nn.Embedding(max_timestep, h_dim)
        self.embed_rtg = torch.nn.Linear(1, h_dim)
        self.embed_state = torch.nn.Linear(state_dim, h_dim)

        # continuous actions
        self.embed_action = torch.nn.Linear(act_dim, h_dim)
        use_action_tanh = True # True for continuous actions

        # Linear encoder (d_input = 1 for grayscale and 3 for RGB)
        # self.encoder = nn.Linear(d_input, d_model)

        # Stack S4 layers as residual blocks
        self.s4_layers = nn.ModuleList()
        self.norms = nn.ModuleList()
        self.dropouts = nn.ModuleList()
        for _ in range(n_layers):
            self.s4_layers.append(
                S4D(h_dim, dropout=dropout, transposed=True, lr=min(0.001, lr))
            )
            self.norms.append(nn.LayerNorm(h_dim))
            self.dropouts.append(dropout_fn(dropout))

        # # Linear decoder
        # self.decoder = nn.Linear(h_dim, act_dim)

        ### prediction heads
        self.predict_rtg = torch.nn.Linear(h_dim, 1)
        self.predict_state = torch.nn.Linear(h_dim, state_dim)
        self.predict_action = nn.Sequential(
            *([nn.Linear(h_dim, act_dim)] + ([nn.Tanh()] if use_action_tanh else []))
        )

    def forward(self, timesteps, states, actions, returns_to_go): # timesteps, states, actions, returns_to_go
        """
        Input x is shape (B, L, d_input)
        """
        B, T, _ = states.shape

        time_embeddings = self.embed_timestep(timesteps) # (B, L, d_input) -> max_timestep, (h_dim)?

        # time embeddings are treated similar to positional embeddings
        state_embeddings = self.embed_state(states) + time_embeddings # (h_dim)
        action_embeddings = self.embed_action(actions) + time_embeddings # (h_dim)
        returns_embeddings = self.embed_rtg(returns_to_go) + time_embeddings # (h_dim)

        # stack rtg, states and actions and reshape sequence as
        # (r1, s1, a1, r2, s2, a2 ...)
        h = torch.stack(
            (returns_embeddings, state_embeddings, action_embeddings), dim=1
        ).permute(0, 2, 1, 3).reshape(B, 3 * T, self.h_dim)

        h = self.embed_ln(h) # (B x 3*T x h_dim)
        # print("H shape before S4", h.shape) # H shape before S4 torch.Size([64, 3000, 128])

        # x = self.encoder(x)  # (B, L, d_input) -> (B, L, d_model)

        x = h.transpose(-1, -2)  # (B, L, d_model) -> (B, d_model, L)


        for layer, norm, dropout in zip(self.s4_layers, self.norms, self.dropouts):
            # Each iteration of this loop will map (B, d_model, L) -> (B, d_model, L)

            z = x
            if self.prenorm:
                # Prenorm
                z = norm(z.transpose(-1, -2)).transpose(-1, -2)

            # Apply S4 block: we ignore the state input and output
            z, _ = layer(z)

            # Dropout on the output of the S4 block
            z = dropout(z)

            # Residual connection
            x = z + x

            if not self.prenorm:
                # Postnorm
                x = norm(x.transpose(-1, -2)).transpose(-1, -2)

        x = x.transpose(-1, -2)

        # Pooling: average pooling over the sequence length
        # print("x (H) shape after S4", x.shape)

        # x = x.mean(dim=1)

        # print("x (H) shape after mean", x.shape)

        # Decode the outputs
        # x = self.decoder(x)  # (B, d_model) -> (B, d_output)

        # get h reshaped such that its size = (B x 3*T x h_dim) and
        # h[:, 0, t] is conditioned on r_0, s_0, a_0 ... r_t
        # h[:, 1, t] is conditioned on r_0, s_0, a_0 ... r_t, s_t
        # h[:, 2, t] is conditioned on r_0, s_0, a_0 ... r_t, s_t, a_t
        h = h.reshape(B, T, 3, self.h_dim).permute(0, 2, 1, 3)

        # get predictions
        return_preds = self.predict_rtg(h[:,2])     # predict next rtg given r, s, a
        state_preds = self.predict_state(h[:,2])    # predict next state given r, s, a
        action_preds = self.predict_action(h[:,1])  # predict action given r, s

        return state_preds, action_preds, return_preds



def setup_optimizer(model, lr, weight_decay, epochs):
    """
    S4 requires a specific optimizer setup.

    The S4 layer (A, B, C, dt) parameters typically
    require a smaller learning rate (typically 0.001), with no weight decay.

    The rest of the model can be trained with a higher learning rate (e.g. 0.004, 0.01)
    and weight decay (if desired).
    """

    # All parameters in the model
    all_parameters = list(model.parameters())

    # General parameters don't contain the special _optim key
    params = [p for p in all_parameters if not hasattr(p, "_optim")]

    # Create an optimizer with the general parameters
    optimizer = optim.AdamW(params, lr=lr, weight_decay=weight_decay)

    # Add parameters with special hyperparameters
    hps = [getattr(p, "_optim") for p in all_parameters if hasattr(p, "_optim")]
    hps = [
        dict(s) for s in sorted(list(dict.fromkeys(frozenset(hp.items()) for hp in hps)))
    ]  # Unique dicts
    for hp in hps:
        params = [p for p in all_parameters if getattr(p, "_optim", None) == hp]
        optimizer.add_param_group(
            {"params": params, **hp}
        )

    # Create a lr scheduler
    # scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=patience, factor=0.2)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, epochs)

    # Print optimizer info
    keys = sorted(set([k for hp in hps for k in hp.keys()]))
    for i, g in enumerate(optimizer.param_groups):
        group_hps = {k: g.get(k, None) for k in keys}
        print(' | '.join([
            f"Optimizer group {i}",
            f"{len(g['params'])} tensors",
        ] + [f"{k} {v}" for k, v in group_hps.items()]))

    return optimizer, scheduler
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
###############################################################################
# Everything after this point is standard PyTorch training!
###############################################################################

# Training
def train():
    model.train()
    train_loss = 0
    correct = 0
    total = 0
    log_action_losses = []
    pbar = tqdm(enumerate(traj_data_loader))
    for batch_idx, (timesteps, states, actions, returns_to_go, traj_mask) in pbar:
        # inputs, targets = inputs.to(device), targets.to(device)
        # optimizer.zero_grad()
        timesteps = timesteps.to(device)	# B x T
        states = states.to(device)			# B x T x state_dim
        actions = actions.to(device)		# B x T x act_dim
        returns_to_go = returns_to_go.to(device).unsqueeze(dim=-1) # B x T x 1
        traj_mask = traj_mask.to(device)	# B x T
        action_target = torch.clone(actions).detach().to(device)
        state_preds, action_preds, return_preds = model.forward(
														timesteps=timesteps,
														states=states,
														actions=actions,
														returns_to_go=returns_to_go
													)

        action_preds = action_preds.view(-1, act_dim)[traj_mask.view(-1,) > 0]
        action_target = action_target.view(-1, act_dim)[traj_mask.view(-1,) > 0]

        # outputs = model(timesteps, states, actions, returns_to_go, traj_mask)
        # action_loss = criterion(action_preds, action_target)

        action_loss = F.mse_loss(action_preds, action_target, reduction='mean')

        action_loss.backward()
        optimizer.step()

        # train_loss += loss.item()
        # _, predicted = outputs.max(1)
        # total += targets.size(0)
        # correct += predicted.eq(targets).sum().item()

        log_action_losses.append(action_loss.detach().cpu().item())

        pbar.set_description(
            'Batch Idx: (%d/%d) | Loss: %.3f' %
            (batch_idx, len(traj_data_loader), log_action_losses[-1])
        )

def evaluate_on_env(model, device, context_len, env, rtg_target, rtg_scale,
                    num_eval_ep=10, max_test_ep_len=1000,
                    state_mean=None, state_std=None, render=False):

    eval_batch_size = 1  # required for forward pass

    results = {}
    total_reward = 0
    total_timesteps = 0

    state_dim = env.observation_space.shape[0]
    act_dim = env.action_space.shape[0]

    if state_mean is None:
        state_mean = torch.zeros((state_dim,)).to(device)
    else:
        state_mean = torch.from_numpy(state_mean).to(device)

    if state_std is None:
        state_std = torch.ones((state_dim,)).to(device)
    else:
        state_std = torch.from_numpy(state_std).to(device)

    # same as timesteps used for training the transformer
    # also, crashes if device is passed to arange()
    timesteps = torch.arange(start=0, end=max_test_ep_len, step=1)
    timesteps = timesteps.repeat(eval_batch_size, 1).to(device)

    model.eval()

    with torch.no_grad():

        for _ in range(num_eval_ep):

            # zeros place holders
            actions = torch.zeros((eval_batch_size, max_test_ep_len, act_dim),
                                dtype=torch.float32, device=device)

            states = torch.zeros((eval_batch_size, max_test_ep_len, state_dim),
                                dtype=torch.float32, device=device)

            rewards_to_go = torch.zeros((eval_batch_size, max_test_ep_len, 1),
                                dtype=torch.float32, device=device)

            # init episode
            running_state = env.reset()
            running_reward = 0
            running_rtg = rtg_target / rtg_scale

            for t in range(max_test_ep_len):

                total_timesteps += 1

                # add state in placeholder and normalize
                states[0, t] = torch.from_numpy(running_state).to(device)
                states[0, t] = (states[0, t] - state_mean) / state_std

                # calcualate running rtg and add in placeholder
                running_rtg = running_rtg - (running_reward / rtg_scale)
                rewards_to_go[0, t] = running_rtg

                if t < context_len:
                    _, act_preds, _ = model.forward(timesteps[:,:context_len],
                                                states[:,:context_len],
                                                actions[:,:context_len],
                                                rewards_to_go[:,:context_len])
                    act = act_preds[0, t].detach()
                else:
                    _, act_preds, _ = model.forward(timesteps[:,t-context_len+1:t+1],
                                                states[:,t-context_len+1:t+1],
                                                actions[:,t-context_len+1:t+1],
                                                rewards_to_go[:,t-context_len+1:t+1])
                    act = act_preds[0, -1].detach()


                running_state, running_reward, done, _ = env.step(act.cpu().numpy())

                # add action in placeholder
                actions[0, t] = act

                total_reward += running_reward

                if render:
                    env.render()
                if done:
                    break

    results['eval/avg_reward'] = total_reward / num_eval_ep
    results['eval/avg_ep_len'] = total_timesteps / num_eval_ep

    return results

def eval(epoch, dataloader, checkpoint=False):
    global best_acc
    model.eval()
    eval_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        pbar = tqdm(enumerate(dataloader))
        for batch_idx, (inputs, targets) in pbar:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)

            eval_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

            log_data = [batch_idx, len(dataloader), eval_loss/(batch_idx+1), 100.*correct/total, correct, total]
            csv_writer.writerow(log_data)

            # pbar.set_description(
            #     'Batch Idx: (%d/%d) | Loss: %.3f | Acc: %.3f%% (%d/%d)' %
            #     (batch_idx, len(dataloader), eval_loss/(batch_idx+1), 100.*correct/total, correct, total)
            # )

    # Save checkpoint.
    if checkpoint:
        acc = 100.*correct/total
        if acc > best_acc:
            state = {
                'model': model.state_dict(),
                'acc': acc,
                'epoch': epoch,
            }
            if not os.path.isdir('/content/drive/MyDrive/6_8200_project/S4/checkpoint'):
                os.mkdir('/content/drive/MyDrive/6_8200_project/S4/checkpoint')
            torch.save(state, '/content/drive/MyDrive/6_8200_project/S4/checkpoint/hopper_ckpt.pth')
            best_acc = acc

        return acc

# %%
if tuple(map(int, torch.__version__.split('.')[:2])) == (1, 11):
    print("WARNING: Dropout is bugged in PyTorch 1.11. Results may be worse.")
    dropout_fn = nn.Dropout
if tuple(map(int, torch.__version__.split('.')[:2])) >= (1, 12):
    dropout_fn = nn.Dropout1d
else:
    dropout_fn = nn.Dropout2d

# %% [markdown]
# # D4RL_DATASET_STATS

# %%
## from infos.py from official d4rl github repo

REF_MAX_SCORE = {
    'halfcheetah' : 12135.0,
    'walker2d' : 4592.3,
    'hopper' : 3234.3,
}

REF_MIN_SCORE = {
    'halfcheetah' : -280.178953,
    'walker2d' : 1.629008,
    'hopper' : -20.272305,
}


## calculated from d4rl datasets

D4RL_DATASET_STATS = {
        'halfcheetah-medium-v2': {
                'state_mean':[-0.06845773756504059, 0.016414547339081764, -0.18354906141757965,
                              -0.2762460708618164, -0.34061527252197266, -0.09339715540409088,
                              -0.21321271359920502, -0.0877423882484436, 5.173007488250732,
                              -0.04275195300579071, -0.036108363419771194, 0.14053793251514435,
                              0.060498327016830444, 0.09550975263118744, 0.06739100068807602,
                              0.005627387668937445, 0.013382787816226482
                ],
                'state_std':[0.07472999393939972, 0.3023499846458435, 0.30207309126853943,
                             0.34417077898979187, 0.17619241774082184, 0.507205605506897,
                             0.2567007839679718, 0.3294812738895416, 1.2574149370193481,
                             0.7600541710853577, 1.9800915718078613, 6.565362453460693,
                             7.466367721557617, 4.472222805023193, 10.566964149475098,
                             5.671932697296143, 7.4982590675354
                ]
            },
        'halfcheetah-medium-replay-v2': {
                'state_mean':[-0.12880703806877136, 0.3738119602203369, -0.14995987713336945,
                              -0.23479078710079193, -0.2841278612613678, -0.13096535205841064,
                              -0.20157982409000397, -0.06517726927995682, 3.4768247604370117,
                              -0.02785065770149231, -0.015035249292850494, 0.07697279006242752,
                              0.01266712136566639, 0.027325302362442017, 0.02316424623131752,
                              0.010438721626996994, -0.015839405357837677
                ],
                'state_std':[0.17019015550613403, 1.284424901008606, 0.33442774415016174,
                             0.3672759234905243, 0.26092398166656494, 0.4784106910228729,
                             0.3181420564651489, 0.33552637696266174, 2.0931615829467773,
                             0.8037433624267578, 1.9044333696365356, 6.573209762573242,
                             7.572863578796387, 5.069749355316162, 9.10555362701416,
                             6.085654258728027, 7.25300407409668
                ]
            },
        'halfcheetah-medium-expert-v2': {
                'state_mean':[-0.05667462572455406, 0.024369969964027405, -0.061670560389757156,
                              -0.22351515293121338, -0.2675151228904724, -0.07545716315507889,
                              -0.05809682980179787, -0.027675075456500053, 8.110626220703125,
                              -0.06136331334710121, -0.17986927926540375, 0.25175222754478455,
                              0.24186332523822784, 0.2519369423389435, 0.5879552960395813,
                              -0.24090635776519775, -0.030184272676706314
                ],
                'state_std':[0.06103534251451492, 0.36054104566574097, 0.45544400811195374,
                             0.38476887345314026, 0.2218363732099533, 0.5667523741722107,
                             0.3196682929992676, 0.2852923572063446, 3.443821907043457,
                             0.6728139519691467, 1.8616976737976074, 9.575807571411133,
                             10.029894828796387, 5.903450012207031, 12.128185272216797,
                             6.4811787605285645, 6.378620147705078
                ]
            },
        'walker2d-medium-v2': {
                'state_mean':[1.218966007232666, 0.14163373410701752, -0.03704913705587387,
                              -0.13814310729503632, 0.5138224363327026, -0.04719110205769539,
                              -0.47288352251052856, 0.042254164814949036, 2.3948874473571777,
                              -0.03143199160695076, 0.04466355964541435, -0.023907244205474854,
                              -0.1013401448726654, 0.09090937674045563, -0.004192637279629707,
                              -0.12120571732521057, -0.5497063994407654
                ],
                'state_std':[0.12311358004808426, 0.3241879940032959, 0.11456084251403809,
                             0.2623065710067749, 0.5640279054641724, 0.2271878570318222,
                             0.3837319612503052, 0.7373676896095276, 1.2387926578521729,
                             0.798020601272583, 1.5664079189300537, 1.8092705011367798,
                             3.025604248046875, 4.062486171722412, 1.4586567878723145,
                             3.7445690631866455, 5.5851287841796875
                ]
            },
        'walker2d-medium-replay-v2': {
                'state_mean':[1.209364652633667, 0.13264022767543793, -0.14371201395988464,
                              -0.2046516090631485, 0.5577612519264221, -0.03231537342071533,
                              -0.2784661054611206, 0.19130706787109375, 1.4701707363128662,
                              -0.12504704296588898, 0.0564953051507473, -0.09991033375263214,
                              -0.340340256690979, 0.03546293452382088, -0.08934258669614792,
                              -0.2992438077926636, -0.5984178185462952
                ],
                'state_std':[0.11929835379123688, 0.3562574088573456, 0.25852200388908386,
                             0.42075422406196594, 0.5202291011810303, 0.15685082972049713,
                             0.36770978569984436, 0.7161387801170349, 1.3763766288757324,
                             0.8632221817970276, 2.6364643573760986, 3.0134117603302,
                             3.720684051513672, 4.867283821105957, 2.6681625843048096,
                             3.845186948776245, 5.4768385887146
                ]
            },
        'walker2d-medium-expert-v2': {
                'state_mean':[1.2294334173202515, 0.16869689524173737, -0.07089081406593323,
                              -0.16197483241558075, 0.37101927399635315, -0.012209027074277401,
                              -0.42461398243904114, 0.18986578285694122, 3.162475109100342,
                              -0.018092676997184753, 0.03496946766972542, -0.013921679928898811,
                              -0.05937029421329498, -0.19549426436424255, -0.0019200450042262673,
                              -0.062483321875333786, -0.27366524934768677
                ],
                'state_std':[0.09932824969291687, 0.25981399416923523, 0.15062759816646576,
                             0.24249176681041718, 0.6758718490600586, 0.1650741547346115,
                             0.38140663504600525, 0.6962361335754395, 1.3501490354537964,
                             0.7641991376876831, 1.534574270248413, 2.1785972118377686,
                             3.276582717895508, 4.766193866729736, 1.1716983318328857,
                             4.039782524108887, 5.891613960266113
                ]
            },
        'hopper-medium-v2': {
                'state_mean':[1.311279058456421, -0.08469521254301071, -0.5382719039916992,
                              -0.07201576232910156, 0.04932365566492081, 2.1066856384277344,
                              -0.15017354488372803, 0.008783451281487942, -0.2848185896873474,
                              -0.18540096282958984, -0.28461286425590515
                ],
                'state_std':[0.17790751159191132, 0.05444620922207832, 0.21297138929367065,
                             0.14530418813228607, 0.6124444007873535, 0.8517446517944336,
                             1.4515252113342285, 0.6751695871353149, 1.5362390279769897,
                             1.616074562072754, 5.607253551483154
                ]
            },
        'hopper-medium-replay-v2': {
                'state_mean':[1.2305138111114502, -0.04371410980820656, -0.44542956352233887,
                              -0.09370097517967224, 0.09094487875699997, 1.3694725036621094,
                              -0.19992674887180328, -0.022861352190375328, -0.5287045240402222,
                              -0.14465883374214172, -0.19652697443962097
                ],
                'state_std':[0.1756512075662613, 0.0636928603053093, 0.3438323438167572,
                             0.19566889107227325, 0.5547984838485718, 1.051029920578003,
                             1.158307671546936, 0.7963128685951233, 1.4802359342575073,
                             1.6540331840515137, 5.108601093292236
                ]
            },
        'hopper-medium-expert-v2': {
                'state_mean':[1.3293815851211548, -0.09836531430482864, -0.5444297790527344,
                              -0.10201650857925415, 0.02277466468513012, 2.3577215671539307,
                              -0.06349576264619827, -0.00374026270583272, -0.1766270101070404,
                              -0.11862941086292267, -0.12097819894552231
                ],
                'state_std':[0.17012375593185425, 0.05159067362546921, 0.18141433596611023,
                             0.16430604457855225, 0.6023368239402771, 0.7737284898757935,
                             1.4986555576324463, 0.7483318448066711, 1.7953159809112549,
                             2.0530025959014893, 5.725032806396484
                ]
            },
    }

# %%
def get_d4rl_normalized_score(score, env_name):
    env_key = env_name.split('-')[0].lower()
    assert env_key in REF_MAX_SCORE, f'no reference score for {env_key} env to calculate d4rl score'
    return (score - REF_MIN_SCORE[env_key]) / (REF_MAX_SCORE[env_key] - REF_MIN_SCORE[env_key])

# %%
dataset = "medium"       # medium / medium-replay / medium-expert
rtg_scale = 1000                # scale to normalize returns to go

dataset_path = f'/content/drive/MyDrive/6_8200_project/S4/data/hopper-medium-v2.pkl'

env_name = 'Hopper-v3'
rtg_target = 5000
env_s4_name = f'hopper-{dataset}-v2'

log_dir = "/content/drive/MyDrive/6_8200_project/S4/s4_runs/"
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

device_name = 'cuda'
device = torch.device(device_name)
print("device set to: ", device)
# Out:
# device set to:  cuda

# %% [markdown]
# # TrajectoryLoader for RL loop

# %%
def discount_cumsum(x, gamma):
    disc_cumsum = np.zeros_like(x)
    disc_cumsum[-1] = x[-1]
    for t in reversed(range(x.shape[0]-1)):
        disc_cumsum[t] = x[t] + gamma * disc_cumsum[t+1]
    return disc_cumsum

class D4RLTrajectoryDataset(Dataset):
    def __init__(self, dataset_path, rtg_scale=1000):


        # load dataset
        with open(dataset_path, 'rb') as f:
            self.trajectories = pickle.load(f)

        # calculate min len of traj, state mean and variance
        # and returns_to_go for all traj
        max_len = -10**6
        states = []
        for traj in self.trajectories:
            traj_len = traj['observations'].shape[0]
            max_len = max(max_len, traj_len)
            states.append(traj['observations'])
            # calculate returns to go and rescale them
            traj['returns_to_go'] = discount_cumsum(traj['rewards'], 1.0) / rtg_scale

        self.context_len = max_len
        # used for input normalization
        states = np.concatenate(states, axis=0)
        self.state_mean, self.state_std = np.mean(states, axis=0), np.std(states, axis=0) + 1e-6

        # normalize states
        for traj in self.trajectories:
            traj['observations'] = (traj['observations'] - self.state_mean) / self.state_std


    def get_state_stats(self):
        return self.state_mean, self.state_std

    def __len__(self):
        return len(self.trajectories)

    def __getitem__(self, idx):
        traj = self.trajectories[idx]
        traj_len = traj['observations'].shape[0]
        traj_len = traj['observations'].shape[0]

        if traj_len >= self.context_len:
            # sample random index to slice trajectory
            si = random.randint(0, traj_len - self.context_len)

            states = torch.from_numpy(traj['observations'][si : si + self.context_len])
            actions = torch.from_numpy(traj['actions'][si : si + self.context_len])
            returns_to_go = torch.from_numpy(traj['returns_to_go'][si : si + self.context_len])
            timesteps = torch.arange(start=si, end=si+self.context_len, step=1)

            # all ones since no padding
            traj_mask = torch.ones(self.context_len, dtype=torch.long)

        else:

            padding_len = self.context_len - traj_len
            # print("padding len", padding_len)
            # print("self.context_len len", self.context_len)
            # print("traj_len len", traj_len)
            # padding with zeros
            states = torch.from_numpy(traj['observations'])
            states = torch.cat([states,
                                torch.zeros(([padding_len] + list(states.shape[1:])),
                                dtype=states.dtype)],
                                dim=0)

            actions = torch.from_numpy(traj['actions'])
            actions = torch.cat([actions,
                                torch.zeros(([padding_len] + list(actions.shape[1:])),
                                dtype=actions.dtype)],
                                dim=0)

            returns_to_go = torch.from_numpy(traj['returns_to_go'])
            returns_to_go = torch.cat([returns_to_go,
                                torch.zeros(([padding_len] + list(returns_to_go.shape[1:])),
                                dtype=returns_to_go.dtype)],
                                dim=0)

            timesteps = torch.arange(start=0, end=self.context_len, step=1)

            traj_mask = torch.cat([torch.ones(traj_len, dtype=torch.long),
                                    torch.zeros(padding_len, dtype=torch.long)],
                                    dim=0)

        return  timesteps, states, actions, returns_to_go, traj_mask

# %% [markdown]
# # Train model

# %%
# model_load = '/content/drive/MyDrive/6_8200_project/decision_transformer/dt_runs_keytodoor_1k/dt_keytodoor_model_24-05-07-15-56-27_best.pt'

start_time = datetime.now().replace(microsecond=0)

start_time_str = start_time.strftime("%y-%m-%d-%H-%M-%S")

prefix = "s4_" + env_s4_name

save_model_name =  prefix + "_model_" + start_time_str + ".pt"
save_model_path = os.path.join(log_dir, save_model_name)
save_best_model_path = save_model_path[:-3] + "_best.pt"

log_csv_name = prefix + "_log_" + start_time_str + ".csv"
log_csv_path = os.path.join(log_dir, log_csv_name)


csv_writer = csv.writer(open(log_csv_path, 'a', 1))
csv_header = (["duration", "num_updates", "action_loss",
               "eval_avg_reward", "eval_avg_ep_len", "eval_d4rl_score"])

csv_writer.writerow(csv_header)

lr = 0.01
weight_decay = 0.01
epochs = 100
# dataset = 'cifar10' #, choices=['mnist', 'cifar10']
grayscale = True
num_workers = 4
batch_size = 64
n_layers = 4
d_model = 128
dropout = 0.1
prenorm = False
resume = False
warmup_steps = 1000
max_train_iters = 200
num_updates_per_iter = 100


print("=" * 60)
print("start time: " + start_time_str)
print("=" * 60)

print("device set to: " + str(device))
print("dataset path: " + dataset_path)
print("model save path: " + save_model_path)
print("log csv save path: " + log_csv_path)

def collate_fn(data):
    return list(zip(*data))


traj_dataset = D4RLTrajectoryDataset(dataset_path, 1000) # is context len max len in this case??

traj_data_loader = DataLoader(traj_dataset,
						batch_size=batch_size,
						shuffle=True,
						pin_memory=True,
						drop_last=True)



# traj_dataset = D4RLTrajectoryDataset(dataset_path, 1000) walker2d-medium-v2

# traj_data_loader = DataLoader(traj_dataset,
# 						batch_size=batch_size,
# 						shuffle=True,
# 						pin_memory=True,
# 						drop_last=True, collate_fn=collate_fn )

data_iter = iter(traj_data_loader)

# env = KeyToDoorEnv(phase_2_begin=100, phase_3_begin=125, max_steps=T)

env = gym.make(env_name)

state_dim = env.observation_space.shape[0]
act_dim = env.action_space.shape[0]

state_mean, state_std = traj_dataset.get_state_stats()


context_len = 1000

model = S4Model(
    state_dim=state_dim,
    act_dim=act_dim,
    h_dim=d_model,
    context_len=context_len, # what is this?
    dropout=dropout,
    n_layers=n_layers,
    prenorm=prenorm,
)

# if model_load is not None:
# 	print("loading model from: " + model_load)
# 	model.load_state_dict(torch.load(model_load))

optimizer, scheduler = setup_optimizer(
    model, lr=lr, weight_decay=weight_decay, epochs=epochs
)

model = model.to(device)
if device == 'cuda':
    cudnn.benchmark = True

# optimizer = torch.optim.AdamW(
# 					model.parameters(),
# 					lr=lr,
# 					weight_decay=weight_decay
# 				)

# scheduler = torch.optim.lr_scheduler.LambdaLR(
# 		optimizer,
# 		lambda steps: min((steps+1)/warmup_steps, 1)
# 	)

max_s4_score = -np.inf
total_updates = 0
num_eval_ep = 10
max_eval_ep_len = 1000


for i_train_iter in range(max_train_iters):
    model.train()

    train_loss = 0
    correct = 0
    total = 0
    log_action_losses = []
    pbar = tqdm(enumerate(traj_data_loader))
    for batch_idx, (timesteps, states, actions, returns_to_go, traj_mask) in pbar:
        # inputs, targets = inputs.to(device), targets.to(device)
        # optimizer.zero_grad()
        timesteps = timesteps.to(device)	# B x T
        states = states.to(device)			# B x T x state_dim
        actions = actions.to(device)		# B x T x act_dim
        returns_to_go = returns_to_go.to(device).unsqueeze(dim=-1) # B x T x 1
        traj_mask = traj_mask.to(device)	# B x T
        action_target = torch.clone(actions).detach().to(device)
        state_preds, action_preds, return_preds = model.forward(
														timesteps=timesteps,
														states=states,
														actions=actions,
														returns_to_go=returns_to_go
													)

        action_preds = action_preds.view(-1, act_dim)[traj_mask.view(-1,) > 0]
        action_target = action_target.view(-1, act_dim)[traj_mask.view(-1,) > 0]

        # outputs = model(timesteps, states, actions, returns_to_go, traj_mask)
        # action_loss = criterion(action_preds, action_target)

        action_loss = F.mse_loss(action_preds, action_target, reduction='mean')

        action_loss.backward()
        optimizer.step()

        # train_loss += loss.item()
        # _, predicted = outputs.max(1)
        # total += targets.size(0)
        # correct += predicted.eq(targets).sum().item()

        log_action_losses.append(action_loss.detach().cpu().item())

        pbar.set_description(
            'Batch Idx: (%d/%d) | Loss: %.3f' %
            (batch_idx, len(traj_data_loader), log_action_losses[-1])
        )
        log_action_losses.append(action_loss.detach().cpu().item())
    # evaluate on env
    results = evaluate_on_env(model, device, context_len, env, rtg_target, rtg_scale,
                            num_eval_ep, max_eval_ep_len, state_mean, state_std,
                            )
    eval_avg_reward = results['eval/avg_reward']
    eval_avg_ep_len = results['eval/avg_ep_len']
    eval_s4_score = get_d4rl_normalized_score(results['eval/avg_reward'], env_name) * 100

    mean_action_loss = np.mean(log_action_losses)
    time_elapsed = str(datetime.now().replace(microsecond=0) - start_time)

    total_updates += num_updates_per_iter

    log_str = ("=" * 60 + '\n' +
            "time elapsed: " + time_elapsed  + '\n' +
            "num of updates: " + str(total_updates) + '\n' +
            "action loss: " +  format(mean_action_loss, ".5f") + '\n' +
            "eval avg reward: " + format(eval_avg_reward, ".5f") + '\n' +
            "eval avg ep len: " + format(eval_avg_ep_len, ".5f") + '\n' +
            "eval s4 score: " + format(eval_s4_score, ".5f")
            )

    print(log_str)

    log_data = [time_elapsed, total_updates, mean_action_loss,
                eval_avg_reward, eval_avg_ep_len,
                eval_s4_score]

    csv_writer.writerow(log_data)

    # save model
    print("max s4 score: " + format(max_s4_score, ".5f"))
    if eval_s4_score >= max_s4_score:
        print("saving max s4 score model at: " + save_best_model_path)
        torch.save(model.state_dict(), save_best_model_path)
        max_s4_score = eval_s4_score

    print("saving current model at: " + save_model_path)
    torch.save(model.state_dict(), save_model_path)

print("=" * 60)
print("finished training!")
print("=" * 60)
end_time = datetime.now().replace(microsecond=0)
time_elapsed = str(end_time - start_time)
end_time_str = end_time.strftime("%y-%m-%d-%H-%M-%S")
print("started training at: " + start_time_str)
print("finished training at: " + end_time_str)
print("total training time: " + time_elapsed)
print("max score: " + format(max_s4_score, ".5f"))
print("saved max score model at: " + save_best_model_path)
print("saved last updated model at: " + save_model_path)
print("=" * 60)

# csv_writer.close()
# Out:
# ============================================================
# start time: 24-05-12-20-55-30
# ============================================================
# device set to: cuda
# dataset path: /content/drive/MyDrive/6_8200_project/S4/data/hopper-medium-v2.pkl
# model save path: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# log csv save path: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_log_24-05-12-20-55-30.csv
# Optimizer group 0 | 39 tensors | lr 0.01 | weight_decay 0.01
# Optimizer group 1 | 12 tensors | lr 0.001 | weight_decay 0.0
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:00:11
# num of updates: 100
# action loss: 0.55662
# eval avg reward: 4.51525
# eval avg ep len: 8.60000
# eval s4 score: 0.76162
# max s4 score: -inf
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:00:19
# num of updates: 200
# action loss: 0.78727
# eval avg reward: 38.83026
# eval avg ep len: 22.10000
# eval s4 score: 1.81599
# max s4 score: 0.76162
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:00:27
# num of updates: 300
# action loss: 0.86871
# eval avg reward: 38.86145
# eval avg ep len: 22.30000
# eval s4 score: 1.81694
# max s4 score: 1.81599
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:00:38
# num of updates: 400
# action loss: 0.85482
# eval avg reward: 75.76166
# eval avg ep len: 41.80000
# eval s4 score: 2.95074
# max s4 score: 1.81694
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:01:03
# num of updates: 500
# action loss: 0.86649
# eval avg reward: 455.16742
# eval avg ep len: 172.20000
# eval s4 score: 14.60836
# max s4 score: 2.95074
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:01:20
# num of updates: 600
# action loss: 0.82691
# eval avg reward: 249.14053
# eval avg ep len: 107.50000
# eval s4 score: 8.27798
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:01:32
# num of updates: 700
# action loss: 0.83491
# eval avg reward: 91.92547
# eval avg ep len: 50.50000
# eval s4 score: 3.44739
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:01:41
# num of updates: 800
# action loss: 0.84240
# eval avg reward: 51.01959
# eval avg ep len: 28.50000
# eval s4 score: 2.19052
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:01:50
# num of updates: 900
# action loss: 0.81558
# eval avg reward: 51.54393
# eval avg ep len: 28.80000
# eval s4 score: 2.20663
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:01:59
# num of updates: 1000
# action loss: 0.79272
# eval avg reward: 56.72995
# eval avg ep len: 31.60000
# eval s4 score: 2.36597
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:02:08
# num of updates: 1100
# action loss: 0.78590
# eval avg reward: 58.15144
# eval avg ep len: 32.40000
# eval s4 score: 2.40965
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:02:18
# num of updates: 1200
# action loss: 0.78346
# eval avg reward: 60.91493
# eval avg ep len: 33.70000
# eval s4 score: 2.49456
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:02:27
# num of updates: 1300
# action loss: 0.77977
# eval avg reward: 62.69512
# eval avg ep len: 34.50000
# eval s4 score: 2.54926
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:02:37
# num of updates: 1400
# action loss: 0.78050
# eval avg reward: 71.92355
# eval avg ep len: 39.50000
# eval s4 score: 2.83281
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:02:56
# num of updates: 1500
# action loss: 0.78057
# eval avg reward: 301.03123
# eval avg ep len: 117.40000
# eval s4 score: 9.87237
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:03:12
# num of updates: 1600
# action loss: 0.77577
# eval avg reward: 206.18149
# eval avg ep len: 92.60000
# eval s4 score: 6.95802
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:03:24
# num of updates: 1700
# action loss: 0.76865
# eval avg reward: 110.48211
# eval avg ep len: 59.70000
# eval s4 score: 4.01756
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:03:36
# num of updates: 1800
# action loss: 0.76173
# eval avg reward: 93.57219
# eval avg ep len: 51.20000
# eval s4 score: 3.49799
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:03:47
# num of updates: 1900
# action loss: 0.75696
# eval avg reward: 89.49619
# eval avg ep len: 48.90000
# eval s4 score: 3.37275
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:03:58
# num of updates: 2000
# action loss: 0.75292
# eval avg reward: 88.62113
# eval avg ep len: 48.20000
# eval s4 score: 3.34586
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:04:09
# num of updates: 2100
# action loss: 0.74928
# eval avg reward: 95.06835
# eval avg ep len: 51.60000
# eval s4 score: 3.54396
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:04:22
# num of updates: 2200
# action loss: 0.74631
# eval avg reward: 117.08567
# eval avg ep len: 60.30000
# eval s4 score: 4.22046
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:04:34
# num of updates: 2300
# action loss: 0.74323
# eval avg reward: 110.11386
# eval avg ep len: 60.00000
# eval s4 score: 4.00625
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:04:47
# num of updates: 2400
# action loss: 0.74108
# eval avg reward: 121.49550
# eval avg ep len: 65.90000
# eval s4 score: 4.35596
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:05:00
# num of updates: 2500
# action loss: 0.73833
# eval avg reward: 127.10815
# eval avg ep len: 68.30000
# eval s4 score: 4.52841
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:05:14
# num of updates: 2600
# action loss: 0.73646
# eval avg reward: 134.03988
# eval avg ep len: 71.00000
# eval s4 score: 4.74140
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:05:27
# num of updates: 2700
# action loss: 0.73531
# eval avg reward: 128.88112
# eval avg ep len: 68.50000
# eval s4 score: 4.58289
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:05:40
# num of updates: 2800
# action loss: 0.73466
# eval avg reward: 124.33216
# eval avg ep len: 66.50000
# eval s4 score: 4.44312
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:05:53
# num of updates: 2900
# action loss: 0.73429
# eval avg reward: 126.82818
# eval avg ep len: 67.80000
# eval s4 score: 4.51981
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:06:07
# num of updates: 3000
# action loss: 0.73376
# eval avg reward: 128.40475
# eval avg ep len: 68.90000
# eval s4 score: 4.56825
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:06:20
# num of updates: 3100
# action loss: 0.73282
# eval avg reward: 132.37658
# eval avg ep len: 70.90000
# eval s4 score: 4.69029
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:06:34
# num of updates: 3200
# action loss: 0.73197
# eval avg reward: 135.34626
# eval avg ep len: 72.10000
# eval s4 score: 4.78154
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:06:48
# num of updates: 3300
# action loss: 0.73074
# eval avg reward: 139.24678
# eval avg ep len: 74.30000
# eval s4 score: 4.90138
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:07:02
# num of updates: 3400
# action loss: 0.73009
# eval avg reward: 137.42037
# eval avg ep len: 73.40000
# eval s4 score: 4.84527
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:07:15
# num of updates: 3500
# action loss: 0.72931
# eval avg reward: 136.36985
# eval avg ep len: 72.70000
# eval s4 score: 4.81299
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:07:29
# num of updates: 3600
# action loss: 0.72925
# eval avg reward: 134.66224
# eval avg ep len: 72.50000
# eval s4 score: 4.76052
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:07:43
# num of updates: 3700
# action loss: 0.72823
# eval avg reward: 139.23454
# eval avg ep len: 74.00000
# eval s4 score: 4.90101
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:07:57
# num of updates: 3800
# action loss: 0.72724
# eval avg reward: 145.59785
# eval avg ep len: 77.30000
# eval s4 score: 5.09653
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:08:12
# num of updates: 3900
# action loss: 0.72567
# eval avg reward: 142.80158
# eval avg ep len: 75.60000
# eval s4 score: 5.01061
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:08:26
# num of updates: 4000
# action loss: 0.72435
# eval avg reward: 142.13417
# eval avg ep len: 75.20000
# eval s4 score: 4.99010
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:08:40
# num of updates: 4100
# action loss: 0.72306
# eval avg reward: 141.46204
# eval avg ep len: 75.30000
# eval s4 score: 4.96945
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:08:53
# num of updates: 4200
# action loss: 0.72213
# eval avg reward: 137.90863
# eval avg ep len: 73.50000
# eval s4 score: 4.86027
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:09:07
# num of updates: 4300
# action loss: 0.72142
# eval avg reward: 131.87536
# eval avg ep len: 71.70000
# eval s4 score: 4.67489
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:09:21
# num of updates: 4400
# action loss: 0.72079
# eval avg reward: 131.74876
# eval avg ep len: 71.60000
# eval s4 score: 4.67100
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:09:34
# num of updates: 4500
# action loss: 0.72039
# eval avg reward: 131.40592
# eval avg ep len: 70.90000
# eval s4 score: 4.66047
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:09:48
# num of updates: 4600
# action loss: 0.71987
# eval avg reward: 130.08226
# eval avg ep len: 70.60000
# eval s4 score: 4.61979
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:10:01
# num of updates: 4700
# action loss: 0.71938
# eval avg reward: 131.04233
# eval avg ep len: 71.10000
# eval s4 score: 4.64929
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:10:15
# num of updates: 4800
# action loss: 0.71915
# eval avg reward: 134.06825
# eval avg ep len: 72.30000
# eval s4 score: 4.74227
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:10:29
# num of updates: 4900
# action loss: 0.71888
# eval avg reward: 132.66056
# eval avg ep len: 71.70000
# eval s4 score: 4.69902
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:10:43
# num of updates: 5000
# action loss: 0.71859
# eval avg reward: 145.98350
# eval avg ep len: 76.00000
# eval s4 score: 5.10838
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:10:57
# num of updates: 5100
# action loss: 0.71835
# eval avg reward: 158.82607
# eval avg ep len: 79.40000
# eval s4 score: 5.50298
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:11:11
# num of updates: 5200
# action loss: 0.71782
# eval avg reward: 130.93212
# eval avg ep len: 71.10000
# eval s4 score: 4.64591
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:11:24
# num of updates: 5300
# action loss: 0.71762
# eval avg reward: 127.93566
# eval avg ep len: 69.70000
# eval s4 score: 4.55384
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:11:38
# num of updates: 5400
# action loss: 0.71750
# eval avg reward: 130.59864
# eval avg ep len: 70.70000
# eval s4 score: 4.63566
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:11:51
# num of updates: 5500
# action loss: 0.71793
# eval avg reward: 131.67014
# eval avg ep len: 71.30000
# eval s4 score: 4.66858
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:12:05
# num of updates: 5600
# action loss: 0.71837
# eval avg reward: 135.61589
# eval avg ep len: 73.00000
# eval s4 score: 4.78982
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:12:19
# num of updates: 5700
# action loss: 0.71903
# eval avg reward: 141.52335
# eval avg ep len: 75.60000
# eval s4 score: 4.97133
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:12:33
# num of updates: 5800
# action loss: 0.71938
# eval avg reward: 138.79424
# eval avg ep len: 74.70000
# eval s4 score: 4.88748
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:12:48
# num of updates: 5900
# action loss: 0.71925
# eval avg reward: 144.73681
# eval avg ep len: 76.80000
# eval s4 score: 5.07007
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:13:02
# num of updates: 6000
# action loss: 0.71887
# eval avg reward: 147.94625
# eval avg ep len: 78.10000
# eval s4 score: 5.16868
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:13:16
# num of updates: 6100
# action loss: 0.71835
# eval avg reward: 145.01242
# eval avg ep len: 77.10000
# eval s4 score: 5.07854
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:13:31
# num of updates: 6200
# action loss: 0.71735
# eval avg reward: 175.28451
# eval avg ep len: 85.50000
# eval s4 score: 6.00868
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:13:47
# num of updates: 6300
# action loss: 0.71637
# eval avg reward: 183.23407
# eval avg ep len: 87.40000
# eval s4 score: 6.25294
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:14:02
# num of updates: 6400
# action loss: 0.71526
# eval avg reward: 168.65474
# eval avg ep len: 84.30000
# eval s4 score: 5.80497
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:14:18
# num of updates: 6500
# action loss: 0.71422
# eval avg reward: 203.09884
# eval avg ep len: 93.10000
# eval s4 score: 6.86330
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:14:38
# num of updates: 6600
# action loss: 0.71391
# eval avg reward: 337.18052
# eval avg ep len: 128.70000
# eval s4 score: 10.98310
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:14:57
# num of updates: 6700
# action loss: 0.71362
# eval avg reward: 322.70867
# eval avg ep len: 125.40000
# eval s4 score: 10.53843
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:15:17
# num of updates: 6800
# action loss: 0.71358
# eval avg reward: 319.00746
# eval avg ep len: 124.30000
# eval s4 score: 10.42471
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:15:37
# num of updates: 6900
# action loss: 0.71418
# eval avg reward: 346.52222
# eval avg ep len: 132.30000
# eval s4 score: 11.27013
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:15:57
# num of updates: 7000
# action loss: 0.71479
# eval avg reward: 338.76861
# eval avg ep len: 129.10000
# eval s4 score: 11.03189
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:16:17
# num of updates: 7100
# action loss: 0.71575
# eval avg reward: 346.32215
# eval avg ep len: 131.60000
# eval s4 score: 11.26398
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:16:37
# num of updates: 7200
# action loss: 0.71660
# eval avg reward: 343.53489
# eval avg ep len: 130.40000
# eval s4 score: 11.17834
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:16:58
# num of updates: 7300
# action loss: 0.71762
# eval avg reward: 352.17367
# eval avg ep len: 133.10000
# eval s4 score: 11.44378
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:17:18
# num of updates: 7400
# action loss: 0.71836
# eval avg reward: 357.69214
# eval avg ep len: 134.70000
# eval s4 score: 11.61334
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:17:38
# num of updates: 7500
# action loss: 0.71902
# eval avg reward: 332.10866
# eval avg ep len: 127.20000
# eval s4 score: 10.82726
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:17:58
# num of updates: 7600
# action loss: 0.71933
# eval avg reward: 348.65038
# eval avg ep len: 132.70000
# eval s4 score: 11.33552
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:18:18
# num of updates: 7700
# action loss: 0.71945
# eval avg reward: 336.42511
# eval avg ep len: 128.40000
# eval s4 score: 10.95989
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:18:38
# num of updates: 7800
# action loss: 0.71930
# eval avg reward: 345.39974
# eval avg ep len: 130.60000
# eval s4 score: 11.23564
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:18:58
# num of updates: 7900
# action loss: 0.71881
# eval avg reward: 339.43663
# eval avg ep len: 130.30000
# eval s4 score: 11.05242
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:19:18
# num of updates: 8000
# action loss: 0.71808
# eval avg reward: 339.09363
# eval avg ep len: 129.00000
# eval s4 score: 11.04188
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:19:38
# num of updates: 8100
# action loss: 0.71709
# eval avg reward: 331.83752
# eval avg ep len: 126.90000
# eval s4 score: 10.81893
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:19:58
# num of updates: 8200
# action loss: 0.71639
# eval avg reward: 354.02704
# eval avg ep len: 131.40000
# eval s4 score: 11.50072
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:20:18
# num of updates: 8300
# action loss: 0.71569
# eval avg reward: 338.28277
# eval avg ep len: 129.50000
# eval s4 score: 11.01696
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:20:37
# num of updates: 8400
# action loss: 0.71534
# eval avg reward: 328.26442
# eval avg ep len: 125.50000
# eval s4 score: 10.70914
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:20:57
# num of updates: 8500
# action loss: 0.71503
# eval avg reward: 346.49249
# eval avg ep len: 129.60000
# eval s4 score: 11.26922
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:21:17
# num of updates: 8600
# action loss: 0.71452
# eval avg reward: 325.34392
# eval avg ep len: 125.70000
# eval s4 score: 10.61941
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:21:37
# num of updates: 8700
# action loss: 0.71401
# eval avg reward: 364.07923
# eval avg ep len: 134.30000
# eval s4 score: 11.80959
# max s4 score: 14.60836
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:22:03
# num of updates: 8800
# action loss: 0.71334
# eval avg reward: 505.88423
# eval avg ep len: 184.40000
# eval s4 score: 16.16669
# max s4 score: 14.60836
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:22:23
# num of updates: 8900
# action loss: 0.71263
# eval avg reward: 334.79006
# eval avg ep len: 127.40000
# eval s4 score: 10.90965
# max s4 score: 16.16669
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:22:51
# num of updates: 9000
# action loss: 0.71191
# eval avg reward: 547.81955
# eval avg ep len: 197.30000
# eval s4 score: 17.45519
# max s4 score: 16.16669
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:23:10
# num of updates: 9100
# action loss: 0.71150
# eval avg reward: 342.80668
# eval avg ep len: 128.70000
# eval s4 score: 11.15597
# max s4 score: 17.45519
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:23:39
# num of updates: 9200
# action loss: 0.71140
# eval avg reward: 611.69851
# eval avg ep len: 210.90000
# eval s4 score: 19.41794
# max s4 score: 17.45519
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:24:02
# num of updates: 9300
# action loss: 0.71152
# eval avg reward: 441.66021
# eval avg ep len: 159.00000
# eval s4 score: 14.19334
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:24:26
# num of updates: 9400
# action loss: 0.71193
# eval avg reward: 454.52040
# eval avg ep len: 161.40000
# eval s4 score: 14.58848
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:24:47
# num of updates: 9500
# action loss: 0.71231
# eval avg reward: 388.24585
# eval avg ep len: 143.20000
# eval s4 score: 12.55213
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:25:15
# num of updates: 9600
# action loss: 0.71276
# eval avg reward: 561.03669
# eval avg ep len: 198.20000
# eval s4 score: 17.86130
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:25:43
# num of updates: 9700
# action loss: 0.71322
# eval avg reward: 589.05395
# eval avg ep len: 204.90000
# eval s4 score: 18.72216
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:26:05
# num of updates: 9800
# action loss: 0.71393
# eval avg reward: 406.03570
# eval avg ep len: 149.70000
# eval s4 score: 13.09874
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:26:31
# num of updates: 9900
# action loss: 0.71437
# eval avg reward: 501.74236
# eval avg ep len: 179.90000
# eval s4 score: 16.03942
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:26:56
# num of updates: 10000
# action loss: 0.71476
# eval avg reward: 522.17285
# eval avg ep len: 183.60000
# eval s4 score: 16.66717
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:27:16
# num of updates: 10100
# action loss: 0.71514
# eval avg reward: 330.41877
# eval avg ep len: 124.60000
# eval s4 score: 10.77534
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:27:38
# num of updates: 10200
# action loss: 0.71519
# eval avg reward: 405.61118
# eval avg ep len: 148.00000
# eval s4 score: 13.08570
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:27:58
# num of updates: 10300
# action loss: 0.71479
# eval avg reward: 357.40507
# eval avg ep len: 131.50000
# eval s4 score: 11.60452
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:28:18
# num of updates: 10400
# action loss: 0.71401
# eval avg reward: 354.39045
# eval avg ep len: 131.10000
# eval s4 score: 11.51189
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:28:38
# num of updates: 10500
# action loss: 0.71308
# eval avg reward: 348.57562
# eval avg ep len: 129.90000
# eval s4 score: 11.33322
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:28:58
# num of updates: 10600
# action loss: 0.71208
# eval avg reward: 342.84472
# eval avg ep len: 129.00000
# eval s4 score: 11.15714
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:29:18
# num of updates: 10700
# action loss: 0.71125
# eval avg reward: 361.01223
# eval avg ep len: 132.60000
# eval s4 score: 11.71535
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:29:37
# num of updates: 10800
# action loss: 0.71047
# eval avg reward: 325.86562
# eval avg ep len: 125.20000
# eval s4 score: 10.63543
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:29:57
# num of updates: 10900
# action loss: 0.70995
# eval avg reward: 344.16633
# eval avg ep len: 129.40000
# eval s4 score: 11.19774
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:30:17
# num of updates: 11000
# action loss: 0.70956
# eval avg reward: 340.98959
# eval avg ep len: 128.60000
# eval s4 score: 11.10013
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:30:36
# num of updates: 11100
# action loss: 0.70947
# eval avg reward: 324.72221
# eval avg ep len: 124.40000
# eval s4 score: 10.60030
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:30:56
# num of updates: 11200
# action loss: 0.70935
# eval avg reward: 329.21749
# eval avg ep len: 126.00000
# eval s4 score: 10.73842
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:31:16
# num of updates: 11300
# action loss: 0.70931
# eval avg reward: 350.28369
# eval avg ep len: 130.80000
# eval s4 score: 11.38570
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:31:36
# num of updates: 11400
# action loss: 0.70944
# eval avg reward: 353.87637
# eval avg ep len: 131.90000
# eval s4 score: 11.49609
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:31:56
# num of updates: 11500
# action loss: 0.70972
# eval avg reward: 353.45011
# eval avg ep len: 132.90000
# eval s4 score: 11.48300
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:32:17
# num of updates: 11600
# action loss: 0.71007
# eval avg reward: 361.81814
# eval avg ep len: 134.00000
# eval s4 score: 11.74011
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:32:38
# num of updates: 11700
# action loss: 0.71061
# eval avg reward: 383.31585
# eval avg ep len: 139.50000
# eval s4 score: 12.40065
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:32:59
# num of updates: 11800
# action loss: 0.71106
# eval avg reward: 364.32553
# eval avg ep len: 136.10000
# eval s4 score: 11.81715
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:33:20
# num of updates: 11900
# action loss: 0.71160
# eval avg reward: 388.83029
# eval avg ep len: 140.20000
# eval s4 score: 12.57009
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:33:41
# num of updates: 12000
# action loss: 0.71169
# eval avg reward: 379.96649
# eval avg ep len: 141.60000
# eval s4 score: 12.29774
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:34:02
# num of updates: 12100
# action loss: 0.71174
# eval avg reward: 392.97256
# eval avg ep len: 144.30000
# eval s4 score: 12.69736
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:34:23
# num of updates: 12200
# action loss: 0.71166
# eval avg reward: 380.58487
# eval avg ep len: 141.00000
# eval s4 score: 12.31674
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:34:45
# num of updates: 12300
# action loss: 0.71144
# eval avg reward: 385.25471
# eval avg ep len: 142.60000
# eval s4 score: 12.46022
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:35:06
# num of updates: 12400
# action loss: 0.71113
# eval avg reward: 376.85308
# eval avg ep len: 140.00000
# eval s4 score: 12.20208
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:35:28
# num of updates: 12500
# action loss: 0.71079
# eval avg reward: 402.44704
# eval avg ep len: 148.10000
# eval s4 score: 12.98848
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:35:50
# num of updates: 12600
# action loss: 0.71074
# eval avg reward: 380.02594
# eval avg ep len: 141.10000
# eval s4 score: 12.29957
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:36:11
# num of updates: 12700
# action loss: 0.71049
# eval avg reward: 386.00935
# eval avg ep len: 142.60000
# eval s4 score: 12.48341
# max s4 score: 19.41794
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# ...
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:48:12
# num of updates: 16100
# action loss: 0.71212
# eval avg reward: 540.98744
# eval avg ep len: 194.80000
# eval s4 score: 17.24527
# max s4 score: 21.29520
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:48:46
# num of updates: 16200
# action loss: 0.71160
# eval avg reward: 731.33266
# eval avg ep len: 254.10000
# eval s4 score: 23.09382
# max s4 score: 21.29520
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:49:21
# num of updates: 16300
# action loss: 0.71101
# eval avg reward: 768.35694
# eval avg ep len: 264.80000
# eval s4 score: 24.23142
# max s4 score: 23.09382
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:50:01
# num of updates: 16400
# action loss: 0.71055
# eval avg reward: 928.65763
# eval avg ep len: 314.20000
# eval s4 score: 29.15682
# max s4 score: 24.23142
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:50:35
# num of updates: 16500
# action loss: 0.71025
# eval avg reward: 739.38793
# eval avg ep len: 255.00000
# eval s4 score: 23.34132
# max s4 score: 29.15682
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:51:05
# num of updates: 16600
# action loss: 0.71006
# eval avg reward: 633.57539
# eval avg ep len: 222.70000
# eval s4 score: 20.09013
# max s4 score: 29.15682
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:51:38
# num of updates: 16700
# action loss: 0.70994
# eval avg reward: 736.70491
# eval avg ep len: 251.60000
# eval s4 score: 23.25888
# max s4 score: 29.15682
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:52:15
# num of updates: 16800
# action loss: 0.70996
# eval avg reward: 842.26533
# eval avg ep len: 284.30000
# eval s4 score: 26.50233
# max s4 score: 29.15682
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:52:49
# num of updates: 16900
# action loss: 0.70997
# eval avg reward: 749.32584
# eval avg ep len: 258.70000
# eval s4 score: 23.64668
# max s4 score: 29.15682
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:53:19
# num of updates: 17000
# action loss: 0.71011
# eval avg reward: 614.35510
# eval avg ep len: 216.80000
# eval s4 score: 19.49956
# max s4 score: 29.15682
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:53:50
# num of updates: 17100
# action loss: 0.71028
# eval avg reward: 659.60929
# eval avg ep len: 231.20000
# eval s4 score: 20.89004
# max s4 score: 29.15682
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:54:25
# num of updates: 17200
# action loss: 0.71073
# eval avg reward: 771.11795
# eval avg ep len: 263.40000
# eval s4 score: 24.31626
# max s4 score: 29.15682
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:55:01
# num of updates: 17300
# action loss: 0.71117
# eval avg reward: 799.27903
# eval avg ep len: 274.90000
# eval s4 score: 25.18154
# max s4 score: 29.15682
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:55:34
# num of updates: 17400
# action loss: 0.71162
# eval avg reward: 735.86341
# eval avg ep len: 253.90000
# eval s4 score: 23.23303
# max s4 score: 29.15682
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:56:09
# num of updates: 17500
# action loss: 0.71205
# eval avg reward: 773.86811
# eval avg ep len: 265.70000
# eval s4 score: 24.40076
# max s4 score: 29.15682
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:56:45
# num of updates: 17600
# action loss: 0.71276
# eval avg reward: 818.14379
# eval avg ep len: 275.80000
# eval s4 score: 25.76118
# max s4 score: 29.15682
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:57:21
# num of updates: 17700
# action loss: 0.71343
# eval avg reward: 809.43796
# eval avg ep len: 276.90000
# eval s4 score: 25.49368
# max s4 score: 29.15682
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:58:01
# num of updates: 17800
# action loss: 0.71394
# eval avg reward: 938.74302
# eval avg ep len: 315.00000
# eval s4 score: 29.46671
# max s4 score: 29.15682
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:58:36
# num of updates: 17900
# action loss: 0.71434
# eval avg reward: 797.93155
# eval avg ep len: 268.90000
# eval s4 score: 25.14013
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:59:10
# num of updates: 18000
# action loss: 0.71467
# eval avg reward: 735.21476
# eval avg ep len: 251.70000
# eval s4 score: 23.21310
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:59:47
# num of updates: 18100
# action loss: 0.71503
# eval avg reward: 877.99172
# eval avg ep len: 292.50000
# eval s4 score: 27.60006
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:00:24
# num of updates: 18200
# action loss: 0.71545
# eval avg reward: 803.11978
# eval avg ep len: 275.90000
# eval s4 score: 25.29955
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:00:55
# num of updates: 18300
# action loss: 0.71587
# eval avg reward: 629.05719
# eval avg ep len: 232.20000
# eval s4 score: 19.95130
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:01:30
# num of updates: 18400
# action loss: 0.71632
# eval avg reward: 745.07085
# eval avg ep len: 262.00000
# eval s4 score: 23.51594
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:02:02
# num of updates: 18500
# action loss: 0.71700
# eval avg reward: 675.73369
# eval avg ep len: 241.60000
# eval s4 score: 21.38548
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:02:36
# num of updates: 18600
# action loss: 0.71723
# eval avg reward: 729.55807
# eval avg ep len: 254.80000
# eval s4 score: 23.03929
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:03:06
# num of updates: 18700
# action loss: 0.71753
# eval avg reward: 627.02533
# eval avg ep len: 224.20000
# eval s4 score: 19.88887
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:03:38
# num of updates: 18800
# action loss: 0.71773
# eval avg reward: 634.08999
# eval avg ep len: 236.20000
# eval s4 score: 20.10594
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:04:10
# num of updates: 18900
# action loss: 0.71801
# eval avg reward: 675.89182
# eval avg ep len: 242.50000
# eval s4 score: 21.39034
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:04:40
# num of updates: 19000
# action loss: 0.71804
# eval avg reward: 591.79769
# eval avg ep len: 220.00000
# eval s4 score: 18.80646
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:05:11
# num of updates: 19100
# action loss: 0.71805
# eval avg reward: 660.82997
# eval avg ep len: 232.80000
# eval s4 score: 20.92755
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:05:43
# num of updates: 19200
# action loss: 0.71826
# eval avg reward: 674.22597
# eval avg ep len: 241.70000
# eval s4 score: 21.33916
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:06:15
# num of updates: 19300
# action loss: 0.71824
# eval avg reward: 632.08759
# eval avg ep len: 231.60000
# eval s4 score: 20.04441
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:06:45
# num of updates: 19400
# action loss: 0.71808
# eval avg reward: 603.83841
# eval avg ep len: 228.50000
# eval s4 score: 19.17643
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:07:18
# num of updates: 19500
# action loss: 0.71787
# eval avg reward: 695.10819
# eval avg ep len: 249.90000
# eval s4 score: 21.98078
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:07:51
# num of updates: 19600
# action loss: 0.71761
# eval avg reward: 723.08123
# eval avg ep len: 249.10000
# eval s4 score: 22.84028
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:08:24
# num of updates: 19700
# action loss: 0.71715
# eval avg reward: 695.67333
# eval avg ep len: 244.90000
# eval s4 score: 21.99815
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:08:56
# num of updates: 19800
# action loss: 0.71711
# eval avg reward: 664.01985
# eval avg ep len: 236.80000
# eval s4 score: 21.02556
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:09:28
# num of updates: 19900
# action loss: 0.71707
# eval avg reward: 685.14949
# eval avg ep len: 238.60000
# eval s4 score: 21.67479
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:09:58
# num of updates: 20000
# action loss: 0.71699
# eval avg reward: 637.54298
# eval avg ep len: 227.20000
# eval s4 score: 20.21203
# max s4 score: 29.46671
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# ============================================================
# finished training!
# ============================================================
# started training at: 24-05-12-20-55-30
# finished training at: 24-05-12-22-05-28
# total training time: 1:09:58
# max score: 29.46671
# saved max score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30_best.pt
# saved last updated model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30.pt
# ============================================================

# %%
# set mujoco env path if not already set
# %env LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin


eval_dataset = "medium"		# medium / medium-replay / medium-expert
eval_rtg_scale = 1000		# normalize returns to go

eval_env_name = "Hopper-v3"
eval_rtg_target = 3600
eval_env_d4rl_name = f'hopper-{eval_dataset}-v2'

# eval_env_name = "HalfCheetah-v3"
# eval_rtg_target = 6000
# eval_env_d4rl_name = f'halfcheetah-{eval_dataset}-v2'

# eval_env_name = "Hopper-v3"
# eval_rtg_target = 3600
# eval_env_d4rl_name = f'hopper-{eval_dataset}-v2'


num_test_eval_ep = 10			# num of evaluation episodes
eval_max_eval_ep_len = 1000		# max len of one episode


context_len = 1000        # K in decision transformer
n_blocks = 3            # num of transformer blocks
embed_dim = 128         # embedding (hidden) dim of transformer
n_heads = 1             # num of transformer heads
dropout_p = 0.1         # dropout probability


eval_chk_pt_dir = "/content/drive/MyDrive/6_8200_project/S4/s4_runs/"
# /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-18-47-30_best.pt

eval_chk_pt_name = "s4_hopper-medium-v2_model_24-05-12-20-55-30_best.pt"
eval_chk_pt_list = [eval_chk_pt_name]


## manually override check point list
## passing a list will evaluate on all checkpoints
## and output mean and std score


# eval_chk_pt_list = [
# 	"dt_walker2d-medium-v2_model_22-02-20-06-27-12_best.pt",
# 	"dt_walker2d-medium-v2_model_22-02-20-09-11-30_best.pt",
# 	"dt_walker2d-medium-v2_model_22-02-22-09-24-12_best.pt"
# ]

def get_d4rl_dataset_stats(env_d4rl_name):
    return D4RL_DATASET_STATS[env_d4rl_name]

env_data_stats = get_d4rl_dataset_stats(eval_env_d4rl_name)
eval_state_mean = np.array(env_data_stats['state_mean'])
eval_state_std = np.array(env_data_stats['state_std'])

eval_env = gym.make(eval_env_name)

state_dim = eval_env.observation_space.shape[0]
act_dim = eval_env.action_space.shape[0]

all_scores = []

for eval_chk_pt_name in eval_chk_pt_list:

	eval_model = S4Model(
		state_dim=state_dim,
		act_dim=act_dim,
		h_dim=d_model,
		context_len=1000, # what is this?
		dropout=dropout,
		n_layers=n_layers,
		prenorm=prenorm,
	).to(device)


	eval_chk_pt_path = os.path.join(eval_chk_pt_dir, eval_chk_pt_name)

	# load checkpoint
	eval_model.load_state_dict(torch.load(eval_chk_pt_path, map_location=device))

	print("model loaded from: " + eval_chk_pt_path)

	# evaluate on env
	results = evaluate_on_env(eval_model, device, context_len,
							eval_env, eval_rtg_target, eval_rtg_scale,
							num_test_eval_ep, eval_max_eval_ep_len,
							eval_state_mean, eval_state_std)
	print(results)

	norm_score = get_d4rl_normalized_score(results['eval/avg_reward'], eval_env_name) * 100
	print("normalized d4rl score: ", norm_score)

	all_scores.append(norm_score)

print("=" * 60)
all_scores = np.array(all_scores)
print("evaluated on env: " + eval_env_name)
print("total num of checkpoints evaluated: " + str(len(eval_chk_pt_list)))
print("d4rl score mean: " + format(all_scores.mean(), ".5f"))
print("d4rl score std: " + format(all_scores.std(), ".5f"))
print("d4rl score var: " + format(all_scores.var(), ".5f"))
print("=" * 60)
# Out:
# env: LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin
# model loaded from: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_hopper-medium-v2_model_24-05-12-20-55-30_best.pt
# {'eval/avg_reward': 752.9745147641312, 'eval/avg_ep_len': 260.3}
# normalized d4rl score:  23.75878448225568
# ============================================================
# evaluated on env: Hopper-v3
# total num of checkpoints evaluated: 1
# d4rl score mean: 23.75878
# d4rl score std: 0.00000
# d4rl score var: 0.00000
# ============================================================

# %%
from colabgymrender.recorder import Recorder

num_test_eval_ep = 1
eval_max_ep_len = 1000


directory = "/content/drive/MyDrive/6_8200_project/S4"
eval_env = Recorder(eval_env, directory)

results = evaluate_on_env(eval_model, device, context_len,
                        eval_env, eval_rtg_target, eval_rtg_scale,
                        num_test_eval_ep, eval_max_ep_len,
						eval_state_mean, eval_state_std)
print(results)

norm_score = get_d4rl_normalized_score(results['eval/avg_reward'], eval_env_name) * 100
print("normalized d4rl score: ", norm_score)

eval_env.play()

eval_env.close()
# Out:
# {'eval/avg_reward': 944.076050757285, 'eval/avg_ep_len': 311.0}
# normalized d4rl score:  29.630570944014867
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-2a03382197a5> in <cell line: 19>()
#      17 print("normalized d4rl score: ", norm_score)
#      18
# ---> 19 eval_env.play()
#      20
#      21 eval_env.close()
#
# /usr/local/lib/python3.10/dist-packages/colabgymrender/recorder.py in play(self)
#      70         filename = 'temp-{start}.mp4'
#      71         clip = VideoFileClip(self.path)
# ---> 72         clip.write_videofile(filename, progress_bar = False, verbose = False)
#      73         display(Video(filename, embed = True))
#      74         os.remove(filename)
#
# TypeError: VideoClip.write_videofile() got an unexpected keyword argument 'progress_bar'

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch

# Data
print(f'==> Preparing {env_name} data..')
