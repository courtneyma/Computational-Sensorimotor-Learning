# %% [markdown]
# ## install mujoco-py, D4RL, graph libs
#
# * **Restart Runtime** after running this block to complete D4RL setup

# %%
###### libs for install ######


# !sudo apt-get update
# !sudo apt-get install gcc

# !sudo apt-get build-dep mesa
# !sudo apt-get install llvm-dev
# !sudo apt-get install freeglut3 freeglut3-dev

# !sudo apt-get install python3-dev

# !sudo apt-get install build-essential

# !sudo apt install curl git libgl1-mesa-dev libgl1-mesa-glx libglew-dev \
        libosmesa6-dev software-properties-common net-tools unzip vim \
        virtualenv wget xpra xserver-xorg-dev libglfw3-dev patchelf

#!sudo apt-get install -y libglew-dev

# !pip install networkx
# !pip install pybind11
# !pip install graph-walker
# !pip install glfw
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gcc is already the newest version (4:11.2.0-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 50 not upgraded.
# Reading package lists... Done
# E: Unable to find a source package for mesa
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# llvm-dev is already the newest version (1:14.0-55~exp2).
# 0 upgraded, 0 newly installed, 0 to remove and 50 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# freeglut3 is already the newest version (2.8.1-6).
# freeglut3-dev is already the newest version (2.8.1-6).
# 0 upgraded, 0 newly installed, 0 to remove and 50 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3-dev is already the newest version (3.10.6-1~22.04).
# 0 upgraded, 0 newly installed, 0 to remove and 50 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# 0 upgraded, 0 newly installed, 0 to remove and 50 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# net-tools is already the newest version (1.60+git20181103.0eebece-1ubuntu5).
# wget is already the newest version (1.21.2-2ubuntu1).
# libglew-dev is already the newest version (2.2.0-4).
# libglfw3-dev is already the newest version (3.3.6-1).
# patchelf is already the newest version (0.14.3-1).
# virtualenv is already the newest version (20.13.0+ds-2).
# xpra is already the newest version (3.1-1build5).
# curl is already the newest version (7.81.0-1ubuntu1.16).
# git is already the newest version (1:2.34.1-1ubuntu1.10).
# libgl1-mesa-dev is already the newest version (23.2.1-1ubuntu3.1~22.04.2).
# libosmesa6-dev is already the newest version (23.2.1-1ubuntu3.1~22.04.2).
# software-properties-common is already the newest version (0.99.22.9).
# unzip is already the newest version (6.0-26ubuntu3.2).
# vim is already the newest version (2:8.2.3995-1ubuntu2.16).
# xserver-xorg-dev is already the newest version (2:21.1.4-2ubuntu1.7~22.04.10).
# libgl1-mesa-glx is already the newest version (23.0.4-0ubuntu1~22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 50 not upgraded.
# Requirement already satisfied: glfw in /usr/local/lib/python3.10/dist-packages (2.7.0)

# %%
###### mujoco setup ######


#!wget https://mujoco.org/download/mujoco210-linux-x86_64.tar.gz

# !wget https://roboti.us/download/mujoco200_linux.zip

# !wget https://roboti.us/file/mjkey.txt
# Out:
# --2024-05-12 22:39:14--  https://roboti.us/download/mujoco200_linux.zip
# Resolving roboti.us (roboti.us)... 104.40.85.93
# Connecting to roboti.us (roboti.us)|104.40.85.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4427362 (4.2M) [application/zip]
# Saving to: ‘mujoco200_linux.zip.1’
#
# mujoco200_linux.zip 100%[===================>]   4.22M  --.-KB/s    in 0.1s
#
# 2024-05-12 22:39:15 (29.6 MB/s) - ‘mujoco200_linux.zip.1’ saved [4427362/4427362]
#
# --2024-05-12 22:39:15--  https://roboti.us/file/mjkey.txt
# Resolving roboti.us (roboti.us)... 104.40.85.93
# Connecting to roboti.us (roboti.us)|104.40.85.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 768 [text/plain]
# Saving to: ‘mjkey.txt’
#
# mjkey.txt           100%[===================>]     768  --.-KB/s    in 0s
#
# 2024-05-12 22:39:15 (69.2 MB/s) - ‘mjkey.txt’ saved [768/768]

# %%
# !mkdir /root/.mujoco

### mujoco 210
#!tar -xf mujoco210-linux-x86_64.tar.gz -C /.mujoco/
#!ls -alh /.mujoco/mujoco210

### mujoco 200
# !unzip mujoco200_linux.zip -d /root/.mujoco/
# !cp -r /root/.mujoco/mujoco200_linux /root/.mujoco/mujoco200

# !mv mjkey.txt /root/.mujoco/

# !cp -r /root/.mujoco/mujoco200/bin/* /usr/lib/
# Out:
# mkdir: cannot create directory ‘/root/.mujoco’: File exists
# Archive:  mujoco200_linux.zip
# replace /root/.mujoco/mujoco200_linux/sample/mjxmake.m? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /root/.mujoco/mujoco200_linux/sample/mjxmake.m
#   inflating: /root/.mujoco/mujoco200_linux/sample/makefile
#   inflating: /root/.mujoco/mujoco200_linux/sample/mjx.cpp
#   inflating: /root/.mujoco/mujoco200_linux/sample/simulate.cpp
#   inflating: /root/.mujoco/mujoco200_linux/sample/record.cpp
#   inflating: /root/.mujoco/mujoco200_linux/sample/basic.cpp
#   inflating: /root/.mujoco/mujoco200_linux/sample/derivative.cpp
#   inflating: /root/.mujoco/mujoco200_linux/sample/compile.cpp
#   inflating: /root/.mujoco/mujoco200_linux/sample/testspeed.cpp
#   inflating: /root/.mujoco/mujoco200_linux/sample/testxml.cpp
#   inflating: /root/.mujoco/mujoco200_linux/model/sponge.png
#   inflating: /root/.mujoco/mujoco200_linux/model/softellipsoid.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/softcylinder.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/softbox.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/scene.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/rope.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/particle.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/marble.png
#   inflating: /root/.mujoco/mujoco200_linux/model/loop.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/grid2pin.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/grid2.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/grid1pin.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/grid1.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/cloth.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/carpet.png
#   inflating: /root/.mujoco/mujoco200_linux/model/hammock.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/humanoid100.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/humanoid.xml
#   inflating: /root/.mujoco/mujoco200_linux/model/arm26.xml
#   inflating: /root/.mujoco/mujoco200_linux/include/uitools.h
#   inflating: /root/.mujoco/mujoco200_linux/include/uitools.c
#   inflating: /root/.mujoco/mujoco200_linux/include/mujoco.h
#   inflating: /root/.mujoco/mujoco200_linux/include/mjxmacro.h
#   inflating: /root/.mujoco/mujoco200_linux/include/mjvisualize.h
#   inflating: /root/.mujoco/mujoco200_linux/include/mjui.h
#   inflating: /root/.mujoco/mujoco200_linux/include/mjrender.h
#   inflating: /root/.mujoco/mujoco200_linux/include/mjmodel.h
#   inflating: /root/.mujoco/mujoco200_linux/include/mjdata.h
#   inflating: /root/.mujoco/mujoco200_linux/include/glfw3.h
#   inflating: /root/.mujoco/mujoco200_linux/doc/README.txt
#   inflating: /root/.mujoco/mujoco200_linux/doc/REFERENCE.txt
#   inflating: /root/.mujoco/mujoco200_linux/bin/libmujoco200.so
#   inflating: /root/.mujoco/mujoco200_linux/bin/simulate
#   inflating: /root/.mujoco/mujoco200_linux/bin/record
#   inflating: /root/.mujoco/mujoco200_linux/bin/basic
#   inflating: /root/.mujoco/mujoco200_linux/bin/derivative
#   inflating: /root/.mujoco/mujoco200_linux/bin/compile
#   inflating: /root/.mujoco/mujoco200_linux/bin/testspeed
#   inflating: /root/.mujoco/mujoco200_linux/bin/testxml
#   inflating: /root/.mujoco/mujoco200_linux/bin/libmujoco200nogl.so
#   inflating: /root/.mujoco/mujoco200_linux/bin/libglfw3.a
#   inflating: /root/.mujoco/mujoco200_linux/bin/libglfw.so.3
#   inflating: /root/.mujoco/mujoco200_linux/bin/libglewosmesa.so
#   inflating: /root/.mujoco/mujoco200_linux/bin/libglewegl.so
#   inflating: /root/.mujoco/mujoco200_linux/bin/libglew.so

# %%
# !ls -alh /root/.mujoco/
# Out:
# total 24K
# drwxr-xr-x 4 root root 4.0K May 12 22:45 .
# drwx------ 1 root root 4.0K May 12 22:13 ..
# -rw-r--r-- 1 root root  768 Oct 18  2021 mjkey.txt
# drwxr-xr-x 8 root root 4.0K May 12 22:45 mujoco200
# drwxrwxr-x 7 root root 4.0K Oct  2  2018 mujoco200_linux

# %%
# %env LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin
# Out:
# env: LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin

# %%
###### mujoco-py setup ######

# !pip install mujoco_py==2.0.2.8
# Out:
# Requirement already satisfied: mujoco_py==2.0.2.8 in /usr/local/lib/python3.10/dist-packages (2.0.2.8)
# Requirement already satisfied: glfw>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (2.7.0)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (1.25.2)
# Requirement already satisfied: Cython>=0.27.2 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (3.0.0a10)
# Requirement already satisfied: imageio>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (2.31.6)
# Requirement already satisfied: cffi>=1.10 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (1.16.0)
# Requirement already satisfied: fasteners~=0.15 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (0.19)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.10->mujoco_py==2.0.2.8) (2.22)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio>=2.1.2->mujoco_py==2.0.2.8) (9.4.0)

# %%
###### D4RL setup ######

## !pip uninstall dm_control==0.0.364896371

# !git clone https://github.com/rail-berkeley/d4rl.git

### edit dm_control version in d4rl setup.py
# !sed -i "s;dm_control @ git+git://github.com/deepmind/dm_control@master#egg=dm_control;dm_control==0.0.364896371;g" /content/d4rl/setup.py

### edit mjrl install in d4rl setup.py to use github's new https protocol instead of git SSH
# !sed -i "s;mjrl @ git+git://github.com/aravindr93/mjrl@master#egg=mjrl;mjrl @ git+https://github.com/aravindr93/mjrl@master#egg=mjrl;g" /content/d4rl/setup.py

# !pip install -e d4rl/.
# Out:
# fatal: destination path 'd4rl' already exists and is not an empty directory.
# Obtaining file:///content/d4rl
#   Preparing metadata (setup.py) ... done
# Collecting mjrl@ git+https://github.com/aravindr93/mjrl@master#egg=mjrl (from D4RL==1.1)
#   Cloning https://github.com/aravindr93/mjrl (to revision master) to /tmp/pip-install-s0u969_d/mjrl_4d66efe13a244e60a098c78e6f9b1796
#   Running command git clone --filter=blob:none --quiet https://github.com/aravindr93/mjrl /tmp/pip-install-s0u969_d/mjrl_4d66efe13a244e60a098c78e6f9b1796
#   Resolved https://github.com/aravindr93/mjrl to commit 3871d93763d3b49c4741e6daeaebbc605fe140dc
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gym<0.24.0 in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (0.23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (1.25.2)
# Requirement already satisfied: mujoco_py in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (2.0.2.8)
# Requirement already satisfied: pybullet in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (3.2.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (3.9.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (2.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (8.1.7)
# Requirement already satisfied: dm_control>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from D4RL==1.1) (1.0.19)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (1.4.0)
# Requirement already satisfied: dm-env in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (1.6)
# Requirement already satisfied: dm-tree!=0.1.2 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (0.1.8)
# Requirement already satisfied: glfw in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (2.7.0)
# Requirement already satisfied: labmaze in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (1.0.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (4.9.4)
# Requirement already satisfied: mujoco>=3.1.5 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (3.1.5)
# Requirement already satisfied: protobuf>=3.19.4 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (3.20.3)
# Requirement already satisfied: pyopengl>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (3.1.7)
# Requirement already satisfied: pyparsing>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (3.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (2.31.0)
# Requirement already satisfied: setuptools!=50.0.0 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (67.7.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (1.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->D4RL==1.1) (4.66.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym<0.24.0->D4RL==1.1) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym<0.24.0->D4RL==1.1) (0.0.8)
# Requirement already satisfied: Cython>=0.27.2 in /usr/local/lib/python3.10/dist-packages (from mujoco_py->D4RL==1.1) (3.0.0a10)
# Requirement already satisfied: imageio>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from mujoco_py->D4RL==1.1) (2.31.6)
# Requirement already satisfied: cffi>=1.10 in /usr/local/lib/python3.10/dist-packages (from mujoco_py->D4RL==1.1) (1.16.0)
# Requirement already satisfied: fasteners~=0.15 in /usr/local/lib/python3.10/dist-packages (from mujoco_py->D4RL==1.1) (0.19)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.10->mujoco_py->D4RL==1.1) (2.22)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio>=2.1.2->mujoco_py->D4RL==1.1) (9.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.10/dist-packages (from mujoco>=3.1.5->dm_control>=1.0.3->D4RL==1.1) (1.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dm_control>=1.0.3->D4RL==1.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dm_control>=1.0.3->D4RL==1.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dm_control>=1.0.3->D4RL==1.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dm_control>=1.0.3->D4RL==1.1) (2024.2.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=3.1.5->dm_control>=1.0.3->D4RL==1.1) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=3.1.5->dm_control>=1.0.3->D4RL==1.1) (6.4.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=3.1.5->dm_control>=1.0.3->D4RL==1.1) (4.11.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=3.1.5->dm_control>=1.0.3->D4RL==1.1) (3.18.1)
# Installing collected packages: D4RL
#   Attempting uninstall: D4RL
#     Found existing installation: D4RL 1.1
#     Uninstalling D4RL-1.1:
#       Successfully uninstalled D4RL-1.1
#   Running setup.py develop for D4RL
# Successfully installed D4RL-1.1

# %%
###### restart runtime ######

exit()

# %%
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install -U colabgymrender
# Out:
# Requirement already satisfied: colabgymrender in /usr/local/lib/python3.10/dist-packages (1.1.0)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (from colabgymrender) (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender) (4.66.4)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender) (1.25.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender) (2.31.6)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy->colabgymrender) (0.4.9)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio<3.0,>=2.5->moviepy->colabgymrender) (9.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg>=0.2.0->moviepy->colabgymrender) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy->colabgymrender) (2024.2.2)

# %%
# !pip install pytorch_lightning
# !pip install einops
# Out:
# Requirement already satisfied: pytorch_lightning in /usr/local/lib/python3.10/dist-packages (2.2.4)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.25.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2.2.1+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2023.6.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (24.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.11.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (0.11.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.9.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->pytorch_lightning) (67.7.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (3.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->pytorch_lightning) (12.4.127)
# Requirement already satisfied: pretty-errors==1.2.25 in /usr/local/lib/python3.10/dist-packages (from torchmetrics>=0.7.0->pytorch_lightning) (1.2.25)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from pretty-errors==1.2.25->torchmetrics>=0.7.0->pytorch_lightning) (0.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->pytorch_lightning) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.8.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install imageio==2.4.1

# %% [markdown]
# # check mujoco-py and D4RL installation
#
# * if check fails then **Restart Runtime** again
# * if check still fails then Factory reset runtime and install again
# * After installing, first import will be slow as the lib will be built again

# %%
# !pip install Cython==3.0.0a10
# Out:
# Requirement already satisfied: Cython==3.0.0a10 in /usr/local/lib/python3.10/dist-packages (3.0.0a10)

# %%
# set mujoco env path if not already set
# %env LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin

import gym
import d4rl # Import required to register environments


env = gym.make('Walker2d-v3')
env.reset()
env.step(env.action_space.sample())
env.close()
print("mujoco-py check passed")

# env = gym.make('walker2d-medium-v2')
# env.reset()
# env.step(env.action_space.sample())
# env.close()
# print("d4rl check passed")
# Out:
# env: LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin
# <frozen importlib._bootstrap>:283: DeprecationWarning: the load_module() method is deprecated and slated for removal in Python 3.12; use exec_module() instead
# Warning: Flow failed to import. Set the environment variable D4RL_SUPPRESS_IMPORT_ERROR=1 to suppress this message.
# No module named 'flow'
# /usr/local/lib/python3.10/dist-packages/glfw/__init__.py:914: GLFWError: (65544) b'X11: The DISPLAY environment variable is missing'
#   warnings.warn(message, GLFWError)
# Warning: CARLA failed to import. Set the environment variable D4RL_SUPPRESS_IMPORT_ERROR=1 to suppress this message.
# No module named 'carla'
# mujoco-py check passed

# %% [markdown]
# # import libs

# %%
# set mujoco env path if not already set
# %env LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin

import os
import sys
import random
import csv
from datetime import datetime
import pickle
import collections
import math

import numpy as np
import gym
from typing import Optional, Mapping, Tuple, Union


import logging

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import torchvision
import torchvision.transforms as transforms

# import networkx as nx

import gym
from gym.envs.registration import registry, register

from pytorch_lightning.utilities import rank_zero_only
from einops import rearrange, repeat


contract = torch.einsum
# Out:
# env: LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/__init__.py:41: Deprecated call to `pkg_resources.declare_namespace('lightning_fabric')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/__init__.py:37: Deprecated call to `pkg_resources.declare_namespace('pytorch_lightning')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn

# %%
from datetime import datetime
import csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/MyDrive/6_8200_project/S4')


from models.s4.s4 import S4Block as S4  # Can use full version instead of minimal S4D standalone below
from models.s4.s4d import S4D
from tqdm.auto import tqdm
# Out:
# WARNING:models.s4.s4:CUDA extension for structured kernels (Cauchy and Vandermonde multiplication) not found. Install by going to extensions/kernels/ and running `python setup.py install`, for improved speed and memory efficiency. Note that the kernel changed for state-spaces 4.0 and must be recompiled.
# WARNING:models.s4.s4:Falling back on slow Cauchy and Vandermonde kernel. Install at least one of pykeops or the CUDA extension for better speed and memory efficiency.

# %% [markdown]
# # S4 model

# %%
def split_train_val(train, val_split):
    train_len = int(len(train) * (1.0-val_split))
    train, val = torch.utils.data.random_split(
        train,
        (train_len, len(train) - train_len),
        generator=torch.Generator().manual_seed(42),
    )
    return train, val


class S4Model(nn.Module):

    def __init__(
        self,
        state_dim,
        act_dim,
        h_dim,
        context_len,
        dropout=0.2,
        n_layers=4,
        max_timestep=4096,
        prenorm=False,


    ):
        super().__init__()

        self.prenorm = prenorm

        self.state_dim = state_dim
        self.act_dim = act_dim
        self.h_dim = h_dim

        ### projection heads (project to embedding)
        self.embed_ln = nn.LayerNorm(h_dim)
        self.embed_timestep = nn.Embedding(max_timestep, h_dim)
        self.embed_rtg = torch.nn.Linear(1, h_dim)
        self.embed_state = torch.nn.Linear(state_dim, h_dim)

        # continuous actions
        self.embed_action = torch.nn.Linear(act_dim, h_dim)
        use_action_tanh = True # True for continuous actions

        # Stack S4 layers as residual blocks
        self.s4_layers = nn.ModuleList()
        self.norms = nn.ModuleList()
        self.dropouts = nn.ModuleList()
        for _ in range(n_layers):
            self.s4_layers.append(
                S4D(h_dim, dropout=dropout, transposed=True, lr=min(0.001, lr))
            )
            self.norms.append(nn.LayerNorm(h_dim))
            self.dropouts.append(dropout_fn(dropout))

        ### prediction heads
        self.predict_rtg = torch.nn.Linear(h_dim, 1)
        self.predict_state = torch.nn.Linear(h_dim, state_dim)
        self.predict_action = nn.Sequential(
            *([nn.Linear(h_dim, act_dim)] + ([nn.Tanh()] if use_action_tanh else []))
        )

    def forward(self, timesteps, states, actions, returns_to_go):
        """
        Input x is shape (B, L, d_input)
        """
        B, T, _ = states.shape

        time_embeddings = self.embed_timestep(timesteps)

        # time embeddings are treated similar to positional embeddings
        state_embeddings = self.embed_state(states) + time_embeddings # (h_dim)
        action_embeddings = self.embed_action(actions) + time_embeddings # (h_dim)
        returns_embeddings = self.embed_rtg(returns_to_go) + time_embeddings # (h_dim)

        # stack rtg, states and actions and reshape sequence as
        # (r1, s1, a1, r2, s2, a2 ...)
        h = torch.stack(
            (returns_embeddings, state_embeddings, action_embeddings), dim=1
        ).permute(0, 2, 1, 3).reshape(B, 3 * T, self.h_dim)

        h = self.embed_ln(h) # (B x 3*T x h_dim)


        x = h.transpose(-1, -2)  # (B, L, d_model) -> (B, d_model, L)


        for layer, norm, dropout in zip(self.s4_layers, self.norms, self.dropouts):
            # Each iteration of this loop will map (B, d_model, L) -> (B, d_model, L)

            z = x
            if self.prenorm:
                # Prenorm
                z = norm(z.transpose(-1, -2)).transpose(-1, -2)

            # Apply S4 block: we ignore the state input and output
            z, _ = layer(z)

            # Dropout on the output of the S4 block
            z = dropout(z)

            # Residual connection
            x = z + x

            if not self.prenorm:
                # Postnorm
                x = norm(x.transpose(-1, -2)).transpose(-1, -2)

        x = x.transpose(-1, -2)

        # get h reshaped such that its size = (B x 3*T x h_dim) and
        # h[:, 0, t] is conditioned on r_0, s_0, a_0 ... r_t
        # h[:, 1, t] is conditioned on r_0, s_0, a_0 ... r_t, s_t
        # h[:, 2, t] is conditioned on r_0, s_0, a_0 ... r_t, s_t, a_t
        h = h.reshape(B, T, 3, self.h_dim).permute(0, 2, 1, 3)

        # get predictions
        return_preds = self.predict_rtg(h[:,2])     # predict next rtg given r, s, a
        state_preds = self.predict_state(h[:,2])    # predict next state given r, s, a
        action_preds = self.predict_action(h[:,1])  # predict action given r, s

        return state_preds, action_preds, return_preds



def setup_optimizer(model, lr, weight_decay, epochs):
    """
    S4 requires a specific optimizer setup.

    The S4 layer (A, B, C, dt) parameters typically
    require a smaller learning rate (typically 0.001), with no weight decay.

    The rest of the model can be trained with a higher learning rate (e.g. 0.004, 0.01)
    and weight decay (if desired).
    """

    # All parameters in the model
    all_parameters = list(model.parameters())

    # General parameters don't contain the special _optim key
    params = [p for p in all_parameters if not hasattr(p, "_optim")]

    # Create an optimizer with the general parameters
    optimizer = optim.AdamW(params, lr=lr, weight_decay=weight_decay)

    # Add parameters with special hyperparameters
    hps = [getattr(p, "_optim") for p in all_parameters if hasattr(p, "_optim")]
    hps = [
        dict(s) for s in sorted(list(dict.fromkeys(frozenset(hp.items()) for hp in hps)))
    ]  # Unique dicts
    for hp in hps:
        params = [p for p in all_parameters if getattr(p, "_optim", None) == hp]
        optimizer.add_param_group(
            {"params": params, **hp}
        )

    # Create a lr scheduler
    # scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=patience, factor=0.2)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, epochs)

    # Print optimizer info
    keys = sorted(set([k for hp in hps for k in hp.keys()]))
    for i, g in enumerate(optimizer.param_groups):
        group_hps = {k: g.get(k, None) for k in keys}
        print(' | '.join([
            f"Optimizer group {i}",
            f"{len(g['params'])} tensors",
        ] + [f"{k} {v}" for k, v in group_hps.items()]))

    return optimizer, scheduler

# %%
###############################################################################
# Everything after this point is standard PyTorch training!
###############################################################################

# Training
def train():
    model.train()
    train_loss = 0
    correct = 0
    total = 0
    log_action_losses = []
    pbar = tqdm(enumerate(traj_data_loader))
    for batch_idx, (timesteps, states, actions, returns_to_go, traj_mask) in pbar:
        # inputs, targets = inputs.to(device), targets.to(device)
        # optimizer.zero_grad()
        timesteps = timesteps.to(device)	# B x T
        states = states.to(device)			# B x T x state_dim
        actions = actions.to(device)		# B x T x act_dim
        returns_to_go = returns_to_go.to(device).unsqueeze(dim=-1) # B x T x 1
        traj_mask = traj_mask.to(device)	# B x T
        action_target = torch.clone(actions).detach().to(device)
        state_preds, action_preds, return_preds = model.forward(
														timesteps=timesteps,
														states=states,
														actions=actions,
														returns_to_go=returns_to_go
													)

        action_preds = action_preds.view(-1, act_dim)[traj_mask.view(-1,) > 0]
        action_target = action_target.view(-1, act_dim)[traj_mask.view(-1,) > 0]

        # outputs = model(timesteps, states, actions, returns_to_go, traj_mask)
        # action_loss = criterion(action_preds, action_target)

        action_loss = F.mse_loss(action_preds, action_target, reduction='mean')

        action_loss.backward()
        optimizer.step()

        # train_loss += loss.item()
        # _, predicted = outputs.max(1)
        # total += targets.size(0)
        # correct += predicted.eq(targets).sum().item()

        log_action_losses.append(action_loss.detach().cpu().item())

        pbar.set_description(
            'Batch Idx: (%d/%d) | Loss: %.3f' %
            (batch_idx, len(traj_data_loader), log_action_losses[-1])
        )

def evaluate_on_env(model, device, context_len, env, rtg_target, rtg_scale,
                    num_eval_ep=10, max_test_ep_len=1000,
                    state_mean=None, state_std=None, render=False):

    eval_batch_size = 1  # required for forward pass

    results = {}
    total_reward = 0
    total_timesteps = 0

    state_dim = env.observation_space.shape[0]
    act_dim = env.action_space.shape[0]

    if state_mean is None:
        state_mean = torch.zeros((state_dim,)).to(device)
    else:
        state_mean = torch.from_numpy(state_mean).to(device)

    if state_std is None:
        state_std = torch.ones((state_dim,)).to(device)
    else:
        state_std = torch.from_numpy(state_std).to(device)

    # same as timesteps used for training the transformer
    # also, crashes if device is passed to arange()
    timesteps = torch.arange(start=0, end=max_test_ep_len, step=1)
    timesteps = timesteps.repeat(eval_batch_size, 1).to(device)

    model.eval()

    with torch.no_grad():

        for _ in range(num_eval_ep):

            # zeros place holders
            actions = torch.zeros((eval_batch_size, max_test_ep_len, act_dim),
                                dtype=torch.float32, device=device)

            states = torch.zeros((eval_batch_size, max_test_ep_len, state_dim),
                                dtype=torch.float32, device=device)

            rewards_to_go = torch.zeros((eval_batch_size, max_test_ep_len, 1),
                                dtype=torch.float32, device=device)

            # init episode
            running_state = env.reset()
            running_reward = 0
            running_rtg = rtg_target / rtg_scale

            for t in range(max_test_ep_len):

                total_timesteps += 1

                # add state in placeholder and normalize
                states[0, t] = torch.from_numpy(running_state).to(device)
                states[0, t] = (states[0, t] - state_mean) / state_std

                # calcualate running rtg and add in placeholder
                running_rtg = running_rtg - (running_reward / rtg_scale)
                rewards_to_go[0, t] = running_rtg

                if t < context_len:
                    _, act_preds, _ = model.forward(timesteps[:,:context_len],
                                                states[:,:context_len],
                                                actions[:,:context_len],
                                                rewards_to_go[:,:context_len])
                    act = act_preds[0, t].detach()
                else:
                    _, act_preds, _ = model.forward(timesteps[:,t-context_len+1:t+1],
                                                states[:,t-context_len+1:t+1],
                                                actions[:,t-context_len+1:t+1],
                                                rewards_to_go[:,t-context_len+1:t+1])
                    act = act_preds[0, -1].detach()


                running_state, running_reward, done, _ = env.step(act.cpu().numpy())

                # add action in placeholder
                actions[0, t] = act

                total_reward += running_reward

                if render:
                    env.render()
                if done:
                    break

    results['eval/avg_reward'] = total_reward / num_eval_ep
    results['eval/avg_ep_len'] = total_timesteps / num_eval_ep

    return results

def eval(epoch, dataloader, checkpoint=False):
    global best_acc
    model.eval()
    eval_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        pbar = tqdm(enumerate(dataloader))
        for batch_idx, (inputs, targets) in pbar:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)

            eval_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

            log_data = [batch_idx, len(dataloader), eval_loss/(batch_idx+1), 100.*correct/total, correct, total]
            csv_writer.writerow(log_data)

            # pbar.set_description(
            #     'Batch Idx: (%d/%d) | Loss: %.3f | Acc: %.3f%% (%d/%d)' %
            #     (batch_idx, len(dataloader), eval_loss/(batch_idx+1), 100.*correct/total, correct, total)
            # )

    # Save checkpoint.
    if checkpoint:
        acc = 100.*correct/total
        if acc > best_acc:
            state = {
                'model': model.state_dict(),
                'acc': acc,
                'epoch': epoch,
            }
            if not os.path.isdir('/content/drive/MyDrive/6_8200_project/S4/checkpoint'):
                os.mkdir('/content/drive/MyDrive/6_8200_project/S4/checkpoint')
            torch.save(state, '/content/drive/MyDrive/6_8200_project/S4/checkpoint/walker_ckpt.pth')
            best_acc = acc

        return acc

# %%
if tuple(map(int, torch.__version__.split('.')[:2])) == (1, 11):
    print("WARNING: Dropout is bugged in PyTorch 1.11. Results may be worse.")
    dropout_fn = nn.Dropout
if tuple(map(int, torch.__version__.split('.')[:2])) >= (1, 12):
    dropout_fn = nn.Dropout1d
else:
    dropout_fn = nn.Dropout2d

# %% [markdown]
# # D4RL_DATASET_STATS

# %%
## from infos.py from official d4rl github repo

REF_MAX_SCORE = {
    'halfcheetah' : 12135.0,
    'walker2d' : 4592.3,
    'hopper' : 3234.3,
}

REF_MIN_SCORE = {
    'halfcheetah' : -280.178953,
    'walker2d' : 1.629008,
    'hopper' : -20.272305,
}


## calculated from d4rl datasets

D4RL_DATASET_STATS = {
        'halfcheetah-medium-v2': {
                'state_mean':[-0.06845773756504059, 0.016414547339081764, -0.18354906141757965,
                              -0.2762460708618164, -0.34061527252197266, -0.09339715540409088,
                              -0.21321271359920502, -0.0877423882484436, 5.173007488250732,
                              -0.04275195300579071, -0.036108363419771194, 0.14053793251514435,
                              0.060498327016830444, 0.09550975263118744, 0.06739100068807602,
                              0.005627387668937445, 0.013382787816226482
                ],
                'state_std':[0.07472999393939972, 0.3023499846458435, 0.30207309126853943,
                             0.34417077898979187, 0.17619241774082184, 0.507205605506897,
                             0.2567007839679718, 0.3294812738895416, 1.2574149370193481,
                             0.7600541710853577, 1.9800915718078613, 6.565362453460693,
                             7.466367721557617, 4.472222805023193, 10.566964149475098,
                             5.671932697296143, 7.4982590675354
                ]
            },
        'halfcheetah-medium-replay-v2': {
                'state_mean':[-0.12880703806877136, 0.3738119602203369, -0.14995987713336945,
                              -0.23479078710079193, -0.2841278612613678, -0.13096535205841064,
                              -0.20157982409000397, -0.06517726927995682, 3.4768247604370117,
                              -0.02785065770149231, -0.015035249292850494, 0.07697279006242752,
                              0.01266712136566639, 0.027325302362442017, 0.02316424623131752,
                              0.010438721626996994, -0.015839405357837677
                ],
                'state_std':[0.17019015550613403, 1.284424901008606, 0.33442774415016174,
                             0.3672759234905243, 0.26092398166656494, 0.4784106910228729,
                             0.3181420564651489, 0.33552637696266174, 2.0931615829467773,
                             0.8037433624267578, 1.9044333696365356, 6.573209762573242,
                             7.572863578796387, 5.069749355316162, 9.10555362701416,
                             6.085654258728027, 7.25300407409668
                ]
            },
        'halfcheetah-medium-expert-v2': {
                'state_mean':[-0.05667462572455406, 0.024369969964027405, -0.061670560389757156,
                              -0.22351515293121338, -0.2675151228904724, -0.07545716315507889,
                              -0.05809682980179787, -0.027675075456500053, 8.110626220703125,
                              -0.06136331334710121, -0.17986927926540375, 0.25175222754478455,
                              0.24186332523822784, 0.2519369423389435, 0.5879552960395813,
                              -0.24090635776519775, -0.030184272676706314
                ],
                'state_std':[0.06103534251451492, 0.36054104566574097, 0.45544400811195374,
                             0.38476887345314026, 0.2218363732099533, 0.5667523741722107,
                             0.3196682929992676, 0.2852923572063446, 3.443821907043457,
                             0.6728139519691467, 1.8616976737976074, 9.575807571411133,
                             10.029894828796387, 5.903450012207031, 12.128185272216797,
                             6.4811787605285645, 6.378620147705078
                ]
            },
        'walker2d-medium-v2': {
                'state_mean':[1.218966007232666, 0.14163373410701752, -0.03704913705587387,
                              -0.13814310729503632, 0.5138224363327026, -0.04719110205769539,
                              -0.47288352251052856, 0.042254164814949036, 2.3948874473571777,
                              -0.03143199160695076, 0.04466355964541435, -0.023907244205474854,
                              -0.1013401448726654, 0.09090937674045563, -0.004192637279629707,
                              -0.12120571732521057, -0.5497063994407654
                ],
                'state_std':[0.12311358004808426, 0.3241879940032959, 0.11456084251403809,
                             0.2623065710067749, 0.5640279054641724, 0.2271878570318222,
                             0.3837319612503052, 0.7373676896095276, 1.2387926578521729,
                             0.798020601272583, 1.5664079189300537, 1.8092705011367798,
                             3.025604248046875, 4.062486171722412, 1.4586567878723145,
                             3.7445690631866455, 5.5851287841796875
                ]
            },
        'walker2d-medium-replay-v2': {
                'state_mean':[1.209364652633667, 0.13264022767543793, -0.14371201395988464,
                              -0.2046516090631485, 0.5577612519264221, -0.03231537342071533,
                              -0.2784661054611206, 0.19130706787109375, 1.4701707363128662,
                              -0.12504704296588898, 0.0564953051507473, -0.09991033375263214,
                              -0.340340256690979, 0.03546293452382088, -0.08934258669614792,
                              -0.2992438077926636, -0.5984178185462952
                ],
                'state_std':[0.11929835379123688, 0.3562574088573456, 0.25852200388908386,
                             0.42075422406196594, 0.5202291011810303, 0.15685082972049713,
                             0.36770978569984436, 0.7161387801170349, 1.3763766288757324,
                             0.8632221817970276, 2.6364643573760986, 3.0134117603302,
                             3.720684051513672, 4.867283821105957, 2.6681625843048096,
                             3.845186948776245, 5.4768385887146
                ]
            },
        'walker2d-medium-expert-v2': {
                'state_mean':[1.2294334173202515, 0.16869689524173737, -0.07089081406593323,
                              -0.16197483241558075, 0.37101927399635315, -0.012209027074277401,
                              -0.42461398243904114, 0.18986578285694122, 3.162475109100342,
                              -0.018092676997184753, 0.03496946766972542, -0.013921679928898811,
                              -0.05937029421329498, -0.19549426436424255, -0.0019200450042262673,
                              -0.062483321875333786, -0.27366524934768677
                ],
                'state_std':[0.09932824969291687, 0.25981399416923523, 0.15062759816646576,
                             0.24249176681041718, 0.6758718490600586, 0.1650741547346115,
                             0.38140663504600525, 0.6962361335754395, 1.3501490354537964,
                             0.7641991376876831, 1.534574270248413, 2.1785972118377686,
                             3.276582717895508, 4.766193866729736, 1.1716983318328857,
                             4.039782524108887, 5.891613960266113
                ]
            },
        'hopper-medium-v2': {
                'state_mean':[1.311279058456421, -0.08469521254301071, -0.5382719039916992,
                              -0.07201576232910156, 0.04932365566492081, 2.1066856384277344,
                              -0.15017354488372803, 0.008783451281487942, -0.2848185896873474,
                              -0.18540096282958984, -0.28461286425590515
                ],
                'state_std':[0.17790751159191132, 0.05444620922207832, 0.21297138929367065,
                             0.14530418813228607, 0.6124444007873535, 0.8517446517944336,
                             1.4515252113342285, 0.6751695871353149, 1.5362390279769897,
                             1.616074562072754, 5.607253551483154
                ]
            },
        'hopper-medium-replay-v2': {
                'state_mean':[1.2305138111114502, -0.04371410980820656, -0.44542956352233887,
                              -0.09370097517967224, 0.09094487875699997, 1.3694725036621094,
                              -0.19992674887180328, -0.022861352190375328, -0.5287045240402222,
                              -0.14465883374214172, -0.19652697443962097
                ],
                'state_std':[0.1756512075662613, 0.0636928603053093, 0.3438323438167572,
                             0.19566889107227325, 0.5547984838485718, 1.051029920578003,
                             1.158307671546936, 0.7963128685951233, 1.4802359342575073,
                             1.6540331840515137, 5.108601093292236
                ]
            },
        'hopper-medium-expert-v2': {
                'state_mean':[1.3293815851211548, -0.09836531430482864, -0.5444297790527344,
                              -0.10201650857925415, 0.02277466468513012, 2.3577215671539307,
                              -0.06349576264619827, -0.00374026270583272, -0.1766270101070404,
                              -0.11862941086292267, -0.12097819894552231
                ],
                'state_std':[0.17012375593185425, 0.05159067362546921, 0.18141433596611023,
                             0.16430604457855225, 0.6023368239402771, 0.7737284898757935,
                             1.4986555576324463, 0.7483318448066711, 1.7953159809112549,
                             2.0530025959014893, 5.725032806396484
                ]
            },
    }

# %%
def get_d4rl_normalized_score(score, env_name):
    env_key = env_name.split('-')[0].lower()
    assert env_key in REF_MAX_SCORE, f'no reference score for {env_key} env to calculate d4rl score'
    return (score - REF_MIN_SCORE[env_key]) / (REF_MAX_SCORE[env_key] - REF_MIN_SCORE[env_key])

# %%
dataset = "medium"       # medium / medium-replay / medium-expert
rtg_scale = 1000                # scale to normalize returns to go

dataset_path = f'/content/drive/MyDrive/6_8200_project/S4/data/walker2d-medium-v2.pkl'

env_name = 'Walker2d-v3'
rtg_target = 5000
env_s4_name = f'walker2d-{dataset}-v2'

log_dir = "/content/drive/MyDrive/6_8200_project/S4/s4_runs/"
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

device_name = 'cuda'
device = torch.device(device_name)
print("device set to: ", device)
# Out:
# device set to:  cuda

# %% [markdown]
# # TrajectoryLoader for RL loop

# %%
def discount_cumsum(x, gamma):
    disc_cumsum = np.zeros_like(x)
    disc_cumsum[-1] = x[-1]
    for t in reversed(range(x.shape[0]-1)):
        disc_cumsum[t] = x[t] + gamma * disc_cumsum[t+1]
    return disc_cumsum

class D4RLTrajectoryDataset(Dataset):
    def __init__(self, dataset_path, rtg_scale=1000):


        # load dataset
        with open(dataset_path, 'rb') as f:
            self.trajectories = pickle.load(f)

        # calculate min len of traj, state mean and variance
        # and returns_to_go for all traj
        max_len = -10**6
        states = []
        for traj in self.trajectories:
            traj_len = traj['observations'].shape[0]
            max_len = max(max_len, traj_len)
            states.append(traj['observations'])
            # calculate returns to go and rescale them
            traj['returns_to_go'] = discount_cumsum(traj['rewards'], 1.0) / rtg_scale

        self.context_len = max_len
        # used for input normalization
        states = np.concatenate(states, axis=0)
        self.state_mean, self.state_std = np.mean(states, axis=0), np.std(states, axis=0) + 1e-6

        # normalize states
        for traj in self.trajectories:
            traj['observations'] = (traj['observations'] - self.state_mean) / self.state_std


    def get_state_stats(self):
        return self.state_mean, self.state_std

    def __len__(self):
        return len(self.trajectories)

    def __getitem__(self, idx):
        traj = self.trajectories[idx]
        traj_len = traj['observations'].shape[0]
        traj_len = traj['observations'].shape[0]

        if traj_len >= self.context_len:
            # sample random index to slice trajectory
            si = random.randint(0, traj_len - self.context_len)

            states = torch.from_numpy(traj['observations'][si : si + self.context_len])
            actions = torch.from_numpy(traj['actions'][si : si + self.context_len])
            returns_to_go = torch.from_numpy(traj['returns_to_go'][si : si + self.context_len])
            timesteps = torch.arange(start=si, end=si+self.context_len, step=1)

            # all ones since no padding
            traj_mask = torch.ones(self.context_len, dtype=torch.long)

        else:

            padding_len = self.context_len - traj_len
            # print("padding len", padding_len)
            # print("self.context_len len", self.context_len)
            # print("traj_len len", traj_len)
            # padding with zeros
            states = torch.from_numpy(traj['observations'])
            states = torch.cat([states,
                                torch.zeros(([padding_len] + list(states.shape[1:])),
                                dtype=states.dtype)],
                                dim=0)

            actions = torch.from_numpy(traj['actions'])
            actions = torch.cat([actions,
                                torch.zeros(([padding_len] + list(actions.shape[1:])),
                                dtype=actions.dtype)],
                                dim=0)

            returns_to_go = torch.from_numpy(traj['returns_to_go'])
            returns_to_go = torch.cat([returns_to_go,
                                torch.zeros(([padding_len] + list(returns_to_go.shape[1:])),
                                dtype=returns_to_go.dtype)],
                                dim=0)

            timesteps = torch.arange(start=0, end=self.context_len, step=1)

            traj_mask = torch.cat([torch.ones(traj_len, dtype=torch.long),
                                    torch.zeros(padding_len, dtype=torch.long)],
                                    dim=0)

        return  timesteps, states, actions, returns_to_go, traj_mask

# %% [markdown]
# # Train model

# %%
# model_load = '/content/drive/MyDrive/6_8200_project/decision_transformer/dt_runs_keytodoor_1k/dt_keytodoor_model_24-05-07-15-56-27_best.pt'

start_time = datetime.now().replace(microsecond=0)

start_time_str = start_time.strftime("%y-%m-%d-%H-%M-%S")

prefix = "s4_" + env_s4_name

save_model_name =  prefix + "_model_" + start_time_str + ".pt"
save_model_path = os.path.join(log_dir, save_model_name)
save_best_model_path = save_model_path[:-3] + "_best.pt"

log_csv_name = prefix + "_log_" + start_time_str + ".csv"
log_csv_path = os.path.join(log_dir, log_csv_name)


csv_writer = csv.writer(open(log_csv_path, 'a', 1))
csv_header = (["duration", "num_updates", "action_loss",
               "eval_avg_reward", "eval_avg_ep_len", "eval_d4rl_score"])

csv_writer.writerow(csv_header)

lr = 0.01
weight_decay = 0.01
epochs = 100
# dataset = 'cifar10' #, choices=['mnist', 'cifar10']
num_workers = 4
batch_size = 64
n_layers = 4
d_model = 128
dropout = 0.1
prenorm = False
resume = False
warmup_steps = 10000
max_train_iters = 200
num_updates_per_iter = 100


print("=" * 60)
print("start time: " + start_time_str)
print("=" * 60)

print("device set to: " + str(device))
print("dataset path: " + dataset_path)
print("model save path: " + save_model_path)
print("log csv save path: " + log_csv_path)

def collate_fn(data):
    return list(zip(*data))


traj_dataset = D4RLTrajectoryDataset(dataset_path, 1000) # is context len max len in this case??

traj_data_loader = DataLoader(traj_dataset,
						batch_size=batch_size,
						shuffle=True,
						pin_memory=True,
						drop_last=True)



# traj_dataset = D4RLTrajectoryDataset(dataset_path, 1000) walker2d-medium-v2

# traj_data_loader = DataLoader(traj_dataset,
# 						batch_size=batch_size,
# 						shuffle=True,
# 						pin_memory=True,
# 						drop_last=True, collate_fn=collate_fn )

data_iter = iter(traj_data_loader)

# env = KeyToDoorEnv(phase_2_begin=100, phase_3_begin=125, max_steps=T)

env = gym.make(env_name)

state_dim = env.observation_space.shape[0]
act_dim = env.action_space.shape[0]

state_mean, state_std = traj_dataset.get_state_stats()


context_len = 1000

model = S4Model(
    state_dim=state_dim,
    act_dim=act_dim,
    h_dim=d_model,
    context_len=context_len, # what is this?
    dropout=dropout,
    n_layers=n_layers,
    prenorm=prenorm,
)

# if model_load is not None:
# 	print("loading model from: " + model_load)
# 	model.load_state_dict(torch.load(model_load))

optimizer, scheduler = setup_optimizer(
    model, lr=lr, weight_decay=weight_decay, epochs=epochs
)

model = model.to(device)
if device == 'cuda':
    cudnn.benchmark = True

# optimizer = torch.optim.AdamW(
# 					model.parameters(),
# 					lr=lr,
# 					weight_decay=weight_decay
# 				)

# scheduler = torch.optim.lr_scheduler.LambdaLR(
# 		optimizer,
# 		lambda steps: min((steps+1)/warmup_steps, 1)
# 	)

max_s4_score = -np.inf
total_updates = 0
num_eval_ep = 10
max_eval_ep_len = 1000


for i_train_iter in range(max_train_iters):
    model.train()

    train_loss = 0
    correct = 0
    total = 0
    log_action_losses = []
    pbar = tqdm(enumerate(traj_data_loader))
    for batch_idx, (timesteps, states, actions, returns_to_go, traj_mask) in pbar:
        # inputs, targets = inputs.to(device), targets.to(device)
        # optimizer.zero_grad()
        timesteps = timesteps.to(device)	# B x T
        states = states.to(device)			# B x T x state_dim
        actions = actions.to(device)		# B x T x act_dim
        returns_to_go = returns_to_go.to(device).unsqueeze(dim=-1) # B x T x 1
        traj_mask = traj_mask.to(device)	# B x T
        action_target = torch.clone(actions).detach().to(device)
        state_preds, action_preds, return_preds = model.forward(
														timesteps=timesteps,
														states=states,
														actions=actions,
														returns_to_go=returns_to_go
													)

        action_preds = action_preds.view(-1, act_dim)[traj_mask.view(-1,) > 0]
        action_target = action_target.view(-1, act_dim)[traj_mask.view(-1,) > 0]

        # outputs = model(timesteps, states, actions, returns_to_go, traj_mask)
        # action_loss = criterion(action_preds, action_target)

        action_loss = F.mse_loss(action_preds, action_target, reduction='mean')

        action_loss.backward()
        optimizer.step()

        # train_loss += loss.item()
        # _, predicted = outputs.max(1)
        # total += targets.size(0)
        # correct += predicted.eq(targets).sum().item()

        log_action_losses.append(action_loss.detach().cpu().item())

        pbar.set_description(
            'Batch Idx: (%d/%d) | Loss: %.3f' %
            (batch_idx, len(trainloader), log_action_losses[-1])
        )
        log_action_losses.append(action_loss.detach().cpu().item())
    # evaluate on env
    results = evaluate_on_env(model, device, context_len, env, rtg_target, rtg_scale,
                            num_eval_ep, max_eval_ep_len, state_mean, state_std,
                            )
    eval_avg_reward = results['eval/avg_reward']
    eval_avg_ep_len = results['eval/avg_ep_len']
    eval_s4_score = get_d4rl_normalized_score(results['eval/avg_reward'], env_name) * 100

    mean_action_loss = np.mean(log_action_losses)
    time_elapsed = str(datetime.now().replace(microsecond=0) - start_time)

    total_updates += num_updates_per_iter

    log_str = ("=" * 60 + '\n' +
            "time elapsed: " + time_elapsed  + '\n' +
            "num of updates: " + str(total_updates) + '\n' +
            "action loss: " +  format(mean_action_loss, ".5f") + '\n' +
            "eval avg reward: " + format(eval_avg_reward, ".5f") + '\n' +
            "eval avg ep len: " + format(eval_avg_ep_len, ".5f") + '\n' +
            "eval s4 score: " + format(eval_s4_score, ".5f")
            )

    print(log_str)

    log_data = [time_elapsed, total_updates, mean_action_loss,
                eval_avg_reward, eval_avg_ep_len,
                eval_s4_score]

    csv_writer.writerow(log_data)

    # save model
    print("max s4 score: " + format(max_s4_score, ".5f"))
    if eval_s4_score >= max_s4_score:
        print("saving max s4 score model at: " + save_best_model_path)
        torch.save(model.state_dict(), save_best_model_path)
        max_s4_score = eval_s4_score

    print("saving current model at: " + save_model_path)
    torch.save(model.state_dict(), save_model_path)

print("=" * 60)
print("finished training!")
print("=" * 60)
end_time = datetime.now().replace(microsecond=0)
time_elapsed = str(end_time - start_time)
end_time_str = end_time.strftime("%y-%m-%d-%H-%M-%S")
print("started training at: " + start_time_str)
print("finished training at: " + end_time_str)
print("total training time: " + time_elapsed)
print("max score: " + format(max_s4_score, ".5f"))
print("saved max score model at: " + save_best_model_path)
print("saved last updated model at: " + save_model_path)
print("=" * 60)

# csv_writer.close()
# Out:
# ============================================================
# start time: 24-05-12-22-49-03
# ============================================================
# device set to: cuda
# dataset path: /content/drive/MyDrive/6_8200_project/S4/data/walker2d-medium-v2.pkl
# model save path: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# log csv save path: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_log_24-05-12-22-49-03.csv
# Optimizer group 0 | 39 tensors | lr 0.01 | weight_decay 0.01
# Optimizer group 1 | 12 tensors | lr 0.001 | weight_decay 0.0
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:00:16
# num of updates: 100
# action loss: 0.35597
# eval avg reward: -10.32246
# eval avg ep len: 103.00000
# eval s4 score: -0.26034
# max s4 score: -inf
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:00:36
# num of updates: 200
# action loss: 0.48611
# eval avg reward: 82.88550
# eval avg ep len: 151.90000
# eval s4 score: 1.77004
# max s4 score: -0.26034
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:00:54
# num of updates: 300
# action loss: 0.55160
# eval avg reward: 27.57599
# eval avg ep len: 135.60000
# eval s4 score: 0.56521
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:01:10
# num of updates: 400
# action loss: 0.60330
# eval avg reward: 25.24828
# eval avg ep len: 121.20000
# eval s4 score: 0.51451
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:01:21
# num of updates: 500
# action loss: 0.55976
# eval avg reward: -8.09399
# eval avg ep len: 66.70000
# eval s4 score: -0.21180
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:01:31
# num of updates: 600
# action loss: 0.65628
# eval avg reward: -6.94613
# eval avg ep len: 67.30000
# eval s4 score: -0.18679
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:01:41
# num of updates: 700
# action loss: 0.61848
# eval avg reward: -8.01709
# eval avg ep len: 66.40000
# eval s4 score: -0.21012
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:01:53
# num of updates: 800
# action loss: 0.57445
# eval avg reward: -21.49493
# eval avg ep len: 75.30000
# eval s4 score: -0.50372
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:02:04
# num of updates: 900
# action loss: 0.56639
# eval avg reward: -18.02740
# eval avg ep len: 69.90000
# eval s4 score: -0.42818
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:02:14
# num of updates: 1000
# action loss: 0.57140
# eval avg reward: -20.50312
# eval avg ep len: 70.30000
# eval s4 score: -0.48211
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:02:25
# num of updates: 1100
# action loss: 0.56212
# eval avg reward: -21.75345
# eval avg ep len: 70.80000
# eval s4 score: -0.50935
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:02:39
# num of updates: 1200
# action loss: 0.54848
# eval avg reward: -0.58310
# eval avg ep len: 100.40000
# eval s4 score: -0.04819
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:02:59
# num of updates: 1300
# action loss: 0.53752
# eval avg reward: 53.80489
# eval avg ep len: 158.70000
# eval s4 score: 1.13656
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:03:13
# num of updates: 1400
# action loss: 0.52848
# eval avg reward: 11.71975
# eval avg ep len: 99.00000
# eval s4 score: 0.21981
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:03:24
# num of updates: 1500
# action loss: 0.52126
# eval avg reward: -6.35554
# eval avg ep len: 77.50000
# eval s4 score: -0.17393
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:03:35
# num of updates: 1600
# action loss: 0.51577
# eval avg reward: -11.46004
# eval avg ep len: 67.70000
# eval s4 score: -0.28512
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:03:45
# num of updates: 1700
# action loss: 0.52231
# eval avg reward: -11.76451
# eval avg ep len: 68.10000
# eval s4 score: -0.29176
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:03:55
# num of updates: 1800
# action loss: 0.50303
# eval avg reward: -8.37903
# eval avg ep len: 67.60000
# eval s4 score: -0.21801
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:04:06
# num of updates: 1900
# action loss: 0.49683
# eval avg reward: -8.07027
# eval avg ep len: 67.40000
# eval s4 score: -0.21128
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:04:16
# num of updates: 2000
# action loss: 0.50047
# eval avg reward: -7.81898
# eval avg ep len: 67.40000
# eval s4 score: -0.20581
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:04:27
# num of updates: 2100
# action loss: 0.49979
# eval avg reward: -8.29356
# eval avg ep len: 67.40000
# eval s4 score: -0.21615
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:04:37
# num of updates: 2200
# action loss: 0.49692
# eval avg reward: -7.03444
# eval avg ep len: 66.60000
# eval s4 score: -0.18872
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:04:47
# num of updates: 2300
# action loss: 0.49368
# eval avg reward: -8.31843
# eval avg ep len: 67.40000
# eval s4 score: -0.21669
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:04:58
# num of updates: 2400
# action loss: 0.49218
# eval avg reward: -7.48745
# eval avg ep len: 67.00000
# eval s4 score: -0.19859
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:05:08
# num of updates: 2500
# action loss: 0.49096
# eval avg reward: -7.61243
# eval avg ep len: 67.20000
# eval s4 score: -0.20131
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:05:18
# num of updates: 2600
# action loss: 0.49098
# eval avg reward: -8.28613
# eval avg ep len: 67.50000
# eval s4 score: -0.21598
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:05:29
# num of updates: 2700
# action loss: 0.49061
# eval avg reward: -8.74022
# eval avg ep len: 67.50000
# eval s4 score: -0.22588
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:05:39
# num of updates: 2800
# action loss: 0.49130
# eval avg reward: -7.31526
# eval avg ep len: 67.10000
# eval s4 score: -0.19484
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:05:51
# num of updates: 2900
# action loss: 0.49013
# eval avg reward: -0.33431
# eval avg ep len: 77.60000
# eval s4 score: -0.04277
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:06:01
# num of updates: 3000
# action loss: 0.48878
# eval avg reward: -7.97309
# eval avg ep len: 67.10000
# eval s4 score: -0.20917
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:06:11
# num of updates: 3100
# action loss: 0.48790
# eval avg reward: -7.82231
# eval avg ep len: 67.10000
# eval s4 score: -0.20588
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:06:23
# num of updates: 3200
# action loss: 0.48770
# eval avg reward: 2.07308
# eval avg ep len: 81.40000
# eval s4 score: 0.00967
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:06:38
# num of updates: 3300
# action loss: 0.48520
# eval avg reward: 23.32341
# eval avg ep len: 103.10000
# eval s4 score: 0.47258
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:06:56
# num of updates: 3400
# action loss: 0.48412
# eval avg reward: 48.81856
# eval avg ep len: 139.00000
# eval s4 score: 1.02794
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:07:18
# num of updates: 3500
# action loss: 0.48284
# eval avg reward: 68.13444
# eval avg ep len: 177.40000
# eval s4 score: 1.44871
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:07:41
# num of updates: 3600
# action loss: 0.48165
# eval avg reward: 73.82903
# eval avg ep len: 183.90000
# eval s4 score: 1.57276
# max s4 score: 1.77004
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:08:06
# num of updates: 3700
# action loss: 0.47988
# eval avg reward: 83.96097
# eval avg ep len: 197.40000
# eval s4 score: 1.79346
# max s4 score: 1.77004
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:08:33
# num of updates: 3800
# action loss: 0.47831
# eval avg reward: 102.95767
# eval avg ep len: 216.90000
# eval s4 score: 2.20727
# max s4 score: 1.79346
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:08:58
# num of updates: 3900
# action loss: 0.47622
# eval avg reward: 107.71729
# eval avg ep len: 201.80000
# eval s4 score: 2.31095
# max s4 score: 2.20727
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:09:23
# num of updates: 4000
# action loss: 0.47536
# eval avg reward: 98.00734
# eval avg ep len: 200.20000
# eval s4 score: 2.09944
# max s4 score: 2.31095
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:09:47
# num of updates: 4100
# action loss: 0.47396
# eval avg reward: 87.34921
# eval avg ep len: 190.20000
# eval s4 score: 1.86727
# max s4 score: 2.31095
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:10:09
# num of updates: 4200
# action loss: 0.47328
# eval avg reward: 85.99412
# eval avg ep len: 175.60000
# eval s4 score: 1.83775
# max s4 score: 2.31095
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:10:28
# num of updates: 4300
# action loss: 0.47264
# eval avg reward: 63.48746
# eval avg ep len: 153.70000
# eval s4 score: 1.34748
# max s4 score: 2.31095
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:10:58
# num of updates: 4400
# action loss: 0.47284
# eval avg reward: 145.98279
# eval avg ep len: 244.20000
# eval s4 score: 3.14450
# max s4 score: 2.31095
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:11:23
# num of updates: 4500
# action loss: 0.47194
# eval avg reward: 93.43663
# eval avg ep len: 199.70000
# eval s4 score: 1.99987
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:11:45
# num of updates: 4600
# action loss: 0.47106
# eval avg reward: 80.12239
# eval avg ep len: 179.00000
# eval s4 score: 1.70985
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:12:04
# num of updates: 4700
# action loss: 0.47135
# eval avg reward: 48.51175
# eval avg ep len: 139.10000
# eval s4 score: 1.02126
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:12:24
# num of updates: 4800
# action loss: 0.47170
# eval avg reward: 59.56508
# eval avg ep len: 157.80000
# eval s4 score: 1.26204
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:12:47
# num of updates: 4900
# action loss: 0.47103
# eval avg reward: 81.21783
# eval avg ep len: 179.10000
# eval s4 score: 1.73371
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:13:09
# num of updates: 5000
# action loss: 0.47077
# eval avg reward: 83.38808
# eval avg ep len: 178.30000
# eval s4 score: 1.78098
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:13:33
# num of updates: 5100
# action loss: 0.47006
# eval avg reward: 86.30711
# eval avg ep len: 196.40000
# eval s4 score: 1.84457
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:13:52
# num of updates: 5200
# action loss: 0.47005
# eval avg reward: 49.58017
# eval avg ep len: 138.70000
# eval s4 score: 1.04453
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:14:12
# num of updates: 5300
# action loss: 0.46941
# eval avg reward: 71.82422
# eval avg ep len: 159.40000
# eval s4 score: 1.52908
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:14:31
# num of updates: 5400
# action loss: 0.46885
# eval avg reward: 49.88655
# eval avg ep len: 148.10000
# eval s4 score: 1.05121
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:14:58
# num of updates: 5500
# action loss: 0.46822
# eval avg reward: 112.60359
# eval avg ep len: 220.30000
# eval s4 score: 2.41739
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:15:22
# num of updates: 5600
# action loss: 0.46744
# eval avg reward: 82.98657
# eval avg ep len: 185.20000
# eval s4 score: 1.77224
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:15:43
# num of updates: 5700
# action loss: 0.46693
# eval avg reward: 66.36029
# eval avg ep len: 167.90000
# eval s4 score: 1.41006
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:16:03
# num of updates: 5800
# action loss: 0.46669
# eval avg reward: 56.58527
# eval avg ep len: 154.50000
# eval s4 score: 1.19713
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:16:23
# num of updates: 5900
# action loss: 0.46625
# eval avg reward: 60.04735
# eval avg ep len: 155.10000
# eval s4 score: 1.27254
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:16:41
# num of updates: 6000
# action loss: 0.46543
# eval avg reward: 53.09359
# eval avg ep len: 140.40000
# eval s4 score: 1.12107
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:17:04
# num of updates: 6100
# action loss: 0.46521
# eval avg reward: 95.02768
# eval avg ep len: 180.90000
# eval s4 score: 2.03453
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:17:23
# num of updates: 6200
# action loss: 0.46452
# eval avg reward: 91.81876
# eval avg ep len: 149.70000
# eval s4 score: 1.96463
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:17:46
# num of updates: 6300
# action loss: 0.46436
# eval avg reward: 144.72075
# eval avg ep len: 184.50000
# eval s4 score: 3.11701
# max s4 score: 3.14450
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:18:11
# num of updates: 6400
# action loss: 0.46378
# eval avg reward: 168.05104
# eval avg ep len: 200.30000
# eval s4 score: 3.62522
# max s4 score: 3.14450
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:18:38
# num of updates: 6500
# action loss: 0.46354
# eval avg reward: 212.52949
# eval avg ep len: 222.80000
# eval s4 score: 4.59411
# max s4 score: 3.62522
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:19:03
# num of updates: 6600
# action loss: 0.46300
# eval avg reward: 171.71504
# eval avg ep len: 194.80000
# eval s4 score: 3.70504
# max s4 score: 4.59411
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:19:31
# num of updates: 6700
# action loss: 0.46317
# eval avg reward: 287.44335
# eval avg ep len: 232.00000
# eval s4 score: 6.22598
# max s4 score: 4.59411
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:20:00
# num of updates: 6800
# action loss: 0.46276
# eval avg reward: 274.62076
# eval avg ep len: 237.60000
# eval s4 score: 5.94666
# max s4 score: 6.22598
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:20:34
# num of updates: 6900
# action loss: 0.46233
# eval avg reward: 371.67190
# eval avg ep len: 283.80000
# eval s4 score: 8.06076
# max s4 score: 6.22598
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:21:01
# num of updates: 7000
# action loss: 0.46218
# eval avg reward: 300.20794
# eval avg ep len: 218.10000
# eval s4 score: 6.50404
# max s4 score: 8.06076
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:21:30
# num of updates: 7100
# action loss: 0.46206
# eval avg reward: 313.46234
# eval avg ep len: 240.90000
# eval s4 score: 6.79276
# max s4 score: 8.06076
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:22:02
# num of updates: 7200
# action loss: 0.46134
# eval avg reward: 373.29383
# eval avg ep len: 272.20000
# eval s4 score: 8.09609
# max s4 score: 8.06076
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:22:36
# num of updates: 7300
# action loss: 0.46097
# eval avg reward: 343.66037
# eval avg ep len: 276.20000
# eval s4 score: 7.45057
# max s4 score: 8.09609
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:23:10
# num of updates: 7400
# action loss: 0.46070
# eval avg reward: 370.17307
# eval avg ep len: 291.40000
# eval s4 score: 8.02811
# max s4 score: 8.09609
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:23:43
# num of updates: 7500
# action loss: 0.46040
# eval avg reward: 350.70639
# eval avg ep len: 276.10000
# eval s4 score: 7.60406
# max s4 score: 8.09609
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:24:13
# num of updates: 7600
# action loss: 0.46081
# eval avg reward: 339.81403
# eval avg ep len: 246.20000
# eval s4 score: 7.36679
# max s4 score: 8.09609
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:24:43
# num of updates: 7700
# action loss: 0.45996
# eval avg reward: 332.24713
# eval avg ep len: 245.60000
# eval s4 score: 7.20196
# max s4 score: 8.09609
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:25:13
# num of updates: 7800
# action loss: 0.45980
# eval avg reward: 356.67599
# eval avg ep len: 252.40000
# eval s4 score: 7.73410
# max s4 score: 8.09609
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:25:42
# num of updates: 7900
# action loss: 0.46016
# eval avg reward: 365.58273
# eval avg ep len: 235.20000
# eval s4 score: 7.92812
# max s4 score: 8.09609
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:26:19
# num of updates: 8000
# action loss: 0.45957
# eval avg reward: 460.96767
# eval avg ep len: 314.80000
# eval s4 score: 10.00592
# max s4 score: 8.09609
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:26:53
# num of updates: 8100
# action loss: 0.45864
# eval avg reward: 386.69117
# eval avg ep len: 285.90000
# eval s4 score: 8.38793
# max s4 score: 10.00592
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:27:21
# num of updates: 8200
# action loss: 0.45916
# eval avg reward: 333.26904
# eval avg ep len: 222.40000
# eval s4 score: 7.22422
# max s4 score: 10.00592
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:27:55
# num of updates: 8300
# action loss: 0.45933
# eval avg reward: 422.32242
# eval avg ep len: 289.30000
# eval s4 score: 9.16409
# max s4 score: 10.00592
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:28:28
# num of updates: 8400
# action loss: 0.45936
# eval avg reward: 493.12607
# eval avg ep len: 273.60000
# eval s4 score: 10.70643
# max s4 score: 10.00592
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:29:02
# num of updates: 8500
# action loss: 0.45913
# eval avg reward: 435.11205
# eval avg ep len: 283.00000
# eval s4 score: 9.44269
# max s4 score: 10.70643
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:29:32
# num of updates: 8600
# action loss: 0.45866
# eval avg reward: 368.05577
# eval avg ep len: 248.50000
# eval s4 score: 7.98199
# max s4 score: 10.70643
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:30:05
# num of updates: 8700
# action loss: 0.45804
# eval avg reward: 460.71578
# eval avg ep len: 276.80000
# eval s4 score: 10.00043
# max s4 score: 10.70643
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:30:32
# num of updates: 8800
# action loss: 0.45832
# eval avg reward: 379.44809
# eval avg ep len: 215.50000
# eval s4 score: 8.23015
# max s4 score: 10.70643
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:31:05
# num of updates: 8900
# action loss: 0.45833
# eval avg reward: 322.49797
# eval avg ep len: 277.00000
# eval s4 score: 6.98959
# max s4 score: 10.70643
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:31:38
# num of updates: 9000
# action loss: 0.45807
# eval avg reward: 410.66312
# eval avg ep len: 274.40000
# eval s4 score: 8.91012
# max s4 score: 10.70643
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:32:14
# num of updates: 9100
# action loss: 0.45780
# eval avg reward: 425.15134
# eval avg ep len: 307.60000
# eval s4 score: 9.22572
# max s4 score: 10.70643
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:32:44
# num of updates: 9200
# action loss: 0.45770
# eval avg reward: 379.43350
# eval avg ep len: 243.70000
# eval s4 score: 8.22983
# max s4 score: 10.70643
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:33:15
# num of updates: 9300
# action loss: 0.45791
# eval avg reward: 366.78608
# eval avg ep len: 257.90000
# eval s4 score: 7.95433
# max s4 score: 10.70643
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:33:47
# num of updates: 9400
# action loss: 0.45748
# eval avg reward: 387.85832
# eval avg ep len: 260.40000
# eval s4 score: 8.41335
# max s4 score: 10.70643
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:34:21
# num of updates: 9500
# action loss: 0.45736
# eval avg reward: 503.71346
# eval avg ep len: 291.20000
# eval s4 score: 10.93706
# max s4 score: 10.70643
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:34:51
# num of updates: 9600
# action loss: 0.45737
# eval avg reward: 401.60329
# eval avg ep len: 248.80000
# eval s4 score: 8.71276
# max s4 score: 10.93706
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:35:27
# num of updates: 9700
# action loss: 0.45687
# eval avg reward: 489.40131
# eval avg ep len: 299.70000
# eval s4 score: 10.62529
# max s4 score: 10.93706
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:35:53
# num of updates: 9800
# action loss: 0.45671
# eval avg reward: 423.22548
# eval avg ep len: 214.60000
# eval s4 score: 9.18377
# max s4 score: 10.93706
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:36:23
# num of updates: 9900
# action loss: 0.45657
# eval avg reward: 430.37725
# eval avg ep len: 247.80000
# eval s4 score: 9.33956
# max s4 score: 10.93706
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:36:50
# num of updates: 10000
# action loss: 0.45643
# eval avg reward: 403.64899
# eval avg ep len: 214.00000
# eval s4 score: 8.75733
# max s4 score: 10.93706
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:37:18
# num of updates: 10100
# action loss: 0.45617
# eval avg reward: 460.21834
# eval avg ep len: 231.30000
# eval s4 score: 9.98959
# max s4 score: 10.93706
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:37:53
# num of updates: 10200
# action loss: 0.45648
# eval avg reward: 505.37005
# eval avg ep len: 289.60000
# eval s4 score: 10.97315
# max s4 score: 10.93706
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:38:27
# num of updates: 10300
# action loss: 0.45643
# eval avg reward: 479.53954
# eval avg ep len: 286.70000
# eval s4 score: 10.41047
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:38:58
# num of updates: 10400
# action loss: 0.45527
# eval avg reward: 444.03399
# eval avg ep len: 260.60000
# eval s4 score: 9.63704
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:39:27
# num of updates: 10500
# action loss: 0.45592
# eval avg reward: 458.75050
# eval avg ep len: 237.50000
# eval s4 score: 9.95762
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:40:00
# num of updates: 10600
# action loss: 0.45493
# eval avg reward: 436.71366
# eval avg ep len: 272.80000
# eval s4 score: 9.47758
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:40:30
# num of updates: 10700
# action loss: 0.45558
# eval avg reward: 453.84329
# eval avg ep len: 249.50000
# eval s4 score: 9.85072
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:41:02
# num of updates: 10800
# action loss: 0.45485
# eval avg reward: 451.51397
# eval avg ep len: 268.40000
# eval s4 score: 9.79998
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:41:34
# num of updates: 10900
# action loss: 0.45507
# eval avg reward: 343.95196
# eval avg ep len: 266.60000
# eval s4 score: 7.45693
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:42:03
# num of updates: 11000
# action loss: 0.45515
# eval avg reward: 353.11065
# eval avg ep len: 238.40000
# eval s4 score: 7.65643
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:42:37
# num of updates: 11100
# action loss: 0.45464
# eval avg reward: 428.53100
# eval avg ep len: 286.90000
# eval s4 score: 9.29934
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:43:04
# num of updates: 11200
# action loss: 0.45455
# eval avg reward: 375.58653
# eval avg ep len: 214.80000
# eval s4 score: 8.14603
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:43:35
# num of updates: 11300
# action loss: 0.45534
# eval avg reward: 365.34284
# eval avg ep len: 256.50000
# eval s4 score: 7.92289
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:44:02
# num of updates: 11400
# action loss: 0.45461
# eval avg reward: 401.31068
# eval avg ep len: 226.80000
# eval s4 score: 8.70639
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:44:30
# num of updates: 11500
# action loss: 0.45436
# eval avg reward: 397.41679
# eval avg ep len: 224.50000
# eval s4 score: 8.62157
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:45:00
# num of updates: 11600
# action loss: 0.45419
# eval avg reward: 303.83958
# eval avg ep len: 249.70000
# eval s4 score: 6.58315
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:45:34
# num of updates: 11700
# action loss: 0.45453
# eval avg reward: 419.90778
# eval avg ep len: 286.70000
# eval s4 score: 9.11150
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:46:04
# num of updates: 11800
# action loss: 0.45436
# eval avg reward: 381.87457
# eval avg ep len: 246.60000
# eval s4 score: 8.28301
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:46:34
# num of updates: 11900
# action loss: 0.45394
# eval avg reward: 342.25662
# eval avg ep len: 247.70000
# eval s4 score: 7.42000
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:47:02
# num of updates: 12000
# action loss: 0.45370
# eval avg reward: 391.89787
# eval avg ep len: 233.30000
# eval s4 score: 8.50135
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:47:31
# num of updates: 12100
# action loss: 0.45382
# eval avg reward: 350.93082
# eval avg ep len: 238.40000
# eval s4 score: 7.60895
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:47:59
# num of updates: 12200
# action loss: 0.45411
# eval avg reward: 350.19763
# eval avg ep len: 227.50000
# eval s4 score: 7.59298
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:48:29
# num of updates: 12300
# action loss: 0.45381
# eval avg reward: 309.03764
# eval avg ep len: 246.60000
# eval s4 score: 6.69638
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 0:48:57
# num of updates: 12400
# action loss: 0.45380
# eval avg reward: 244.33541
# eval avg ep len: 230.00000
# eval s4 score: 5.28695
# max s4 score: 10.97315
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# ...
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:08:52
# num of updates: 16000
# action loss: 0.45194
# eval avg reward: 496.84526
# eval avg ep len: 327.00000
# eval s4 score: 10.78745
# max s4 score: 12.58641
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:09:33
# num of updates: 16100
# action loss: 0.45185
# eval avg reward: 553.86835
# eval avg ep len: 347.10000
# eval s4 score: 12.02960
# max s4 score: 12.58641
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:10:13
# num of updates: 16200
# action loss: 0.45147
# eval avg reward: 541.87081
# eval avg ep len: 342.90000
# eval s4 score: 11.76825
# max s4 score: 12.58641
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:10:58
# num of updates: 16300
# action loss: 0.45224
# eval avg reward: 538.29486
# eval avg ep len: 390.90000
# eval s4 score: 11.69036
# max s4 score: 12.58641
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:11:41
# num of updates: 16400
# action loss: 0.45153
# eval avg reward: 592.33485
# eval avg ep len: 359.70000
# eval s4 score: 12.86753
# max s4 score: 12.58641
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:12:23
# num of updates: 16500
# action loss: 0.45156
# eval avg reward: 509.27893
# eval avg ep len: 363.10000
# eval s4 score: 11.05829
# max s4 score: 12.86753
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:13:04
# num of updates: 16600
# action loss: 0.45150
# eval avg reward: 481.21336
# eval avg ep len: 347.50000
# eval s4 score: 10.44693
# max s4 score: 12.86753
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:13:42
# num of updates: 16700
# action loss: 0.45195
# eval avg reward: 476.37543
# eval avg ep len: 316.70000
# eval s4 score: 10.34155
# max s4 score: 12.86753
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:14:18
# num of updates: 16800
# action loss: 0.45054
# eval avg reward: 425.40850
# eval avg ep len: 306.30000
# eval s4 score: 9.23132
# max s4 score: 12.86753
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:14:53
# num of updates: 16900
# action loss: 0.45180
# eval avg reward: 496.85206
# eval avg ep len: 294.30000
# eval s4 score: 10.78760
# max s4 score: 12.86753
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:15:40
# num of updates: 17000
# action loss: 0.45114
# eval avg reward: 568.99784
# eval avg ep len: 401.40000
# eval s4 score: 12.35917
# max s4 score: 12.86753
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:16:26
# num of updates: 17100
# action loss: 0.45160
# eval avg reward: 729.56257
# eval avg ep len: 404.80000
# eval s4 score: 15.85680
# max s4 score: 12.86753
# saving max s4 score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:17:10
# num of updates: 17200
# action loss: 0.45160
# eval avg reward: 519.97670
# eval avg ep len: 367.50000
# eval s4 score: 11.29133
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:17:48
# num of updates: 17300
# action loss: 0.45138
# eval avg reward: 511.11443
# eval avg ep len: 329.30000
# eval s4 score: 11.09828
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:18:32
# num of updates: 17400
# action loss: 0.45132
# eval avg reward: 480.84182
# eval avg ep len: 372.80000
# eval s4 score: 10.43884
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:19:20
# num of updates: 17500
# action loss: 0.45194
# eval avg reward: 572.54183
# eval avg ep len: 416.20000
# eval s4 score: 12.43637
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:20:00
# num of updates: 17600
# action loss: 0.45198
# eval avg reward: 471.10746
# eval avg ep len: 337.60000
# eval s4 score: 10.22679
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:20:46
# num of updates: 17700
# action loss: 0.45160
# eval avg reward: 631.45314
# eval avg ep len: 397.10000
# eval s4 score: 13.71965
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:21:31
# num of updates: 17800
# action loss: 0.45092
# eval avg reward: 544.49680
# eval avg ep len: 391.10000
# eval s4 score: 11.82546
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:22:14
# num of updates: 17900
# action loss: 0.45130
# eval avg reward: 529.56322
# eval avg ep len: 366.10000
# eval s4 score: 11.50015
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:22:54
# num of updates: 18000
# action loss: 0.45190
# eval avg reward: 457.96691
# eval avg ep len: 336.50000
# eval s4 score: 9.94055
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:23:38
# num of updates: 18100
# action loss: 0.45171
# eval avg reward: 484.42133
# eval avg ep len: 372.80000
# eval s4 score: 10.51681
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:24:15
# num of updates: 18200
# action loss: 0.45088
# eval avg reward: 458.63804
# eval avg ep len: 315.00000
# eval s4 score: 9.95517
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:24:56
# num of updates: 18300
# action loss: 0.45109
# eval avg reward: 519.33804
# eval avg ep len: 350.40000
# eval s4 score: 11.27742
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:25:39
# num of updates: 18400
# action loss: 0.45092
# eval avg reward: 524.53922
# eval avg ep len: 364.90000
# eval s4 score: 11.39071
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:26:19
# num of updates: 18500
# action loss: 0.45153
# eval avg reward: 453.41815
# eval avg ep len: 346.30000
# eval s4 score: 9.84146
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:26:55
# num of updates: 18600
# action loss: 0.45126
# eval avg reward: 474.50649
# eval avg ep len: 298.00000
# eval s4 score: 10.30084
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:27:35
# num of updates: 18700
# action loss: 0.45150
# eval avg reward: 469.36109
# eval avg ep len: 339.10000
# eval s4 score: 10.18875
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:28:08
# num of updates: 18800
# action loss: 0.45198
# eval avg reward: 403.75326
# eval avg ep len: 281.90000
# eval s4 score: 8.75960
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:28:48
# num of updates: 18900
# action loss: 0.45180
# eval avg reward: 500.49838
# eval avg ep len: 334.50000
# eval s4 score: 10.86703
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:29:26
# num of updates: 19000
# action loss: 0.45159
# eval avg reward: 496.87689
# eval avg ep len: 327.50000
# eval s4 score: 10.78814
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:29:59
# num of updates: 19100
# action loss: 0.45146
# eval avg reward: 453.08482
# eval avg ep len: 276.80000
# eval s4 score: 9.83420
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:30:37
# num of updates: 19200
# action loss: 0.45171
# eval avg reward: 475.79196
# eval avg ep len: 322.20000
# eval s4 score: 10.32884
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:31:02
# num of updates: 19300
# action loss: 0.45186
# eval avg reward: 412.52844
# eval avg ep len: 199.70000
# eval s4 score: 8.95075
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:31:32
# num of updates: 19400
# action loss: 0.45230
# eval avg reward: 520.50117
# eval avg ep len: 251.40000
# eval s4 score: 11.30275
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:32:07
# num of updates: 19500
# action loss: 0.45144
# eval avg reward: 577.76694
# eval avg ep len: 294.70000
# eval s4 score: 12.55019
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:32:49
# num of updates: 19600
# action loss: 0.45127
# eval avg reward: 627.51956
# eval avg ep len: 353.60000
# eval s4 score: 13.63397
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:33:21
# num of updates: 19700
# action loss: 0.45138
# eval avg reward: 504.21983
# eval avg ep len: 268.40000
# eval s4 score: 10.94809
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:33:47
# num of updates: 19800
# action loss: 0.45144
# eval avg reward: 444.11089
# eval avg ep len: 214.00000
# eval s4 score: 9.63872
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:34:17
# num of updates: 19900
# action loss: 0.45082
# eval avg reward: 488.75333
# eval avg ep len: 252.40000
# eval s4 score: 10.61118
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# 0it [00:00, ?it/s]
# ============================================================
# time elapsed: 1:34:42
# num of updates: 20000
# action loss: 0.45185
# eval avg reward: 457.06613
# eval avg ep len: 200.60000
# eval s4 score: 9.92093
# max s4 score: 15.85680
# saving current model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# ============================================================
# finished training!
# ============================================================
# started training at: 24-05-12-22-49-03
# finished training at: 24-05-13-00-23-45
# total training time: 1:34:42
# max score: 15.85680
# saved max score model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03_best.pt
# saved last updated model at: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# ============================================================

# %%
# set mujoco env path if not already set
# %env LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin


eval_dataset = "medium"		# medium / medium-replay / medium-expert
eval_rtg_scale = 1000		# normalize returns to go

eval_env_name = "Walker2d-v3"
eval_rtg_target = 5000
eval_env_d4rl_name = f'walker2d-{eval_dataset}-v2'

# eval_env_name = "HalfCheetah-v3"
# eval_rtg_target = 6000
# eval_env_d4rl_name = f'halfcheetah-{eval_dataset}-v2'

# eval_env_name = "Hopper-v3"
# eval_rtg_target = 3600
# eval_env_d4rl_name = f'hopper-{eval_dataset}-v2'


num_test_eval_ep = 10			# num of evaluation episodes
eval_max_eval_ep_len = 1000		# max len of one episode


context_len = 20        # K in decision transformer
n_blocks = 3            # num of transformer blocks
embed_dim = 128         # embedding (hidden) dim of transformer
n_heads = 1             # num of transformer heads
dropout_p = 0.1         # dropout probability


eval_chk_pt_dir = "/content/drive/MyDrive/6_8200_project/S4/s4_runs/"
# /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-18-47-30_best.pt

eval_chk_pt_name = "s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt"
eval_chk_pt_list = [eval_chk_pt_name]


## manually override check point list
## passing a list will evaluate on all checkpoints
## and output mean and std score


# eval_chk_pt_list = [
# 	"dt_walker2d-medium-v2_model_22-02-20-06-27-12_best.pt",
# 	"dt_walker2d-medium-v2_model_22-02-20-09-11-30_best.pt",
# 	"dt_walker2d-medium-v2_model_22-02-22-09-24-12_best.pt"
# ]

def get_d4rl_dataset_stats(env_d4rl_name):
    return D4RL_DATASET_STATS[env_d4rl_name]

env_data_stats = get_d4rl_dataset_stats(eval_env_d4rl_name)
eval_state_mean = np.array(env_data_stats['state_mean'])
eval_state_std = np.array(env_data_stats['state_std'])

eval_env = gym.make(eval_env_name)

state_dim = eval_env.observation_space.shape[0]
act_dim = eval_env.action_space.shape[0]

all_scores = []

for eval_chk_pt_name in eval_chk_pt_list:

	eval_model = S4Model(
		state_dim=state_dim,
		act_dim=act_dim,
		h_dim=d_model,
		context_len=1000, # what is this?
		dropout=dropout,
		n_layers=n_layers,
		prenorm=prenorm,
	).to(device)


	eval_chk_pt_path = os.path.join(eval_chk_pt_dir, eval_chk_pt_name)

	# load checkpoint
	eval_model.load_state_dict(torch.load(eval_chk_pt_path, map_location=device))

	print("model loaded from: " + eval_chk_pt_path)

	# evaluate on env
	results = evaluate_on_env(eval_model, device, context_len,
							eval_env, eval_rtg_target, eval_rtg_scale,
							num_test_eval_ep, eval_max_eval_ep_len,
							eval_state_mean, eval_state_std)
	print(results)

	norm_score = get_d4rl_normalized_score(results['eval/avg_reward'], eval_env_name) * 100
	print("normalized d4rl score: ", norm_score)

	all_scores.append(norm_score)

print("=" * 60)
all_scores = np.array(all_scores)
print("evaluated on env: " + eval_env_name)
print("total num of checkpoints evaluated: " + str(len(eval_chk_pt_list)))
print("d4rl score mean: " + format(all_scores.mean(), ".5f"))
print("d4rl score std: " + format(all_scores.std(), ".5f"))
print("d4rl score var: " + format(all_scores.var(), ".5f"))
print("=" * 60)
# Out:
# env: LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin
# model loaded from: /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-22-49-03.pt
# {'eval/avg_reward': 440.30685238982306, 'eval/avg_ep_len': 206.0}
# normalized d4rl score:  9.555854583225228
# ============================================================
# evaluated on env: Walker2d-v3
# total num of checkpoints evaluated: 1
# d4rl score mean: 9.55585
# d4rl score std: 0.00000
# d4rl score var: 0.00000
# ============================================================

# %%
from colabgymrender.recorder import Recorder

num_test_eval_ep = 1
eval_max_ep_len = 1000


directory = "/content/drive/MyDrive/6_8200_project/S4"
eval_env = Recorder(eval_env, directory)

results = evaluate_on_env(eval_model, device, context_len,
                        eval_env, eval_rtg_target, eval_rtg_scale,
                        num_test_eval_ep, eval_max_ep_len,
						eval_state_mean, eval_state_std)
print(results)

norm_score = get_d4rl_normalized_score(results['eval/avg_reward'], eval_env_name) * 100
print("normalized d4rl score: ", norm_score)

eval_env.play()

eval_env.close()
# Out:
# {'eval/avg_reward': 448.12052674110924, 'eval/avg_ep_len': 200.0}
# normalized d4rl score:  9.72606225798351
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-2a03382197a5> in <cell line: 19>()
#      17 print("normalized d4rl score: ", norm_score)
#      18
# ---> 19 eval_env.play()
#      20
#      21 eval_env.close()
#
# /usr/local/lib/python3.10/dist-packages/colabgymrender/recorder.py in play(self)
#      70         filename = 'temp-{start}.mp4'
#      71         clip = VideoFileClip(self.path)
# ---> 72         clip.write_videofile(filename, progress_bar = False, verbose = False)
#      73         display(Video(filename, embed = True))
#      74         os.remove(filename)
#
# TypeError: VideoClip.write_videofile() got an unexpected keyword argument 'progress_bar'

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch

# Data
print(f'==> Preparing {env_name} data..')

# %%
# set mujoco env path if not already set
# %env LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin


eval_dataset = "medium"		# medium / medium-replay / medium-expert
eval_rtg_scale = 1000		# normalize returns to go

eval_env_name = "Walker2d-v3"
eval_rtg_target = 5000
eval_env_d4rl_name = f'walker2d-{eval_dataset}-v2'

# eval_env_name = "HalfCheetah-v3"
# eval_rtg_target = 6000
# eval_env_d4rl_name = f'halfcheetah-{eval_dataset}-v2'

# eval_env_name = "Hopper-v3"
# eval_rtg_target = 3600
# eval_env_d4rl_name = f'hopper-{eval_dataset}-v2'


num_test_eval_ep = 10			# num of evaluation episodes
eval_max_eval_ep_len = 1000		# max len of one episode


context_len = 20        # K in decision transformer
n_blocks = 3            # num of transformer blocks
embed_dim = 128         # embedding (hidden) dim of transformer
n_heads = 1             # num of transformer heads
dropout_p = 0.1         # dropout probability


eval_chk_pt_dir = "/content/drive/MyDrive/6_8200_project/S4/"
# /content/drive/MyDrive/6_8200_project/S4/s4_runs/s4_walker2d-medium-v2_model_24-05-12-18-47-30_best.pt

eval_chk_pt_name = "mem.pkl"
eval_chk_pt_list = [eval_chk_pt_name]


## manually override check point list
## passing a list will evaluate on all checkpoints
## and output mean and std score


# eval_chk_pt_list = [
# 	"dt_walker2d-medium-v2_model_22-02-20-06-27-12_best.pt",
# 	"dt_walker2d-medium-v2_model_22-02-20-09-11-30_best.pt",
# 	"dt_walker2d-medium-v2_model_22-02-22-09-24-12_best.pt"
# ]

def get_d4rl_dataset_stats(env_d4rl_name):
    return D4RL_DATASET_STATS[env_d4rl_name]

env_data_stats = get_d4rl_dataset_stats(eval_env_d4rl_name)
eval_state_mean = np.array(env_data_stats['state_mean'])
eval_state_std = np.array(env_data_stats['state_std'])

eval_env = gym.make(eval_env_name)

state_dim = eval_env.observation_space.shape[0]
act_dim = eval_env.action_space.shape[0]

all_scores = []

for eval_chk_pt_name in eval_chk_pt_list:

	eval_model = S4Model(
		state_dim=state_dim,
		act_dim=act_dim,
		h_dim=d_model,
		context_len=1000, # what is this?
		dropout=dropout,
		n_layers=n_layers,
		prenorm=prenorm,
	).to(device)


	eval_chk_pt_path = os.path.join(eval_chk_pt_dir, eval_chk_pt_name)

	# load checkpoint
	eval_model.load_state_dict(torch.load(eval_chk_pt_path, map_location=device))

	print("model loaded from: " + eval_chk_pt_path)

	# evaluate on env
	results = evaluate_on_env(eval_model, device, context_len,
							eval_env, eval_rtg_target, eval_rtg_scale,
							num_test_eval_ep, eval_max_eval_ep_len,
							eval_state_mean, eval_state_std)
	print(results)

	norm_score = get_d4rl_normalized_score(results['eval/avg_reward'], eval_env_name) * 100
	print("normalized d4rl score: ", norm_score)

	all_scores.append(norm_score)

print("=" * 60)
all_scores = np.array(all_scores)
print("evaluated on env: " + eval_env_name)
print("total num of checkpoints evaluated: " + str(len(eval_chk_pt_list)))
print("d4rl score mean: " + format(all_scores.mean(), ".5f"))
print("d4rl score std: " + format(all_scores.std(), ".5f"))
print("d4rl score var: " + format(all_scores.var(), ".5f"))
print("=" * 60)
# Out:
# env: LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/root/.mujoco/mujoco200/bin
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-41-30275d1ebf8e> in <cell line: 64>()
#      78
#      79         # load checkpoint
# ---> 80         eval_model.load_state_dict(torch.load(eval_chk_pt_path, map_location=device))
#      81
#      82         print("model loaded from: " + eval_chk_pt_path)
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1038             except RuntimeError as e:
#    1039                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1040         return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#    1041
#    1042
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#    1258     magic_number = pickle_module.load(f, **pickle_load_args)
#    1259     if magic_number != MAGIC_NUMBER:
# -> 1260         raise RuntimeError("Invalid magic number; corrupt file?")
#    1261     protocol_version = pickle_module.load(f, **pickle_load_args)
#    1262     if protocol_version != PROTOCOL_VERSION:
#
# RuntimeError: Invalid magic number; corrupt file?
